# %% [markdown]
# 训练自编码器
#
# 用现在筛选过的数据训练自编码器
#
# 纯 MLP
#
# ---
# 有约束
#
# 效果：1.5156190395355225
#
#
# 无约束：
#
# 效果：0.0045988475903868675

# %%
# 直接训练
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import pickle
import os

from torch.utils.tensorboard import SummaryWriter


from model.PIAE_models import T7DAE2,Vehicle_Model_Methods

# 检查是否有可用的GPU
if torch.cuda.is_available():
    print('显卡参与训练')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# 显卡参与训练

# %%
# 1. 加载预处理后的数据
def load_preprocessed_data(input_file):
    with open(input_file, 'rb') as f:
        data = pickle.load(f)
    return data


input_file = '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/data/Task2_data'  # 替换为你保存的.pkl文件路径

tarin_data = load_preprocessed_data(os.path.join(input_file,'train_noisy_data.kpl'))
dataset = TensorDataset(tarin_data[1],tarin_data[0])
dataloader = DataLoader(dataset, batch_size=100, shuffle=True)


val_data = load_preprocessed_data(os.path.join(input_file,'val_noisy_data.kpl'))
val_input = val_data[1].to(device)
val_label = val_data[0].to(device)

# %%
class CustomLoss(nn.Module,Vehicle_Model_Methods):
    def __init__(self):
        super(CustomLoss, self).__init__()


    def forward(self, outputs, targets):

        # 计算自定义损失
        # 首先均方误差作为基础，保证平滑结果和原来数据的相似性
        mse_loss = nn.MSELoss()(outputs, targets)

        ax_limit_loss,delta_limit_loss=self.constrain_loss(outputs)

        custom_loss = mse_loss + ax_limit_loss*1e-1  + delta_limit_loss*1e1
        # custom_loss =  ax_limit_loss*1e-1  + delta_limit_loss*1e1
        # custom_loss =  mse_loss + loss_x*5e-2  + loss_y*5e-1 + ax_limit_loss*1e-1  + delta_limit_loss*1e1
        return custom_loss

# %%
# 3. 定义模型、损失函数和优化器
model = T7DAE2()
criterion = nn.MSELoss()
criterion2 = CustomLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-3)

model.to(device)
# Out:
# T7DAE2(
#   (encoder): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=40, out_features=400, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=400, out_features=100, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=100, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=40, bias=True)
#     (3): Unflatten(dim=1, unflattened_size=(2, 20))
#   )
# )

# %%
# 4. 训练模型Autoencoder


# 创建一个SummaryWriter对象，指定日志保存的路径
writer = SummaryWriter('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/logs/log7-1')
# log7 有无模型惩罚约束
# log7-1 无罚约束

epochs = 600
best_loss = float('inf')

for epoch in range(epochs):
    for batch_idx, (inputs,label) in enumerate(dataloader):  
        # 添加噪声
        inputs = inputs.to(device)  # 将输入数据移动到同一设备
        label = label.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        # print('output shape:',outputs.shape)

        # loss = criterion2(outputs, label) # 没有-1
        loss = criterion(outputs, label) # 有-1

        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}, Train Loss: {loss.item()}')

    with torch.no_grad():
        
        val_out = model(val_input)
        loss_val = criterion(val_out, val_label)
        orig_err = criterion(val_input, val_label)
    
    print(f'验证集上的指标为:{loss_val}，总噪声为:{orig_err},减少噪声{orig_err-loss_val}')
    
    if loss_val.item() < best_loss :
        # 保存模型
        torch.save(model.state_dict(), '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task7-1_model_best.pth')
        best_loss = loss_val.item()

    # 使用SummaryWriter记录数据
    writer.add_scalar('Loss/train', loss, epoch)
    writer.add_scalar('Loss/val', loss_val, epoch)

# 关闭SummaryWriter
writer.close()
# Out:
# Epoch 1, Train Loss: 0.005826626904308796
# 验证集上的指标为:0.007055501453578472，总噪声为:0.025070490315556526,减少噪声0.01801498979330063
# Epoch 2, Train Loss: 0.009132927283644676
# 验证集上的指标为:0.007065538316965103，总噪声为:0.025070490315556526,减少噪声0.018004951998591423
# Epoch 3, Train Loss: 0.0067596882581710815
# 验证集上的指标为:0.006718420423567295，总噪声为:0.025070490315556526,减少噪声0.018352068960666656
# Epoch 4, Train Loss: 0.00568522559478879
# 验证集上的指标为:0.006978572346270084，总噪声为:0.025070490315556526,减少噪声0.018091917037963867
# Epoch 5, Train Loss: 0.007207423914223909
# 验证集上的指标为:0.0074385893531143665，总噪声为:0.025070490315556526,减少噪声0.017631901428103447
# Epoch 6, Train Loss: 0.005895568523555994
# 验证集上的指标为:0.006065338850021362，总噪声为:0.025070490315556526,减少噪声0.019005151465535164
# Epoch 7, Train Loss: 0.0056274933740496635
# 验证集上的指标为:0.005464760586619377，总噪声为:0.025070490315556526,减少噪声0.01960572972893715
# Epoch 8, Train Loss: 0.005495812278240919
# 验证集上的指标为:0.007917838171124458，总噪声为:0.025070490315556526,减少噪声0.017152652144432068
# Epoch 9, Train Loss: 0.007677983492612839
# 验证集上的指标为:0.005673632491379976，总噪声为:0.025070490315556526,减少噪声0.019396858289837837
# Epoch 10, Train Loss: 0.005612481385469437
# 验证集上的指标为:0.006194939836859703，总噪声为:0.025070490315556526,减少噪声0.018875550478696823
# Epoch 11, Train Loss: 0.005655475426465273
# 验证集上的指标为:0.006499534007161856，总噪声为:0.025070490315556526,减少噪声0.018570955842733383
# Epoch 12, Train Loss: 0.008976861834526062
# 验证集上的指标为:0.0075742630288004875，总噪声为:0.025070490315556526,减少噪声0.017496228218078613
# Epoch 13, Train Loss: 0.00559884961694479
# 验证集上的指标为:0.005757281091064215，总噪声为:0.025070490315556526,减少噪声0.019313208758831024
# Epoch 14, Train Loss: 0.006348589435219765
# 验证集上的指标为:0.0056523606181144714，总噪声为:0.025070490315556526,减少噪声0.019418129697442055
# Epoch 15, Train Loss: 0.005177091341465712
# 验证集上的指标为:0.0054815360344946384，总噪声为:0.025070490315556526,减少噪声0.019588954746723175
# Epoch 16, Train Loss: 0.004307462368160486
# 验证集上的指标为:0.006184061989188194，总噪声为:0.025070490315556526,减少噪声0.018886428326368332
# Epoch 17, Train Loss: 0.004239596426486969
# 验证集上的指标为:0.006578325293958187，总噪声为:0.025070490315556526,减少噪声0.018492165952920914
# Epoch 18, Train Loss: 0.006307888776063919
# 验证集上的指标为:0.005320009309798479，总噪声为:0.025070490315556526,减少噪声0.019750481471419334
# Epoch 19, Train Loss: 0.005379623733460903
# 验证集上的指标为:0.004934508353471756，总噪声为:0.025070490315556526,减少噪声0.02013598196208477
# Epoch 20, Train Loss: 0.005984377581626177
# 验证集上的指标为:0.005612798035144806，总噪声为:0.025070490315556526,减少噪声0.01945769228041172
# Epoch 21, Train Loss: 0.005408823024481535
# 验证集上的指标为:0.005796832963824272，总噪声为:0.025070490315556526,减少噪声0.019273657351732254
# Epoch 22, Train Loss: 0.0061508710496127605
# 验证集上的指标为:0.00549954641610384，总噪声为:0.025070490315556526,减少噪声0.01957094296813011
# Epoch 23, Train Loss: 0.0052881003357470036
# 验证集上的指标为:0.005406197626143694，总噪声为:0.025070490315556526,减少噪声0.01966429315507412
# Epoch 24, Train Loss: 0.004602605942636728
# 验证集上的指标为:0.005141656380146742，总噪声为:0.025070490315556526,减少噪声0.019928833469748497
# Epoch 25, Train Loss: 0.0042744893580675125
# 验证集上的指标为:0.005563060287386179，总噪声为:0.025070490315556526,减少噪声0.019507430493831635
# Epoch 26, Train Loss: 0.004344734363257885
# 验证集上的指标为:0.006387070752680302，总噪声为:0.025070490315556526,减少噪声0.01868341863155365
# Epoch 27, Train Loss: 0.005527873057872057
# 验证集上的指标为:0.0052678450010716915，总噪声为:0.025070490315556526,减少噪声0.019802644848823547
# Epoch 28, Train Loss: 0.00911624450236559
# 验证集上的指标为:0.005584231577813625，总噪声为:0.025070490315556526,减少噪声0.019486259669065475
# Epoch 29, Train Loss: 0.005917670670896769
# 验证集上的指标为:0.007724054157733917，总噪声为:0.025070490315556526,减少噪声0.01734643615782261
# Epoch 30, Train Loss: 0.005477372091263533
# 验证集上的指标为:0.005136452149599791，总噪声为:0.025070490315556526,减少噪声0.01993403770029545
# Epoch 31, Train Loss: 0.005105964373797178
# 验证集上的指标为:0.005594979971647263，总噪声为:0.025070490315556526,减少噪声0.019475510343909264
# Epoch 32, Train Loss: 0.0052068172954022884
# 验证集上的指标为:0.00506982859224081，总噪声为:0.025070490315556526,减少噪声0.02000066265463829
# Epoch 33, Train Loss: 0.00596146285533905
# 验证集上的指标为:0.005413824692368507，总噪声为:0.025070490315556526,减少噪声0.01965666562318802
# Epoch 34, Train Loss: 0.004482132848352194
# 验证集上的指标为:0.005071096122264862，总噪声为:0.025070490315556526,减少噪声0.019999394193291664
# Epoch 35, Train Loss: 0.005370288155972958
# 验证集上的指标为:0.0052732801996171474，总噪声为:0.025070490315556526,减少噪声0.01979720965027809
# Epoch 36, Train Loss: 0.005423532333225012
# 验证集上的指标为:0.005305008962750435，总噪声为:0.025070490315556526,减少噪声0.01976548135280609
# Epoch 37, Train Loss: 0.005372818559408188
# 验证集上的指标为:0.0061198147013783455，总噪声为:0.025070490315556526,减少噪声0.018950674682855606
# Epoch 38, Train Loss: 0.004920053295791149
# 验证集上的指标为:0.004970320966094732，总噪声为:0.025070490315556526,减少噪声0.020100168883800507
# Epoch 39, Train Loss: 0.004530136473476887
# 验证集上的指标为:0.005138640757650137，总噪声为:0.025070490315556526,减少噪声0.019931849092245102
# Epoch 40, Train Loss: 0.005446529481559992
# 验证集上的指标为:0.005379941780120134，总噪声为:0.025070490315556526,减少噪声0.01969054900109768
# Epoch 41, Train Loss: 0.005085892044007778
# 验证集上的指标为:0.005181705113500357，总噪声为:0.025070490315556526,减少噪声0.019888784736394882
# Epoch 42, Train Loss: 0.00508266082033515
# 验证集上的指标为:0.004933840129524469，总噪声为:0.025070490315556526,减少噪声0.020136650651693344
# Epoch 43, Train Loss: 0.005551907699555159
# 验证集上的指标为:0.005327099934220314，总噪声为:0.025070490315556526,减少噪声0.019743390381336212
# Epoch 44, Train Loss: 0.00465785525739193
# 验证集上的指标为:0.005088625475764275，总噪声为:0.025070490315556526,减少噪声0.01998186483979225
# Epoch 45, Train Loss: 0.0052907150238752365
# 验证集上的指标为:0.005298927426338196，总噪声为:0.025070490315556526,减少噪声0.01977156288921833
# Epoch 46, Train Loss: 0.00499124638736248
# 验证集上的指标为:0.005086999852210283，总噪声为:0.025070490315556526,减少噪声0.01998349092900753
# Epoch 47, Train Loss: 0.005391925107687712
# 验证集上的指标为:0.00535525381565094，总噪声为:0.025070490315556526,减少噪声0.019715236499905586
# Epoch 48, Train Loss: 0.009180284105241299
# 验证集上的指标为:0.006418144330382347，总噪声为:0.025070490315556526,减少噪声0.01865234598517418
# Epoch 49, Train Loss: 0.004262126982212067
# 验证集上的指标为:0.005005269777029753，总噪声为:0.025070490315556526,减少噪声0.020065220072865486
# Epoch 50, Train Loss: 0.005477352067828178
# 验证集上的指标为:0.006087181624025106，总噪声为:0.025070490315556526,减少噪声0.018983308225870132
# Epoch 51, Train Loss: 0.004920004867017269
# 验证集上的指标为:0.005032313521951437，总噪声为:0.025070490315556526,减少噪声0.020038176327943802
# Epoch 52, Train Loss: 0.004318299237638712
# 验证集上的指标为:0.005055756773799658，总噪声为:0.025070490315556526,减少噪声0.02001473307609558
# Epoch 53, Train Loss: 0.005638466216623783
# 验证集上的指标为:0.005032512359321117，总噪声为:0.025070490315556526,减少噪声0.020037978887557983
# Epoch 54, Train Loss: 0.0056829978711903095
# 验证集上的指标为:0.005196713376790285，总噪声为:0.025070490315556526,减少噪声0.01987377740442753
# Epoch 55, Train Loss: 0.0047541833482682705
# 验证集上的指标为:0.005064536817371845，总噪声为:0.025070490315556526,减少噪声0.020005952566862106
# Epoch 56, Train Loss: 0.005013853777199984
# 验证集上的指标为:0.005099550820887089，总噪声为:0.025070490315556526,减少噪声0.019970938563346863
# Epoch 57, Train Loss: 0.004989982582628727
# 验证集上的指标为:0.005012505687773228，总噪声为:0.025070490315556526,减少噪声0.020057983696460724
# Epoch 58, Train Loss: 0.004706998821347952
# 验证集上的指标为:0.005195441655814648，总噪声为:0.025070490315556526,减少噪声0.019875049591064453
# Epoch 59, Train Loss: 0.004287028219550848
# 验证集上的指标为:0.004803807009011507，总噪声为:0.025070490315556526,减少噪声0.020266683772206306
# Epoch 60, Train Loss: 0.004401115700602531
# 验证集上的指标为:0.005298448260873556，总噪声为:0.025070490315556526,减少噪声0.019772041589021683
# Epoch 61, Train Loss: 0.004617849364876747
# 验证集上的指标为:0.00530831515789032，总噪声为:0.025070490315556526,减少噪声0.019762175157666206
# Epoch 62, Train Loss: 0.005165452603250742
# 验证集上的指标为:0.004889410920441151，总噪声为:0.025070490315556526,减少噪声0.0201810784637928
# Epoch 63, Train Loss: 0.00491848960518837
# 验证集上的指标为:0.005056669469922781，总噪声为:0.025070490315556526,减少噪声0.020013820379972458
# Epoch 64, Train Loss: 0.004573005251586437
# 验证集上的指标为:0.0051640174351632595，总噪声为:0.025070490315556526,减少噪声0.01990647241473198
# Epoch 65, Train Loss: 0.005422163754701614
# 验证集上的指标为:0.005464950576424599，总噪声为:0.025070490315556526,减少噪声0.019605539739131927
# Epoch 66, Train Loss: 0.0051728724502027035
# 验证集上的指标为:0.0049913241527974606，总噪声为:0.025070490315556526,减少噪声0.02007916569709778
# Epoch 67, Train Loss: 0.004958019591867924
# 验证集上的指标为:0.004934878554195166，总噪声为:0.025070490315556526,减少噪声0.020135611295700073
# Epoch 68, Train Loss: 0.004286127630621195
# 验证集上的指标为:0.0048046354204416275，总噪声为:0.025070490315556526,减少噪声0.0202658548951149
# Epoch 69, Train Loss: 0.004981472156941891
# 验证集上的指标为:0.005605542566627264，总噪声为:0.025070490315556526,减少噪声0.019464947283267975
# Epoch 70, Train Loss: 0.0054338425397872925
# 验证集上的指标为:0.0058131092227995396，总噪声为:0.025070490315556526,减少噪声0.019257381558418274
# Epoch 71, Train Loss: 0.005437964573502541
# 验证集上的指标为:0.004914189223200083，总噪声为:0.025070490315556526,减少噪声0.02015630155801773
# Epoch 72, Train Loss: 0.005448070354759693
# 验证集上的指标为:0.005553285591304302，总噪声为:0.025070490315556526,减少噪声0.0195172056555748
# Epoch 73, Train Loss: 0.0058697862550616264
# 验证集上的指标为:0.004850513301789761，总噪声为:0.025070490315556526,减少噪声0.02021997794508934
# Epoch 74, Train Loss: 0.005447682458907366
# 验证集上的指标为:0.004790242295712233，总噪声为:0.025070490315556526,减少噪声0.020280247554183006
# Epoch 75, Train Loss: 0.005211581010371447
# 验证集上的指标为:0.00473879836499691，总噪声为:0.025070490315556526,减少噪声0.020331691950559616
# Epoch 76, Train Loss: 0.005231902934610844
# 验证集上的指标为:0.0048346309922635555，总噪声为:0.025070490315556526,减少噪声0.020235858857631683
# Epoch 77, Train Loss: 0.004574613645672798
# 验证集上的指标为:0.004713429603725672，总噪声为:0.025070490315556526,减少噪声0.02035706117749214
# Epoch 78, Train Loss: 0.0040158918127417564
# 验证集上的指标为:0.00477720657363534，总噪声为:0.025070490315556526,减少噪声0.020293284207582474
# Epoch 79, Train Loss: 0.004515723325312138
# 验证集上的指标为:0.005090079270303249，总噪声为:0.025070490315556526,减少噪声0.01998041197657585
# Epoch 80, Train Loss: 0.004170549567788839
# 验证集上的指标为:0.005067850463092327，总噪声为:0.025070490315556526,减少噪声0.020002640783786774
# Epoch 81, Train Loss: 0.005711869336664677
# 验证集上的指标为:0.004886961076408625，总噪声为:0.025070490315556526,减少噪声0.02018352970480919
# Epoch 82, Train Loss: 0.005042742006480694
# 验证集上的指标为:0.005168534349650145，总噪声为:0.025070490315556526,减少噪声0.019901955500245094
# Epoch 83, Train Loss: 0.005865383427590132
# 验证集上的指标为:0.005100648384541273，总噪声为:0.025070490315556526,减少噪声0.019969841465353966
# Epoch 84, Train Loss: 0.005447168368846178
# 验证集上的指标为:0.005185006186366081，总噪声为:0.025070490315556526,减少噪声0.019885484129190445
# Epoch 85, Train Loss: 0.005112027283757925
# 验证集上的指标为:0.005054847337305546，总噪声为:0.025070490315556526,减少噪声0.020015642046928406
# Epoch 86, Train Loss: 0.004687311593443155
# 验证集上的指标为:0.00485382741317153，总噪声为:0.025070490315556526,减少噪声0.02021666243672371
# Epoch 87, Train Loss: 0.0051431977190077305
# 验证集上的指标为:0.005192616954445839，总噪声为:0.025070490315556526,减少噪声0.019877873361110687
# Epoch 88, Train Loss: 0.0051219710148870945
# 验证集上的指标为:0.004980025347322226，总噪声为:0.025070490315556526,减少噪声0.020090464502573013
# Epoch 89, Train Loss: 0.004837894346565008
# 验证集上的指标为:0.005288312211632729，总噪声为:0.025070490315556526,减少噪声0.019782178103923798
# Epoch 90, Train Loss: 0.004868757911026478
# 验证集上的指标为:0.005140267312526703，总噪声为:0.025070490315556526,减少噪声0.019930223003029823
# Epoch 91, Train Loss: 0.004979840014129877
# 验证集上的指标为:0.005621722899377346，总噪声为:0.025070490315556526,减少噪声0.019448768347501755
# Epoch 92, Train Loss: 0.005245196167379618
# 验证集上的指标为:0.004924975801259279，总噪声为:0.025070490315556526,减少噪声0.020145514979958534
# Epoch 93, Train Loss: 0.0065922923386096954
# 验证集上的指标为:0.005589667707681656，总噪声为:0.025070490315556526,减少噪声0.01948082260787487
# Epoch 94, Train Loss: 0.004915577359497547
# 验证集上的指标为:0.004827318713068962，总噪声为:0.025070490315556526,减少噪声0.020243171602487564
# Epoch 95, Train Loss: 0.004992785397917032
# 验证集上的指标为:0.005450959783047438，总噪声为:0.025070490315556526,减少噪声0.0196195300668478
# Epoch 96, Train Loss: 0.00526927225291729
# 验证集上的指标为:0.004911542870104313，总噪声为:0.025070490315556526,减少噪声0.02015894651412964
# Epoch 97, Train Loss: 0.004938493482768536
# 验证集上的指标为:0.0054887887090444565，总噪声为:0.025070490315556526,减少噪声0.01958170160651207
# Epoch 98, Train Loss: 0.004664713051170111
# 验证集上的指标为:0.004808424971997738，总噪声为:0.025070490315556526,减少噪声0.020262066274881363
# Epoch 99, Train Loss: 0.0047081527300179005
# 验证集上的指标为:0.004874177742749453，总噪声为:0.025070490315556526,减少噪声0.02019631303846836
# Epoch 100, Train Loss: 0.0039784773252904415
# 验证集上的指标为:0.004887657705694437，总噪声为:0.025070490315556526,减少噪声0.020182833075523376
# Epoch 101, Train Loss: 0.004202131647616625
# 验证集上的指标为:0.0047996933571994305，总噪声为:0.025070490315556526,减少噪声0.02027079649269581
# Epoch 102, Train Loss: 0.004932898096740246
# 验证集上的指标为:0.004979769233614206，总噪声为:0.025070490315556526,减少噪声0.020090721547603607
# Epoch 103, Train Loss: 0.004619866143912077
# 验证集上的指标为:0.004851291887462139，总噪声为:0.025070490315556526,减少噪声0.02021919935941696
# Epoch 104, Train Loss: 0.006255278829485178
# 验证集上的指标为:0.004959036596119404，总噪声为:0.025070490315556526,减少噪声0.020111452788114548
# Epoch 105, Train Loss: 0.004570948425680399
# 验证集上的指标为:0.004774590488523245，总噪声为:0.025070490315556526,减少噪声0.020295899361371994
# Epoch 106, Train Loss: 0.0038374774158000946
# 验证集上的指标为:0.005303087178617716，总噪声为:0.025070490315556526,减少噪声0.019767403602600098
# Epoch 107, Train Loss: 0.005377893801778555
# 验证集上的指标为:0.005081173963844776，总噪声为:0.025070490315556526,减少噪声0.019989315420389175
# Epoch 108, Train Loss: 0.004609128925949335
# 验证集上的指标为:0.004858544562011957，总噪声为:0.025070490315556526,减少噪声0.020211946219205856
# Epoch 109, Train Loss: 0.007445530500262976
# 验证集上的指标为:0.008768456988036633，总噪声为:0.025070490315556526,减少噪声0.016302034258842468
# Epoch 110, Train Loss: 0.005142176058143377
# 验证集上的指标为:0.004697958938777447，总噪声为:0.025070490315556526,减少噪声0.020372532308101654
# Epoch 111, Train Loss: 0.0065591903403401375
# 验证集上的指标为:0.004847736097872257，总噪声为:0.025070490315556526,减少噪声0.020222753286361694
# Epoch 112, Train Loss: 0.004803755786269903
# 验证集上的指标为:0.004855995066463947，总噪声为:0.025070490315556526,减少噪声0.020214494317770004
# Epoch 113, Train Loss: 0.005470101721584797
# 验证集上的指标为:0.00508709205314517，总噪声为:0.025070490315556526,减少噪声0.01998339779675007
# Epoch 114, Train Loss: 0.005300144664943218
# 验证集上的指标为:0.005465561989694834，总噪声为:0.025070490315556526,减少噪声0.01960492879152298
# Epoch 115, Train Loss: 0.0049636391922831535
# 验证集上的指标为:0.0052053676918148994，总噪声为:0.025070490315556526,减少噪声0.019865121692419052
# Epoch 116, Train Loss: 0.005728548392653465
# 验证集上的指标为:0.00570217240601778，总噪声为:0.025070490315556526,减少噪声0.01936831697821617
# Epoch 117, Train Loss: 0.004726959392428398
# 验证集上的指标为:0.004642536398023367，总噪声为:0.025070490315556526,减少噪声0.020427953451871872
# Epoch 118, Train Loss: 0.004364788066595793
# 验证集上的指标为:0.0048110815696418285，总噪声为:0.025070490315556526,减少噪声0.02025940828025341
# Epoch 119, Train Loss: 0.005076757166534662
# 验证集上的指标为:0.004784369841217995，总噪声为:0.025070490315556526,减少噪声0.02028612047433853
# Epoch 120, Train Loss: 0.00588976638391614
# 验证集上的指标为:0.004877043887972832，总噪声为:0.025070490315556526,减少噪声0.020193446427583694
# Epoch 121, Train Loss: 0.006057787220925093
# 验证集上的指标为:0.005459317937493324，总噪声为:0.025070490315556526,减少噪声0.019611172378063202
# Epoch 122, Train Loss: 0.005392713006585836
# 验证集上的指标为:0.005215357057750225，总噪声为:0.025070490315556526,减少噪声0.019855134189128876
# Epoch 123, Train Loss: 0.005796448327600956
# 验证集上的指标为:0.005300255957990885，总噪声为:0.025070490315556526,减少噪声0.01977023482322693
# Epoch 124, Train Loss: 0.005036091897636652
# 验证集上的指标为:0.005494728218764067，总噪声为:0.025070490315556526,减少噪声0.019575761631131172
# Epoch 125, Train Loss: 0.0045600407756865025
# 验证集上的指标为:0.005035225301980972，总噪声为:0.025070490315556526,减少噪声0.020035265013575554
# Epoch 126, Train Loss: 0.003538296325132251
# 验证集上的指标为:0.004805013537406921，总噪声为:0.025070490315556526,减少噪声0.020265476778149605
# Epoch 127, Train Loss: 0.005807924084365368
# 验证集上的指标为:0.004839085973799229，总噪声为:0.025070490315556526,减少噪声0.020231403410434723
# Epoch 128, Train Loss: 0.0043406118638813496
# 验证集上的指标为:0.004939984064549208，总噪声为:0.025070490315556526,减少噪声0.02013050578534603
# Epoch 129, Train Loss: 0.005274969153106213
# 验证集上的指标为:0.004740213043987751，总噪声为:0.025070490315556526,减少噪声0.0203302763402462
# Epoch 130, Train Loss: 0.004164826590567827
# 验证集上的指标为:0.004954409785568714，总噪声为:0.025070490315556526,减少噪声0.020116079598665237
# Epoch 131, Train Loss: 0.0038198980037122965
# 验证集上的指标为:0.0050720339640975，总噪声为:0.025070490315556526,减少噪声0.0199984572827816
# Epoch 132, Train Loss: 0.004057110752910376
# 验证集上的指标为:0.004898477345705032，总噪声为:0.025070490315556526,减少噪声0.020172012969851494
# Epoch 133, Train Loss: 0.004897836595773697
# 验证集上的指标为:0.005177595186978579，总噪声为:0.025070490315556526,减少噪声0.019892895594239235
# Epoch 134, Train Loss: 0.005148039199411869
# 验证集上的指标为:0.004713701084256172，总噪声为:0.025070490315556526,减少噪声0.020356789231300354
# Epoch 135, Train Loss: 0.005133477970957756
# 验证集上的指标为:0.004938233643770218，总噪声为:0.025070490315556526,减少噪声0.02013225667178631
# Epoch 136, Train Loss: 0.005572413560003042
# 验证集上的指标为:0.004937292076647282，总噪声为:0.025070490315556526,减少噪声0.02013319730758667
# Epoch 137, Train Loss: 0.005009276792407036
# 验证集上的指标为:0.0050020827911794186，总噪声为:0.025070490315556526,减少噪声0.02006840705871582
# Epoch 138, Train Loss: 0.006937348283827305
# 验证集上的指标为:0.00575827993452549，总噪声为:0.025070490315556526,减少噪声0.019312210381031036
# Epoch 139, Train Loss: 0.00496208481490612
# 验证集上的指标为:0.005168074741959572，总噪声为:0.025070490315556526,减少噪声0.019902415573596954
# Epoch 140, Train Loss: 0.004452020861208439
# 验证集上的指标为:0.0048529002815485，总噪声为:0.025070490315556526,减少噪声0.020217590034008026
# Epoch 141, Train Loss: 0.005064039956778288
# 验证集上的指标为:0.005006744060665369，总噪声为:0.025070490315556526,减少噪声0.020063746720552444
# Epoch 142, Train Loss: 0.004889096599072218
# 验证集上的指标为:0.005295992363244295，总噪声为:0.025070490315556526,减少噪声0.01977449841797352
# Epoch 143, Train Loss: 0.004046246409416199
# 验证集上的指标为:0.004721079953014851，总噪声为:0.025070490315556526,减少噪声0.0203494094312191
# Epoch 144, Train Loss: 0.005142960697412491
# 验证集上的指标为:0.005134178325533867，总噪声为:0.025070490315556526,减少噪声0.01993631199002266
# Epoch 145, Train Loss: 0.004607340320944786
# 验证集上的指标为:0.00506877526640892，总噪声为:0.025070490315556526,减少噪声0.020001715049147606
# Epoch 146, Train Loss: 0.005089920479804277
# 验证集上的指标为:0.00498987315222621，总噪声为:0.025070490315556526,减少噪声0.02008061669766903
# Epoch 147, Train Loss: 0.005337233655154705
# 验证集上的指标为:0.005501205567270517，总噪声为:0.025070490315556526,减少噪声0.019569285213947296
# Epoch 148, Train Loss: 0.004839906468987465
# 验证集上的指标为:0.004775688983500004，总噪声为:0.025070490315556526,减少噪声0.020294800400733948
# Epoch 149, Train Loss: 0.00486780097708106
# 验证集上的指标为:0.004798917565494776，总噪声为:0.025070490315556526,减少噪声0.020271573215723038
# Epoch 150, Train Loss: 0.004681882914155722
# 验证集上的指标为:0.0049313632771372795，总噪声为:0.025070490315556526,减少噪声0.02013912796974182
# Epoch 151, Train Loss: 0.0042200759053230286
# 验证集上的指标为:0.004704521037638187，总噪声为:0.025070490315556526,减少噪声0.020365968346595764
# Epoch 152, Train Loss: 0.005886381026357412
# 验证集上的指标为:0.0052949534729123116，总噪声为:0.025070490315556526,减少噪声0.01977553591132164
# Epoch 153, Train Loss: 0.005553950555622578
# 验证集上的指标为:0.005079347174614668，总噪声为:0.025070490315556526,减少噪声0.01999114267528057
# Epoch 154, Train Loss: 0.004328799434006214
# 验证集上的指标为:0.0050045582465827465，总噪声为:0.025070490315556526,减少噪声0.020065931603312492
# Epoch 155, Train Loss: 0.005233575124293566
# 验证集上的指标为:0.0048594423569738865，总噪声为:0.025070490315556526,减少噪声0.020211048424243927
# Epoch 156, Train Loss: 0.005406270734965801
# 验证集上的指标为:0.00564440106973052，总噪声为:0.025070490315556526,减少噪声0.01942608878016472
# Epoch 157, Train Loss: 0.006112376693636179
# 验证集上的指标为:0.005539475474506617，总噪声为:0.025070490315556526,减少噪声0.019531015306711197
# Epoch 158, Train Loss: 0.005111800041049719
# 验证集上的指标为:0.005056708585470915，总噪声为:0.025070490315556526,减少噪声0.020013781264424324
# Epoch 159, Train Loss: 0.005177789367735386
# 验证集上的指标为:0.004921416286379099，总噪声为:0.025070490315556526,减少噪声0.020149074494838715
# Epoch 160, Train Loss: 0.0036115036346018314
# 验证集上的指标为:0.004831527825444937，总噪声为:0.025070490315556526,减少噪声0.020238962024450302
# Epoch 161, Train Loss: 0.004542526323348284
# 验证集上的指标为:0.004850628320127726，总噪声为:0.025070490315556526,减少噪声0.020219862461090088
# Epoch 162, Train Loss: 0.005555645562708378
# 验证集上的指标为:0.004670279566198587，总噪声为:0.025070490315556526,减少噪声0.020400211215019226
# Epoch 163, Train Loss: 0.004754727706313133
# 验证集上的指标为:0.004930573981255293，总噪声为:0.025070490315556526,减少噪声0.020139915868639946
# Epoch 164, Train Loss: 0.004444166086614132
# 验证集上的指标为:0.004779039416462183，总噪声为:0.025070490315556526,减少噪声0.02029145136475563
# Epoch 165, Train Loss: 0.005526948720216751
# 验证集上的指标为:0.00489899842068553，总噪声为:0.025070490315556526,减少噪声0.02017149142920971
# Epoch 166, Train Loss: 0.005022081080824137
# 验证集上的指标为:0.004665003158152103，总噪声为:0.025070490315556526,减少噪声0.020405486226081848
# Epoch 167, Train Loss: 0.0037740294355899096
# 验证集上的指标为:0.005019567906856537，总噪声为:0.025070490315556526,减少噪声0.02005092240869999
# Epoch 168, Train Loss: 0.0042426129803061485
# 验证集上的指标为:0.00484434561803937，总噪声为:0.025070490315556526,减少噪声0.020226145163178444
# Epoch 169, Train Loss: 0.004851523786783218
# 验证集上的指标为:0.00517233507707715，总噪声为:0.025070490315556526,减少噪声0.019898155704140663
# Epoch 170, Train Loss: 0.00442077498883009
# 验证集上的指标为:0.0051983124576509，总噪声为:0.025070490315556526,减少噪声0.01987217739224434
# Epoch 171, Train Loss: 0.00489585567265749
# 验证集上的指标为:0.00601234519854188，总噪声为:0.025070490315556526,减少噪声0.019058145582675934
# Epoch 172, Train Loss: 0.004572166595607996
# 验证集上的指标为:0.004991617053747177，总噪声为:0.025070490315556526,减少噪声0.02007887326180935
# Epoch 173, Train Loss: 0.004649442620575428
# 验证集上的指标为:0.004958794452250004，总噪声为:0.025070490315556526,减少噪声0.020111694931983948
# Epoch 174, Train Loss: 0.005057003814727068
# 验证集上的指标为:0.004939536098390818，总噪声为:0.025070490315556526,减少噪声0.020130954682826996
# Epoch 175, Train Loss: 0.00487919757142663
# 验证集上的指标为:0.004736806266009808，总噪声为:0.025070490315556526,减少噪声0.020333684980869293
# Epoch 176, Train Loss: 0.00559059577062726
# 验证集上的指标为:0.004787416197359562，总噪声为:0.025070490315556526,减少噪声0.02028307318687439
# Epoch 177, Train Loss: 0.0046557593159377575
# 验证集上的指标为:0.004970518406480551，总噪声为:0.025070490315556526,减少噪声0.020099971443414688
# Epoch 178, Train Loss: 0.005110883619636297
# 验证集上的指标为:0.004921782296150923，总噪声为:0.025070490315556526,减少噪声0.020148707553744316
# Epoch 179, Train Loss: 0.004569513723254204
# 验证集上的指标为:0.004895759280771017，总噪声为:0.025070490315556526,减少噪声0.020174730569124222
# Epoch 180, Train Loss: 0.004695905838161707
# 验证集上的指标为:0.00512232119217515，总噪声为:0.025070490315556526,减少噪声0.019948169589042664
# Epoch 181, Train Loss: 0.004242248833179474
# 验证集上的指标为:0.005409779492765665，总噪声为:0.025070490315556526,减少噪声0.01966071128845215
# Epoch 182, Train Loss: 0.005456110928207636
# 验证集上的指标为:0.004752551205456257，总噪声为:0.025070490315556526,减少噪声0.020317938178777695
# Epoch 183, Train Loss: 0.004787703510373831
# 验证集上的指标为:0.005559643730521202，总噪声为:0.025070490315556526,减少噪声0.019510846585035324
# Epoch 184, Train Loss: 0.004414308350533247
# 验证集上的指标为:0.005222253035753965，总噪声为:0.025070490315556526,减少噪声0.019848236814141273
# Epoch 185, Train Loss: 0.0046387603506445885
# 验证集上的指标为:0.004797798115760088，总噪声为:0.025070490315556526,减少噪声0.020272692665457726
# Epoch 186, Train Loss: 0.004525783471763134
# 验证集上的指标为:0.005170424003154039，总噪声为:0.025070490315556526,减少噪声0.019900066778063774
# Epoch 187, Train Loss: 0.004135058261454105
# 验证集上的指标为:0.004964007530361414，总噪声为:0.025070490315556526,减少噪声0.0201064832508564
# Epoch 188, Train Loss: 0.004043945576995611
# 验证集上的指标为:0.005285071209073067，总噪声为:0.025070490315556526,减少噪声0.01978541910648346
# Epoch 189, Train Loss: 0.0045411475002765656
# 验证集上的指标为:0.0048452625051140785，总噪声为:0.025070490315556526,减少噪声0.020225226879119873
# Epoch 190, Train Loss: 0.00996645912528038
# 验证集上的指标为:0.0047829411923885345，总噪声为:0.025070490315556526,减少噪声0.02028754912316799
# Epoch 191, Train Loss: 0.004438731819391251
# 验证集上的指标为:0.004880304913967848，总噪声为:0.025070490315556526,减少噪声0.02019018493592739
# Epoch 192, Train Loss: 0.004453587811440229
# 验证集上的指标为:0.005015010014176369，总噪声为:0.025070490315556526,减少噪声0.020055480301380157
# Epoch 193, Train Loss: 0.004535894375294447
# 验证集上的指标为:0.0047343214973807335，总噪声为:0.025070490315556526,减少噪声0.020336169749498367
# Epoch 194, Train Loss: 0.0052317483350634575
# 验证集上的指标为:0.004708533640950918，总噪声为:0.025070490315556526,减少噪声0.02036195620894432
# Epoch 195, Train Loss: 0.005617497954517603
# 验证集上的指标为:0.005308439489454031，总噪声为:0.025070490315556526,减少噪声0.019762050360441208
# Epoch 196, Train Loss: 0.004791628569364548
# 验证集上的指标为:0.0050650592893362045，总噪声为:0.025070490315556526,减少噪声0.02000543102622032
# Epoch 197, Train Loss: 0.004436840303242207
# 验证集上的指标为:0.004618814215064049，总噪声为:0.025070490315556526,减少噪声0.020451676100492477
# Epoch 198, Train Loss: 0.004297645762562752
# 验证集上的指标为:0.004910407122224569，总噪声为:0.025070490315556526,减少噪声0.02016008272767067
# Epoch 199, Train Loss: 0.005817488767206669
# 验证集上的指标为:0.004699979908764362，总噪声为:0.025070490315556526,减少噪声0.02037050947546959
# Epoch 200, Train Loss: 0.0051137409172952175
# 验证集上的指标为:0.005002581514418125，总噪声为:0.025070490315556526,减少噪声0.020067907869815826
# Epoch 201, Train Loss: 0.0052148220129311085
# 验证集上的指标为:0.004746164660900831，总噪声为:0.025070490315556526,减少噪声0.020324325188994408
# Epoch 202, Train Loss: 0.005068034399300814
# 验证集上的指标为:0.005140725523233414，总噪声为:0.025070490315556526,减少噪声0.019929764792323112
# Epoch 203, Train Loss: 0.0057980394922196865
# 验证集上的指标为:0.004659195430576801，总噪声为:0.025070490315556526,减少噪声0.02041129395365715
# Epoch 204, Train Loss: 0.004607745911926031
# 验证集上的指标为:0.0046873693354427814，总噪声为:0.025070490315556526,减少噪声0.020383121445775032
# Epoch 205, Train Loss: 0.004644467961043119
# 验证集上的指标为:0.004756338428705931，总噪声为:0.025070490315556526,减少噪声0.020314151421189308
# Epoch 206, Train Loss: 0.004693245515227318
# 验证集上的指标为:0.00483341608196497，总噪声为:0.025070490315556526,减少噪声0.020237073302268982
# Epoch 207, Train Loss: 0.004438101314008236
# 验证集上的指标为:0.0054968963377177715，总噪声为:0.025070490315556526,减少噪声0.019573593512177467
# Epoch 208, Train Loss: 0.005842667538672686
# 验证集上的指标为:0.004853846505284309，总噪声为:0.025070490315556526,减少噪声0.020216643810272217
# Epoch 209, Train Loss: 0.00403003953397274
# 验证集上的指标为:0.0048631164245307446，总噪声为:0.025070490315556526,减少噪声0.020207373425364494
# Epoch 210, Train Loss: 0.005384873133152723
# 验证集上的指标为:0.0048772371374070644，总噪声为:0.025070490315556526,减少噪声0.020193252712488174
# Epoch 211, Train Loss: 0.004798266105353832
# 验证集上的指标为:0.004793095868080854，总噪声为:0.025070490315556526,减少噪声0.020277393981814384
# Epoch 212, Train Loss: 0.005167074501514435
# 验证集上的指标为:0.005910561885684729，总噪声为:0.025070490315556526,减少噪声0.01915992796421051
# Epoch 213, Train Loss: 0.005230502691119909
# 验证集上的指标为:0.004868887830525637，总噪声为:0.025070490315556526,减少噪声0.020201602950692177
# Epoch 214, Train Loss: 0.0047177826054394245
# 验证集上的指标为:0.004909214563667774，总噪声为:0.025070490315556526,减少噪声0.020161274820566177
# Epoch 215, Train Loss: 0.004198677837848663
# 验证集上的指标为:0.005055221263319254，总噪声为:0.025070490315556526,减少噪声0.02001526951789856
# Epoch 216, Train Loss: 0.004886648617684841
# 验证集上的指标为:0.004967961460351944，总噪声为:0.025070490315556526,减少噪声0.020102528855204582
# Epoch 217, Train Loss: 0.005209564696997404
# 验证集上的指标为:0.004782095551490784，总噪声为:0.025070490315556526,减少噪声0.020288394764065742
# Epoch 218, Train Loss: 0.004696817137300968
# 验证集上的指标为:0.005008753854781389，总噪声为:0.025070490315556526,减少噪声0.020061736926436424
# Epoch 219, Train Loss: 0.005360334645956755
# 验证集上的指标为:0.004748436622321606，总噪声为:0.025070490315556526,减少噪声0.020322054624557495
# Epoch 220, Train Loss: 0.004609259311109781
# 验证集上的指标为:0.005168606992810965，总噪声为:0.025070490315556526,减少噪声0.019901882857084274
# Epoch 221, Train Loss: 0.004473237320780754
# 验证集上的指标为:0.004866073839366436，总噪声为:0.025070490315556526,减少噪声0.020204417407512665
# Epoch 222, Train Loss: 0.005056231748312712
# 验证集上的指标为:0.0048344009555876255，总噪声为:0.025070490315556526,减少噪声0.020236089825630188
# Epoch 223, Train Loss: 0.0037585648242384195
# 验证集上的指标为:0.0047291419468820095，总噪声为:0.025070490315556526,减少噪声0.02034134790301323
# Epoch 224, Train Loss: 0.004594690166413784
# 验证集上的指标为:0.004714060574769974，总噪声为:0.025070490315556526,减少噪声0.020356429740786552
# Epoch 225, Train Loss: 0.00572526641190052
# 验证集上的指标为:0.0050170267932116985，总噪声为:0.025070490315556526,减少噪声0.02005346305668354
# Epoch 226, Train Loss: 0.005413000006228685
# 验证集上的指标为:0.004787524230778217，总噪声为:0.025070490315556526,减少噪声0.020282965153455734
# Epoch 227, Train Loss: 0.005731541197746992
# 验证集上的指标为:0.004924924112856388，总噪声为:0.025070490315556526,减少噪声0.020145565271377563
# Epoch 228, Train Loss: 0.004769275896251202
# 验证集上的指标为:0.0052332463674247265，总噪声为:0.025070490315556526,减少噪声0.019837243482470512
# Epoch 229, Train Loss: 0.00559763191267848
# 验证集上的指标为:0.004992498550564051，总噪声为:0.025070490315556526,减少噪声0.020077992230653763
# Epoch 230, Train Loss: 0.005203372333198786
# 验证集上的指标为:0.005251980386674404，总噪声为:0.025070490315556526,减少噪声0.019818510860204697
# Epoch 231, Train Loss: 0.005350465886294842
# 验证集上的指标为:0.005210304632782936，总噪声为:0.025070490315556526,减少噪声0.01986018568277359
# Epoch 232, Train Loss: 0.005271670408546925
# 验证集上的指标为:0.00489779282361269，总噪声为:0.025070490315556526,减少噪声0.02017269656062126
# Epoch 233, Train Loss: 0.004847320262342691
# 验证集上的指标为:0.004939571022987366，总噪声为:0.025070490315556526,减少噪声0.02013091929256916
# Epoch 234, Train Loss: 0.004796074237674475
# 验证集上的指标为:0.004925222601741552，总噪声为:0.025070490315556526,减少噪声0.020145267248153687
# Epoch 235, Train Loss: 0.005070288199931383
# 验证集上的指标为:0.00484384736046195，总噪声为:0.025070490315556526,减少噪声0.02022664248943329
# Epoch 236, Train Loss: 0.003603554330766201
# 验证集上的指标为:0.004852943122386932，总噪声为:0.025070490315556526,减少噪声0.020217547193169594
# Epoch 237, Train Loss: 0.005466036964207888
# 验证集上的指标为:0.0048179770819842815，总噪声为:0.025070490315556526,减少噪声0.020252512767910957
# Epoch 238, Train Loss: 0.004461724776774645
# 验证集上的指标为:0.004896987695246935，总噪声为:0.025070490315556526,减少噪声0.02017350308597088
# Epoch 239, Train Loss: 0.005033591296523809
# 验证集上的指标为:0.004716717638075352，总噪声为:0.025070490315556526,减少噪声0.0203537717461586
# Epoch 240, Train Loss: 0.0054514454677701
# 验证集上的指标为:0.004689714405685663，总噪声为:0.025070490315556526,减少噪声0.02038077637553215
# Epoch 241, Train Loss: 0.0045120008289813995
# 验证集上的指标为:0.004762198776006699，总噪声为:0.025070490315556526,减少噪声0.020308291539549828
# Epoch 242, Train Loss: 0.004228898789733648
# 验证集上的指标为:0.004648459143936634，总噪声为:0.025070490315556526,减少噪声0.020422030240297318
# Epoch 243, Train Loss: 0.004597964230924845
# 验证集上的指标为:0.004803596530109644，总噪声为:0.025070490315556526,减少噪声0.02026689425110817
# Epoch 244, Train Loss: 0.005259492434561253
# 验证集上的指标为:0.004747900180518627，总噪声为:0.025070490315556526,减少噪声0.020322591066360474
# Epoch 245, Train Loss: 0.004847983364015818
# 验证集上的指标为:0.004927519243210554，总噪声为:0.025070490315556526,减少噪声0.020142970606684685
# Epoch 246, Train Loss: 0.004829645622521639
# 验证集上的指标为:0.004954611416906118，总噪声为:0.025070490315556526,减少噪声0.02011587843298912
# Epoch 247, Train Loss: 0.004511609207838774
# 验证集上的指标为:0.00549547653645277，总噪声为:0.025070490315556526,减少噪声0.01957501471042633
# Epoch 248, Train Loss: 0.00410314928740263
# 验证集上的指标为:0.004652161616832018，总噪声为:0.025070490315556526,减少噪声0.020418329164385796
# Epoch 249, Train Loss: 0.00446409871801734
# 验证集上的指标为:0.004893595818430185，总噪声为:0.025070490315556526,减少噪声0.020176894962787628
# Epoch 250, Train Loss: 0.005220409948378801
# 验证集上的指标为:0.004630125593394041，总噪声为:0.025070490315556526,减少噪声0.020440364256501198
# Epoch 251, Train Loss: 0.0044433302246034145
# 验证集上的指标为:0.005010145716369152，总噪声为:0.025070490315556526,减少噪声0.02006034553050995
# Epoch 252, Train Loss: 0.004723720718175173
# 验证集上的指标为:0.004856449086219072，总噪声为:0.025070490315556526,减少噪声0.02021404169499874
# Epoch 253, Train Loss: 0.005830054637044668
# 验证集上的指标为:0.004672603216022253，总噪声为:0.025070490315556526,减少噪声0.020397886633872986
# Epoch 254, Train Loss: 0.005419802851974964
# 验证集上的指标为:0.004866027273237705，总噪声为:0.025070490315556526,减少噪声0.020204462110996246
# Epoch 255, Train Loss: 0.005491628777235746
# 验证集上的指标为:0.004804539028555155，总噪声为:0.025070490315556526,减少噪声0.02026595175266266
# Epoch 256, Train Loss: 0.00507911155000329
# 验证集上的指标为:0.005094206426292658，总噪声为:0.025070490315556526,减少噪声0.019976284354925156
# Epoch 257, Train Loss: 0.0053107826970517635
# 验证集上的指标为:0.0052649229764938354，总噪声为:0.025070490315556526,减少噪声0.01980556733906269
# Epoch 258, Train Loss: 0.004968059249222279
# 验证集上的指标为:0.005056362133473158，总噪声为:0.025070490315556526,减少噪声0.02001412771642208
# Epoch 259, Train Loss: 0.004071760922670364
# 验证集上的指标为:0.004770343657582998，总噪声为:0.025070490315556526,减少噪声0.02030014619231224
# Epoch 260, Train Loss: 0.004803202114999294
# 验证集上的指标为:0.005180206149816513，总噪声为:0.025070490315556526,减少噪声0.019890284165740013
# Epoch 261, Train Loss: 0.004359529819339514
# 验证集上的指标为:0.004759025294333696，总噪声为:0.025070490315556526,减少噪声0.020311465486884117
# Epoch 262, Train Loss: 0.005393044091761112
# 验证集上的指标为:0.004809150937944651，总噪声为:0.025070490315556526,减少噪声0.020261339843273163
# Epoch 263, Train Loss: 0.004202650394290686
# 验证集上的指标为:0.005154143553227186，总噪声为:0.025070490315556526,减少噪声0.019916346296668053
# Epoch 264, Train Loss: 0.00524265319108963
# 验证集上的指标为:0.005021748133003712，总噪声为:0.025070490315556526,减少噪声0.02004874125123024
# Epoch 265, Train Loss: 0.005516853649169207
# 验证集上的指标为:0.00496644526720047，总噪声为:0.025070490315556526,减少噪声0.020104045048356056
# Epoch 266, Train Loss: 0.003716131206601858
# 验证集上的指标为:0.004849567078053951，总噪声为:0.025070490315556526,减少噪声0.02022092416882515
# Epoch 267, Train Loss: 0.004941422492265701
# 验证集上的指标为:0.004697315860539675，总噪声为:0.025070490315556526,减少噪声0.02037317492067814
# Epoch 268, Train Loss: 0.004978404846042395
# 验证集上的指标为:0.004820674192160368，总噪声为:0.025070490315556526,减少噪声0.02024981565773487
# Epoch 269, Train Loss: 0.004624523222446442
# 验证集上的指标为:0.004887083545327187，总噪声为:0.025070490315556526,减少噪声0.02018340677022934
# Epoch 270, Train Loss: 0.004041638690978289
# 验证集上的指标为:0.004710141569375992，总噪声为:0.025070490315556526,减少噪声0.020360348746180534
# Epoch 271, Train Loss: 0.004885729867964983
# 验证集上的指标为:0.004702500067651272，总噪声为:0.025070490315556526,减少噪声0.02036799117922783
# Epoch 272, Train Loss: 0.004618797916918993
# 验证集上的指标为:0.0048136040568351746，总噪声为:0.025070490315556526,减少噪声0.02025688625872135
# Epoch 273, Train Loss: 0.004471075255423784
# 验证集上的指标为:0.004876208025962114，总噪声为:0.025070490315556526,减少噪声0.0201942827552557
# Epoch 274, Train Loss: 0.00493171252310276
# 验证集上的指标为:0.004775547422468662，总噪声为:0.025070490315556526,减少噪声0.02029494196176529
# Epoch 275, Train Loss: 0.005358117166906595
# 验证集上的指标为:0.004829125478863716，总噪声为:0.025070490315556526,减少噪声0.02024136483669281
# Epoch 276, Train Loss: 0.00427574897184968
# 验证集上的指标为:0.004840995650738478，总噪声为:0.025070490315556526,减少噪声0.02022949419915676
# Epoch 277, Train Loss: 0.00461465073749423
# 验证集上的指标为:0.004702387843281031，总噪声为:0.025070490315556526,减少噪声0.020368102937936783
# Epoch 278, Train Loss: 0.00424488028511405
# 验证集上的指标为:0.0047311559319496155，总噪声为:0.025070490315556526,减少噪声0.02033933438360691
# Epoch 279, Train Loss: 0.004449136555194855
# 验证集上的指标为:0.004691652487963438，总噪声为:0.025070490315556526,减少噪声0.0203788373619318
# Epoch 280, Train Loss: 0.003867783583700657
# 验证集上的指标为:0.004846590105444193，总噪声为:0.025070490315556526,减少噪声0.02022390067577362
# Epoch 281, Train Loss: 0.005109761375933886
# 验证集上的指标为:0.00490148551762104，总噪声为:0.025070490315556526,减少噪声0.020169004797935486
# Epoch 282, Train Loss: 0.004168477840721607
# 验证集上的指标为:0.00468839704990387，总噪声为:0.025070490315556526,减少噪声0.020382093265652657
# Epoch 283, Train Loss: 0.005198553670197725
# 验证集上的指标为:0.004988490138202906，总噪声为:0.025070490315556526,减少噪声0.020082000643014908
# Epoch 284, Train Loss: 0.004995604511350393
# 验证集上的指标为:0.005186030641198158，总噪声为:0.025070490315556526,减少噪声0.019884459674358368
# Epoch 285, Train Loss: 0.004502552095800638
# 验证集上的指标为:0.0046912021934986115，总噪声为:0.025070490315556526,减少噪声0.020379288122057915
# Epoch 286, Train Loss: 0.004220101051032543
# 验证集上的指标为:0.004838310182094574，总噪声为:0.025070490315556526,减少噪声0.020232180133461952
# Epoch 287, Train Loss: 0.004110640846192837
# 验证集上的指标为:0.00464881444349885，总噪声为:0.025070490315556526,减少噪声0.020421676337718964
# Epoch 288, Train Loss: 0.005804140120744705
# 验证集上的指标为:0.004654928110539913，总噪声为:0.025070490315556526,减少噪声0.020415563136339188
# Epoch 289, Train Loss: 0.005302661098539829
# 验证集上的指标为:0.004966265521943569，总噪声为:0.025070490315556526,减少噪声0.02010422572493553
# Epoch 290, Train Loss: 0.00496572395786643
# 验证集上的指标为:0.005065394565463066，总噪声为:0.025070490315556526,减少噪声0.02000509575009346
# Epoch 291, Train Loss: 0.004766610451042652
# 验证集上的指标为:0.005144051741808653，总噪声为:0.025070490315556526,减少噪声0.019926438108086586
# Epoch 292, Train Loss: 0.005220550112426281
# 验证集上的指标为:0.004650681279599667，总噪声为:0.025070490315556526,减少噪声0.020419809967279434
# Epoch 293, Train Loss: 0.004391293041408062
# 验证集上的指标为:0.004782327450811863，总噪声为:0.025070490315556526,减少噪声0.02028816193342209
# Epoch 294, Train Loss: 0.0043197013437747955
# 验证集上的指标为:0.004765988327562809，总噪声为:0.025070490315556526,减少噪声0.020304501056671143
# Epoch 295, Train Loss: 0.004072493873536587
# 验证集上的指标为:0.004878989886492491，总噪声为:0.025070490315556526,减少噪声0.020191499963402748
# Epoch 296, Train Loss: 0.005828536581248045
# 验证集上的指标为:0.004710730165243149，总噪声为:0.025070490315556526,减少噪声0.020359760150313377
# Epoch 297, Train Loss: 0.005800643935799599
# 验证集上的指标为:0.004927816800773144，总噪声为:0.025070490315556526,减少噪声0.020142674446105957
# Epoch 298, Train Loss: 0.00525360694155097
# 验证集上的指标为:0.004635769408196211，总噪声为:0.025070490315556526,减少噪声0.020434720441699028
# Epoch 299, Train Loss: 0.004761195741593838
# 验证集上的指标为:0.004654312040656805，总噪声为:0.025070490315556526,减少噪声0.020416177809238434
# Epoch 300, Train Loss: 0.004009234718978405
# 验证集上的指标为:0.004804546944797039，总噪声为:0.025070490315556526,减少噪声0.020265944302082062
# Epoch 301, Train Loss: 0.005649910774081945
# 验证集上的指标为:0.004818899091333151，总噪声为:0.025070490315556526,减少噪声0.020251590758562088
# Epoch 302, Train Loss: 0.0052317604422569275
# 验证集上的指标为:0.0049414485692977905，总噪声为:0.025070490315556526,减少噪声0.020129041746258736
# Epoch 303, Train Loss: 0.0055167111568152905
# 验证集上的指标为:0.004888069350272417，总噪声为:0.025070490315556526,减少噪声0.020182421430945396
# Epoch 304, Train Loss: 0.00458492198958993
# 验证集上的指标为:0.004875056445598602，总噪声为:0.025070490315556526,减少噪声0.020195433869957924
# Epoch 305, Train Loss: 0.005407494027167559
# 验证集上的指标为:0.004992186091840267，总噪声为:0.025070490315556526,减少噪声0.020078305155038834
# Epoch 306, Train Loss: 0.003941957373172045
# 验证集上的指标为:0.0051894295029342175，总噪声为:0.025070490315556526,减少噪声0.01988106034696102
# Epoch 307, Train Loss: 0.0040809474885463715
# 验证集上的指标为:0.004695850890129805，总噪声为:0.025070490315556526,减少噪声0.020374638959765434
# Epoch 308, Train Loss: 0.004417033400386572
# 验证集上的指标为:0.004695735406130552，总噪声为:0.025070490315556526,减少噪声0.020374754443764687
# Epoch 309, Train Loss: 0.005129327066242695
# 验证集上的指标为:0.0047822799533605576，总噪声为:0.025070490315556526,减少噪声0.02028821036219597
# Epoch 310, Train Loss: 0.005179807543754578
# 验证集上的指标为:0.004651271738111973，总噪声为:0.025070490315556526,减少噪声0.02041921764612198
# Epoch 311, Train Loss: 0.005261569283902645
# 验证集上的指标为:0.004823281895369291，总噪声为:0.025070490315556526,减少噪声0.020247207954525948
# Epoch 312, Train Loss: 0.004301856271922588
# 验证集上的指标为:0.004752660635858774，总噪声为:0.025070490315556526,减少噪声0.02031783014535904
# Epoch 313, Train Loss: 0.0038538051303476095
# 验证集上的指标为:0.0046964045614004135，总噪声为:0.025070490315556526,减少噪声0.020374085754156113
# Epoch 314, Train Loss: 0.005802094470709562
# 验证集上的指标为:0.004746849648654461，总噪声为:0.025070490315556526,减少噪声0.02032364159822464
# Epoch 315, Train Loss: 0.004907991271466017
# 验证集上的指标为:0.00489088473841548，总噪声为:0.025070490315556526,减少噪声0.02017960511147976
# Epoch 316, Train Loss: 0.005126032046973705
# 验证集上的指标为:0.0047853440046310425，总噪声为:0.025070490315556526,减少噪声0.020285146310925484
# Epoch 317, Train Loss: 0.006954655051231384
# 验证集上的指标为:0.004799875430762768，总噪声为:0.025070490315556526,减少噪声0.020270615816116333
# Epoch 318, Train Loss: 0.004161915276199579
# 验证集上的指标为:0.005611430387943983，总噪声为:0.025070490315556526,减少噪声0.019459059461951256
# Epoch 319, Train Loss: 0.004586049821227789
# 验证集上的指标为:0.004707195796072483，总噪声为:0.025070490315556526,减少噪声0.02036329358816147
# Epoch 320, Train Loss: 0.004679569974541664
# 验证集上的指标为:0.0047582779079675674，总噪声为:0.025070490315556526,减少噪声0.02031221240758896
# Epoch 321, Train Loss: 0.004975637886673212
# 验证集上的指标为:0.004809886682778597，总噪声为:0.025070490315556526,减少噪声0.020260604098439217
# Epoch 322, Train Loss: 0.004393800161778927
# 验证集上的指标为:0.005861347541213036，总噪声为:0.025070490315556526,减少噪声0.01920914277434349
# Epoch 323, Train Loss: 0.005492967087775469
# 验证集上的指标为:0.004739193711429834，总噪声为:0.025070490315556526,减少噪声0.02033129706978798
# Epoch 324, Train Loss: 0.005029488820582628
# 验证集上的指标为:0.005179604049772024，总噪声为:0.025070490315556526,减少噪声0.019890885800123215
# Epoch 325, Train Loss: 0.004850440192967653
# 验证集上的指标为:0.004850435070693493，总噪声为:0.025070490315556526,减少噪声0.020220056176185608
# Epoch 326, Train Loss: 0.005419111344963312
# 验证集上的指标为:0.004763470031321049，总噪声为:0.025070490315556526,减少噪声0.020307019352912903
# Epoch 327, Train Loss: 0.004807302262634039
# 验证集上的指标为:0.004679535981267691，总噪声为:0.025070490315556526,减少噪声0.020390953868627548
# Epoch 328, Train Loss: 0.004843446891754866
# 验证集上的指标为:0.005086746998131275，总噪声为:0.025070490315556526,减少噪声0.019983742386102676
# Epoch 329, Train Loss: 0.004443618468940258
# 验证集上的指标为:0.004717581439763308，总噪声为:0.025070490315556526,减少噪声0.020352909341454506
# Epoch 330, Train Loss: 0.004911026917397976
# 验证集上的指标为:0.004697376862168312，总噪声为:0.025070490315556526,减少噪声0.020373113453388214
# Epoch 331, Train Loss: 0.004521756898611784
# 验证集上的指标为:0.0047839051112532616，总噪声为:0.025070490315556526,减少噪声0.02028658613562584
# Epoch 332, Train Loss: 0.004308438394218683
# 验证集上的指标为:0.004887512885034084，总噪声为:0.025070490315556526,减少噪声0.020182978361845016
# Epoch 333, Train Loss: 0.0041272444650530815
# 验证集上的指标为:0.005080052651464939，总噪声为:0.025070490315556526,减少噪声0.019990436732769012
# Epoch 334, Train Loss: 0.00628808094188571
# 验证集上的指标为:0.004778501112014055，总噪声为:0.025070490315556526,减少噪声0.020291989669203758
# Epoch 335, Train Loss: 0.00405489606782794
# 验证集上的指标为:0.004788343328982592，总噪声为:0.025070490315556526,减少噪声0.020282147452235222
# Epoch 336, Train Loss: 0.005564010702073574
# 验证集上的指标为:0.005085717886686325，总噪声为:0.025070490315556526,减少噪声0.0199847724288702
# Epoch 337, Train Loss: 0.004513945430517197
# 验证集上的指标为:0.004815907683223486，总噪声为:0.025070490315556526,减少噪声0.020254582166671753
# Epoch 338, Train Loss: 0.004682192578911781
# 验证集上的指标为:0.004713607020676136，总噪声为:0.025070490315556526,减少噪声0.020356882363557816
# Epoch 339, Train Loss: 0.005000014323741198
# 验证集上的指标为:0.004891922697424889，总噪声为:0.025070490315556526,减少噪声0.020178567618131638
# Epoch 340, Train Loss: 0.004252908285707235
# 验证集上的指标为:0.005067707039415836，总噪声为:0.025070490315556526,减少噪声0.020002782344818115
# Epoch 341, Train Loss: 0.005395378917455673
# 验证集上的指标为:0.004800228867679834，总噪声为:0.025070490315556526,减少噪声0.02027026191353798
# Epoch 342, Train Loss: 0.004512485582381487
# 验证集上的指标为:0.004655247088521719，总噪声为:0.025070490315556526,减少噪声0.02041524276137352
# Epoch 343, Train Loss: 0.0041650342755019665
# 验证集上的指标为:0.004649334587156773，总噪声为:0.025070490315556526,减少噪声0.02042115479707718
# Epoch 344, Train Loss: 0.004079968202859163
# 验证集上的指标为:0.004650856833904982，总噪声为:0.025070490315556526,减少噪声0.020419633015990257
# Epoch 345, Train Loss: 0.004714518319815397
# 验证集上的指标为:0.004774205386638641，总噪声为:0.025070490315556526,减少噪声0.020296284928917885
# Epoch 346, Train Loss: 0.004905479960143566
# 验证集上的指标为:0.004972137976437807，总噪声为:0.025070490315556526,减少噪声0.020098352804780006
# Epoch 347, Train Loss: 0.0046759978868067265
# 验证集上的指标为:0.004681623540818691，总噪声为:0.025070490315556526,减少噪声0.02038886770606041
# Epoch 348, Train Loss: 0.004587447736412287
# 验证集上的指标为:0.004839604254812002，总噪声为:0.025070490315556526,减少噪声0.020230885595083237
# Epoch 349, Train Loss: 0.004126518499106169
# 验证集上的指标为:0.004730319604277611，总噪声为:0.025070490315556526,减少噪声0.020340170711278915
# Epoch 350, Train Loss: 0.004982240963727236
# 验证集上的指标为:0.004633130971342325，总噪声为:0.025070490315556526,减少噪声0.02043735980987549
# Epoch 351, Train Loss: 0.0035812894348055124
# 验证集上的指标为:0.004700258374214172，总噪声为:0.025070490315556526,减少噪声0.020370231941342354
# Epoch 352, Train Loss: 0.005769715644419193
# 验证集上的指标为:0.004702829290181398，总噪声为:0.025070490315556526,减少噪声0.020367661491036415
# Epoch 353, Train Loss: 0.0040418109856545925
# 验证集上的指标为:0.004837478045374155，总噪声为:0.025070490315556526,减少噪声0.02023301273584366
# Epoch 354, Train Loss: 0.005377443041652441
# 验证集上的指标为:0.004923935513943434，总噪声为:0.025070490315556526,减少噪声0.020146554335951805
# Epoch 355, Train Loss: 0.005020422395318747
# 验证集上的指标为:0.004957877565175295，总噪声为:0.025070490315556526,减少噪声0.02011261321604252
# Epoch 356, Train Loss: 0.004535916727036238
# 验证集上的指标为:0.0047288271598517895，总噪声为:0.025070490315556526,减少噪声0.02034166269004345
# Epoch 357, Train Loss: 0.004825343377888203
# 验证集上的指标为:0.005202408414334059，总噪声为:0.025070490315556526,减少噪声0.01986808143556118
# Epoch 358, Train Loss: 0.0044397818855941296
# 验证集上的指标为:0.004908091854304075，总噪声为:0.025070490315556526,减少噪声0.020162397995591164
# Epoch 359, Train Loss: 0.004945221822708845
# 验证集上的指标为:0.005041518714278936，总噪声为:0.025070490315556526,减少噪声0.020028971135616302
# Epoch 360, Train Loss: 0.0041976068168878555
# 验证集上的指标为:0.00484422966837883，总噪声为:0.025070490315556526,减少噪声0.020226260647177696
# Epoch 361, Train Loss: 0.005187327973544598
# 验证集上的指标为:0.0048786336556077，总噪声为:0.025070490315556526,减少噪声0.02019185572862625
# Epoch 362, Train Loss: 0.0044440701603889465
# 验证集上的指标为:0.004686763044446707，总噪声为:0.025070490315556526,减少噪声0.020383726805448532
# Epoch 363, Train Loss: 0.005026643630117178
# 验证集上的指标为:0.005592646077275276，总噪声为:0.025070490315556526,减少噪声0.01947784423828125
# Epoch 364, Train Loss: 0.004570720251649618
# 验证集上的指标为:0.004995417781174183，总噪声为:0.025070490315556526,减少噪声0.02007507160305977
# Epoch 365, Train Loss: 0.003590024309232831
# 验证集上的指标为:0.004728285595774651，总噪声为:0.025070490315556526,减少噪声0.020342204719781876
# Epoch 366, Train Loss: 0.004970211535692215
# 验证集上的指标为:0.0046638804487884045，总噪声为:0.025070490315556526,减少噪声0.020406609401106834
# Epoch 367, Train Loss: 0.004871584940701723
# 验证集上的指标为:0.004629843402653933，总噪声为:0.025070490315556526,减少噪声0.02044064737856388
# Epoch 368, Train Loss: 0.004018167499452829
# 验证集上的指标为:0.005297739990055561，总噪声为:0.025070490315556526,减少噪声0.01977274939417839
# Epoch 369, Train Loss: 0.0051668984815478325
# 验证集上的指标为:0.004830016754567623，总噪声为:0.025070490315556526,减少噪声0.020240474492311478
# Epoch 370, Train Loss: 0.0047541419044137
# 验证集上的指标为:0.004690872970968485，总噪声为:0.025070490315556526,减少噪声0.02037961781024933
# Epoch 371, Train Loss: 0.004152278415858746
# 验证集上的指标为:0.0051704584620893，总噪声为:0.025070490315556526,减少噪声0.01990003138780594
# Epoch 372, Train Loss: 0.005191810894757509
# 验证集上的指标为:0.004698590841144323，总噪声为:0.025070490315556526,减少噪声0.020371899008750916
# Epoch 373, Train Loss: 0.004322011489421129
# 验证集上的指标为:0.00483862217515707，总噪声为:0.025070490315556526,减少噪声0.02023186907172203
# Epoch 374, Train Loss: 0.005034822039306164
# 验证集上的指标为:0.004619337618350983，总噪声为:0.025070490315556526,减少噪声0.020451152697205544
# Epoch 375, Train Loss: 0.0059519074857234955
# 验证集上的指标为:0.004732039757072926，总噪声为:0.025070490315556526,减少噪声0.020338449627161026
# Epoch 376, Train Loss: 0.00393329793587327
# 验证集上的指标为:0.004645962733775377，总噪声为:0.025070490315556526,减少噪声0.020424528047442436
# Epoch 377, Train Loss: 0.004435454495251179
# 验证集上的指标为:0.0048194038681685925，总噪声为:0.025070490315556526,减少噪声0.020251085981726646
# Epoch 378, Train Loss: 0.005267382599413395
# 验证集上的指标为:0.0049241757951676846，总噪声为:0.025070490315556526,减少噪声0.020146314054727554
# Epoch 379, Train Loss: 0.004611543845385313
# 验证集上的指标为:0.004708640277385712，总噪声为:0.025070490315556526,减少噪声0.020361850038170815
# Epoch 380, Train Loss: 0.005052059423178434
# 验证集上的指标为:0.005043513141572475，总噪声为:0.025070490315556526,减少噪声0.020026978105306625
# Epoch 381, Train Loss: 0.004258702043443918
# 验证集上的指标为:0.004715932533144951，总噪声为:0.025070490315556526,减少噪声0.020354557782411575
# Epoch 382, Train Loss: 0.004403655417263508
# 验证集上的指标为:0.005606379359960556，总噪声为:0.025070490315556526,减少噪声0.01946411095559597
# Epoch 383, Train Loss: 0.005205181427299976
# 验证集上的指标为:0.0053944578394293785，总噪声为:0.025070490315556526,减少噪声0.019676033407449722
# Epoch 384, Train Loss: 0.004899625666439533
# 验证集上的指标为:0.004647582303732634，总噪声为:0.025070490315556526,减少噪声0.020422907546162605
# Epoch 385, Train Loss: 0.00455447705462575
# 验证集上的指标为:0.0048075830563902855，总噪声为:0.025070490315556526,减少噪声0.020262908190488815
# Epoch 386, Train Loss: 0.004407182801514864
# ...
# Epoch 473, Train Loss: 0.004840176086872816
# 验证集上的指标为:0.0048691993579268456，总噪声为:0.025070490315556526,减少噪声0.020201291888952255
# Epoch 474, Train Loss: 0.005961996968835592
# 验证集上的指标为:0.004799603018909693，总噪声为:0.025070490315556526,减少噪声0.02027088776230812
# Epoch 475, Train Loss: 0.004875521641224623
# 验证集上的指标为:0.005065103992819786，总噪声为:0.025070490315556526,减少噪声0.02000538632273674
# Epoch 476, Train Loss: 0.003979420755058527
# 验证集上的指标为:0.004764636512845755，总噪声为:0.025070490315556526,减少噪声0.020305853337049484
# Epoch 477, Train Loss: 0.0049414257518947124
# 验证集上的指标为:0.004684192128479481，总噪声为:0.025070490315556526,减少噪声0.02038629725575447
# Epoch 478, Train Loss: 0.00494743138551712
# 验证集上的指标为:0.005091285333037376，总噪声为:0.025070490315556526,减少噪声0.01997920498251915
# Epoch 479, Train Loss: 0.005478222854435444
# 验证集上的指标为:0.005121556576341391，总噪声为:0.025070490315556526,减少噪声0.01994893327355385
# Epoch 480, Train Loss: 0.006463635712862015
# 验证集上的指标为:0.00466287462040782，总噪声为:0.025070490315556526,减少噪声0.02040761522948742
# Epoch 481, Train Loss: 0.00436252448707819
# 验证集上的指标为:0.004660759121179581，总噪声为:0.025070490315556526,减少噪声0.020409731194376945
# Epoch 482, Train Loss: 0.005204356741160154
# 验证集上的指标为:0.0048990435898303986，总噪声为:0.025070490315556526,减少噪声0.020171446725726128
# Epoch 483, Train Loss: 0.0043405150063335896
# 验证集上的指标为:0.004720483906567097，总噪声为:0.025070490315556526,减少噪声0.020350005477666855
# Epoch 484, Train Loss: 0.004407872911542654
# 验证集上的指标为:0.004677900578826666，总噪声为:0.025070490315556526,减少噪声0.020392589271068573
# Epoch 485, Train Loss: 0.004186396487057209
# 验证集上的指标为:0.005082396790385246，总噪声为:0.025070490315556526,减少噪声0.01998809352517128
# Epoch 486, Train Loss: 0.004790018312633038
# 验证集上的指标为:0.004911405965685844，总噪声为:0.025070490315556526,减少噪声0.020159084349870682
# Epoch 487, Train Loss: 0.004255970474332571
# 验证集上的指标为:0.0052412403747439384，总噪声为:0.025070490315556526,减少噪声0.019829250872135162
# Epoch 488, Train Loss: 0.005239976570010185
# 验证集上的指标为:0.004874680191278458，总噪声为:0.025070490315556526,减少噪声0.02019581012427807
# Epoch 489, Train Loss: 0.004376232158392668
# 验证集上的指标为:0.004701552912592888，总噪声为:0.025070490315556526,减少噪声0.02036893740296364
# Epoch 490, Train Loss: 0.004741727374494076
# 验证集上的指标为:0.004830243065953255，总噪声为:0.025070490315556526,减少噪声0.02024024724960327
# Epoch 491, Train Loss: 0.004056344740092754
# 验证集上的指标为:0.004642410669475794，总噪声为:0.025070490315556526,减少噪声0.02042808011174202
# Epoch 492, Train Loss: 0.005270281806588173
# 验证集上的指标为:0.0046599977649748325，总噪声为:0.025070490315556526,减少噪声0.02041049301624298
# Epoch 493, Train Loss: 0.004038869868963957
# 验证集上的指标为:0.004650816321372986，总噪声为:0.025070490315556526,减少噪声0.02041967399418354
# Epoch 494, Train Loss: 0.004719761200249195
# 验证集上的指标为:0.0048011173494160175，总噪声为:0.025070490315556526,减少噪声0.020269373431801796
# Epoch 495, Train Loss: 0.004007282201200724
# 验证集上的指标为:0.004925548564642668，总噪声为:0.025070490315556526,减少噪声0.02014494128525257
# Epoch 496, Train Loss: 0.004703389015048742
# 验证集上的指标为:0.00480716023594141，总噪声为:0.025070490315556526,减少噪声0.02026332914829254
# Epoch 497, Train Loss: 0.004959587473422289
# 验证集上的指标为:0.004788569174706936，总噪声为:0.025070490315556526,减少噪声0.020281922072172165
# Epoch 498, Train Loss: 0.004159501288086176
# 验证集上的指标为:0.004930123686790466，总噪声为:0.025070490315556526,减少噪声0.02014036662876606
# Epoch 499, Train Loss: 0.004400149919092655
# 验证集上的指标为:0.0047062155790627，总噪声为:0.025070490315556526,减少噪声0.020364275202155113
# Epoch 500, Train Loss: 0.0049296095967292786
# 验证集上的指标为:0.004859396256506443，总噪声为:0.025070490315556526,减少噪声0.02021109312772751
# Epoch 501, Train Loss: 0.004406174179166555
# 验证集上的指标为:0.004735688213258982，总噪声为:0.025070490315556526,减少噪声0.020334802567958832
# Epoch 502, Train Loss: 0.004714062437415123
# 验证集上的指标为:0.004880434833467007，总噪声为:0.025070490315556526,减少噪声0.020190056413412094
# Epoch 503, Train Loss: 0.004978669807314873
# 验证集上的指标为:0.00476752920076251，总噪声为:0.025070490315556526,减少噪声0.02030296064913273
# Epoch 504, Train Loss: 0.004413117654621601
# 验证集上的指标为:0.004757355898618698，总噪声为:0.025070490315556526,减少噪声0.020313134416937828
# Epoch 505, Train Loss: 0.004202869720757008
# 验证集上的指标为:0.0047091227024793625，总噪声为:0.025070490315556526,减少噪声0.020361367613077164
# Epoch 506, Train Loss: 0.004813356790691614
# 验证集上的指标为:0.004776175133883953，总噪声为:0.025070490315556526,减少噪声0.020294316112995148
# Epoch 507, Train Loss: 0.004738510586321354
# 验证集上的指标为:0.0047041671350598335，总噪声为:0.025070490315556526,减少噪声0.020366322249174118
# Epoch 508, Train Loss: 0.004644609056413174
# 验证集上的指标为:0.005069757346063852，总噪声为:0.025070490315556526,减少噪声0.02000073343515396
# Epoch 509, Train Loss: 0.0048647113144397736
# 验证集上的指标为:0.004766420461237431，总噪声为:0.025070490315556526,减少噪声0.02030406892299652
# Epoch 510, Train Loss: 0.0040732803754508495
# 验证集上的指标为:0.004719299729913473，总噪声为:0.025070490315556526,减少噪声0.020351190119981766
# Epoch 511, Train Loss: 0.00471312552690506
# 验证集上的指标为:0.00511283241212368，总噪声为:0.025070490315556526,减少噪声0.019957657903432846
# Epoch 512, Train Loss: 0.003978831227868795
# 验证集上的指标为:0.004765789490193129，总噪声为:0.025070490315556526,减少噪声0.02030470035970211
# Epoch 513, Train Loss: 0.0052311476320028305
# 验证集上的指标为:0.004692309070378542，总噪声为:0.025070490315556526,减少噪声0.02037818171083927
# Epoch 514, Train Loss: 0.0049642538651824
# 验证集上的指标为:0.004732433240860701，总噪声为:0.025070490315556526,减少噪声0.02033805660903454
# Epoch 515, Train Loss: 0.00438346154987812
# 验证集上的指标为:0.004888924770057201，总噪声为:0.025070490315556526,减少噪声0.0201815664768219
# Epoch 516, Train Loss: 0.00462588295340538
# 验证集上的指标为:0.004764933604747057，总噪声为:0.025070490315556526,减少噪声0.020305557176470757
# Epoch 517, Train Loss: 0.004358530044555664
# 验证集上的指标为:0.004777199123054743，总噪声为:0.025070490315556526,减少噪声0.02029329165816307
# Epoch 518, Train Loss: 0.005120328161865473
# 验证集上的指标为:0.004755711182951927，总噪声为:0.025070490315556526,减少噪声0.0203147791326046
# Epoch 519, Train Loss: 0.005328921601176262
# 验证集上的指标为:0.0048633175902068615，总噪声为:0.025070490315556526,减少噪声0.020207172259688377
# Epoch 520, Train Loss: 0.003939944785088301
# 验证集上的指标为:0.00479624979197979，总噪声为:0.025070490315556526,减少噪声0.020274240523576736
# Epoch 521, Train Loss: 0.004506796132773161
# 验证集上的指标为:0.004856322892010212，总噪声为:0.025070490315556526,减少噪声0.02021416649222374
# Epoch 522, Train Loss: 0.004494418390095234
# 验证集上的指标为:0.005004932172596455，总噪声为:0.025070490315556526,减少噪声0.020065557211637497
# Epoch 523, Train Loss: 0.0047969757579267025
# 验证集上的指标为:0.00470060994848609，总噪声为:0.025070490315556526,减少噪声0.02036987990140915
# Epoch 524, Train Loss: 0.004546002950519323
# 验证集上的指标为:0.0049607339315116405，总噪声为:0.025070490315556526,减少噪声0.0201097559183836
# Epoch 525, Train Loss: 0.004707048647105694
# 验证集上的指标为:0.00466491375118494，总噪声为:0.025070490315556526,减少噪声0.02040557563304901
# Epoch 526, Train Loss: 0.004002708476036787
# 验证集上的指标为:0.004711919464170933，总噪声为:0.025070490315556526,减少噪声0.02035856992006302
# Epoch 527, Train Loss: 0.004156621638685465
# 验证集上的指标为:0.004857493564486504，总噪声为:0.025070490315556526,减少噪声0.020212996751070023
# Epoch 528, Train Loss: 0.004291599616408348
# 验证集上的指标为:0.004694622941315174，总噪声为:0.025070490315556526,减少噪声0.020375866442918777
# Epoch 529, Train Loss: 0.0038187778554856777
# 验证集上的指标为:0.0046431818045675755，总噪声为:0.025070490315556526,减少噪声0.020427308976650238
# Epoch 530, Train Loss: 0.005350523162633181
# 验证集上的指标为:0.005197328049689531，总噪声为:0.025070490315556526,减少噪声0.019873162731528282
# Epoch 531, Train Loss: 0.00491731520742178
# 验证集上的指标为:0.004647679161280394，总噪声为:0.025070490315556526,减少噪声0.020422810688614845
# Epoch 532, Train Loss: 0.004960090387612581
# 验证集上的指标为:0.004934432916343212，总噪声为:0.025070490315556526,减少噪声0.02013605833053589
# Epoch 533, Train Loss: 0.004083289764821529
# 验证集上的指标为:0.004711083602160215，总噪声为:0.025070490315556526,减少噪声0.020359406247735023
# Epoch 534, Train Loss: 0.004608407616615295
# 验证集上的指标为:0.004745136015117168，总噪声为:0.025070490315556526,减少噪声0.020325355231761932
# Epoch 535, Train Loss: 0.0048167165368795395
# 验证集上的指标为:0.004824039060622454，总噪声为:0.025070490315556526,减少噪声0.02024645172059536
# Epoch 536, Train Loss: 0.0046971580013632774
# 验证集上的指标为:0.004735908471047878，总噪声为:0.025070490315556526,减少噪声0.020334582775831223
# Epoch 537, Train Loss: 0.004582773428410292
# 验证集上的指标为:0.004909034818410873，总噪声为:0.025070490315556526,减少噪声0.020161455497145653
# Epoch 538, Train Loss: 0.005230678245425224
# 验证集上的指标为:0.004713902715593576，总噪声为:0.025070490315556526,减少噪声0.020356588065624237
# Epoch 539, Train Loss: 0.004276798572391272
# 验证集上的指标为:0.004765684250742197，总噪声为:0.025070490315556526,减少噪声0.020304806530475616
# Epoch 540, Train Loss: 0.005170346237719059
# 验证集上的指标为:0.004856921266764402，总噪声为:0.025070490315556526,减少噪声0.020213568583130836
# Epoch 541, Train Loss: 0.004837061744183302
# 验证集上的指标为:0.00507299555465579，总噪声为:0.025070490315556526,减少噪声0.01999749429523945
# Epoch 542, Train Loss: 0.005169494077563286
# 验证集上的指标为:0.004791158717125654，总噪声为:0.025070490315556526,减少噪声0.020279331132769585
# Epoch 543, Train Loss: 0.004750481341034174
# 验证集上的指标为:0.004724496975541115，总噪声为:0.025070490315556526,减少噪声0.02034599334001541
# Epoch 544, Train Loss: 0.004327868111431599
# 验证集上的指标为:0.0051360283978283405，总噪声为:0.025070490315556526,减少噪声0.019934462383389473
# Epoch 545, Train Loss: 0.005112875252962112
# 验证集上的指标为:0.004703077487647533，总噪声为:0.025070490315556526,减少噪声0.020367413759231567
# Epoch 546, Train Loss: 0.004547063261270523
# 验证集上的指标为:0.004699915647506714，总噪声为:0.025070490315556526,减少噪声0.020370574668049812
# Epoch 547, Train Loss: 0.004754329565912485
# 验证集上的指标为:0.004841601010411978，总噪声为:0.025070490315556526,减少噪声0.02022888883948326
# Epoch 548, Train Loss: 0.005233828444033861
# 验证集上的指标为:0.004812173545360565，总噪声为:0.025070490315556526,减少噪声0.02025831677019596
# Epoch 549, Train Loss: 0.004454770125448704
# 验证集上的指标为:0.004871699493378401，总噪声为:0.025070490315556526,减少噪声0.020198790356516838
# Epoch 550, Train Loss: 0.004381523467600346
# 验证集上的指标为:0.004967906046658754，总噪声为:0.025070490315556526,减少噪声0.02010258473455906
# Epoch 551, Train Loss: 0.004177199676632881
# 验证集上的指标为:0.004683264531195164，总噪声为:0.025070490315556526,减少噪声0.020387224853038788
# Epoch 552, Train Loss: 0.004974011331796646
# 验证集上的指标为:0.004858020227402449，总噪声为:0.025070490315556526,减少噪声0.02021246962249279
# Epoch 553, Train Loss: 0.0046835304237902164
# 验证集上的指标为:0.004676446318626404，总噪声为:0.025070490315556526,减少噪声0.020394043996930122
# Epoch 554, Train Loss: 0.004687897395342588
# 验证集上的指标为:0.004672326613217592，总噪声为:0.025070490315556526,减少噪声0.02039816416800022
# Epoch 555, Train Loss: 0.004255978390574455
# 验证集上的指标为:0.004743602126836777，总噪声为:0.025070490315556526,减少噪声0.02032688818871975
# Epoch 556, Train Loss: 0.005232247523963451
# 验证集上的指标为:0.0047250958159565926，总噪声为:0.025070490315556526,减少噪声0.02034539356827736
# Epoch 557, Train Loss: 0.004062129184603691
# 验证集上的指标为:0.004907567985355854，总噪声为:0.025070490315556526,减少噪声0.020162921398878098
# Epoch 558, Train Loss: 0.004144025966525078
# 验证集上的指标为:0.004707673564553261，总噪声为:0.025070490315556526,减少噪声0.020362816751003265
# Epoch 559, Train Loss: 0.004646565765142441
# 验证集上的指标为:0.005241263657808304，总噪声为:0.025070490315556526,减少噪声0.019829226657748222
# Epoch 560, Train Loss: 0.004255111329257488
# 验证集上的指标为:0.005093779880553484，总噪声为:0.025070490315556526,减少噪声0.01997671090066433
# Epoch 561, Train Loss: 0.004500710405409336
# 验证集上的指标为:0.004931285046041012，总噪声为:0.025070490315556526,减少噪声0.02013920620083809
# Epoch 562, Train Loss: 0.004440614953637123
# 验证集上的指标为:0.005019427742809057，总噪声为:0.025070490315556526,减少噪声0.02005106210708618
# Epoch 563, Train Loss: 0.0046505494974553585
# 验证集上的指标为:0.0047706421464681625，总噪声为:0.025070490315556526,减少噪声0.020299848169088364
# Epoch 564, Train Loss: 0.004964102059602737
# 验证集上的指标为:0.004613940604031086，总噪声为:0.025070490315556526,减少噪声0.020456548780202866
# Epoch 565, Train Loss: 0.005258563440293074
# 验证集上的指标为:0.00481454050168395，总噪声为:0.025070490315556526,减少噪声0.02025594934821129
# Epoch 566, Train Loss: 0.005861424840986729
# 验证集上的指标为:0.004740628879517317，总噪声为:0.025070490315556526,减少噪声0.020329860970377922
# Epoch 567, Train Loss: 0.0056794448755681515
# 验证集上的指标为:0.004739927127957344，总噪声为:0.025070490315556526,减少噪声0.020330563187599182
# Epoch 568, Train Loss: 0.004668888635933399
# 验证集上的指标为:0.004735667258501053，总噪声为:0.025070490315556526,减少噪声0.020334823057055473
# Epoch 569, Train Loss: 0.00512089766561985
# 验证集上的指标为:0.004745020065456629，总噪声为:0.025070490315556526,减少噪声0.020325470715761185
# Epoch 570, Train Loss: 0.003747574519366026
# 验证集上的指标为:0.004917697049677372，总噪声为:0.025070490315556526,减少噪声0.02015279233455658
# Epoch 571, Train Loss: 0.004843376111239195
# 验证集上的指标为:0.00487765995785594，总噪声为:0.025070490315556526,减少噪声0.0201928298920393
# Epoch 572, Train Loss: 0.005726140458136797
# 验证集上的指标为:0.004664013162255287，总噪声为:0.025070490315556526,减少噪声0.02040647715330124
# Epoch 573, Train Loss: 0.003964260686188936
# 验证集上的指标为:0.0046609435230493546，总噪声为:0.025070490315556526,减少噪声0.02040954679250717
# Epoch 574, Train Loss: 0.004672730807214975
# 验证集上的指标为:0.004624636843800545，总噪声为:0.025070490315556526,减少噪声0.02044585347175598
# Epoch 575, Train Loss: 0.004251014906913042
# 验证集上的指标为:0.004755955655127764，总噪声为:0.025070490315556526,减少噪声0.02031453512609005
# Epoch 576, Train Loss: 0.00453181192278862
# 验证集上的指标为:0.004795219283550978，总噪声为:0.025070490315556526,减少噪声0.02027527056634426
# Epoch 577, Train Loss: 0.005635594483464956
# 验证集上的指标为:0.004746028687804937，总噪声为:0.025070490315556526,减少噪声0.0203244611620903
# Epoch 578, Train Loss: 0.004068663809448481
# 验证集上的指标为:0.005355640314519405，总噪声为:0.025070490315556526,减少噪声0.019714850932359695
# Epoch 579, Train Loss: 0.004741845186799765
# 验证集上的指标为:0.004765055142343044，总噪声为:0.025070490315556526,减少噪声0.020305436104536057
# Epoch 580, Train Loss: 0.004542582668364048
# 验证集上的指标为:0.004707955755293369，总噪声为:0.025070490315556526,减少噪声0.020362533628940582
# Epoch 581, Train Loss: 0.0045851003378629684
# 验证集上的指标为:0.004617925267666578，总噪声为:0.025070490315556526,减少噪声0.02045256458222866
# Epoch 582, Train Loss: 0.004822027403861284
# 验证集上的指标为:0.004691357724368572，总噪声为:0.025070490315556526,减少噪声0.02037913352251053
# Epoch 583, Train Loss: 0.004367928020656109
# 验证集上的指标为:0.004723952617496252，总噪声为:0.025070490315556526,减少噪声0.020346537232398987
# Epoch 584, Train Loss: 0.0040542553178966045
# 验证集上的指标为:0.004699186887592077，总噪声为:0.025070490315556526,减少噪声0.02037130296230316
# Epoch 585, Train Loss: 0.004326005466282368
# 验证集上的指标为:0.004737149458378553，总噪声为:0.025070490315556526,减少噪声0.020333340391516685
# Epoch 586, Train Loss: 0.0044464184902608395
# 验证集上的指标为:0.004841485992074013，总噪声为:0.025070490315556526,减少噪声0.020229004323482513
# Epoch 587, Train Loss: 0.0042104339227080345
# 验证集上的指标为:0.0047019533812999725，总噪声为:0.025070490315556526,减少噪声0.020368536934256554
# Epoch 588, Train Loss: 0.003990378696471453
# 验证集上的指标为:0.004756330046802759，总噪声为:0.025070490315556526,减少噪声0.020314160734415054
# Epoch 589, Train Loss: 0.00425249757245183
# 验证集上的指标为:0.004824111238121986，总噪声为:0.025070490315556526,减少噪声0.02024637907743454
# Epoch 590, Train Loss: 0.0040043615736067295
# 验证集上的指标为:0.004677921067923307，总噪声为:0.025070490315556526,减少噪声0.02039256878197193
# Epoch 591, Train Loss: 0.004387909546494484
# 验证集上的指标为:0.00481308763846755，总噪声为:0.025070490315556526,减少噪声0.02025740221142769
# Epoch 592, Train Loss: 0.005283649079501629
# 验证集上的指标为:0.004825572017580271，总噪声为:0.025070490315556526,减少噪声0.020244918763637543
# Epoch 593, Train Loss: 0.004771037492901087
# 验证集上的指标为:0.005031289998441935，总噪声为:0.025070490315556526,减少噪声0.02003920078277588
# Epoch 594, Train Loss: 0.004181419964879751
# 验证集上的指标为:0.004731663968414068，总噪声为:0.025070490315556526,减少噪声0.02033882588148117
# Epoch 595, Train Loss: 0.004023453686386347
# 验证集上的指标为:0.004914383869618177，总噪声为:0.025070490315556526,减少噪声0.02015610598027706
# Epoch 596, Train Loss: 0.005155682563781738
# 验证集上的指标为:0.004632758442312479，总噪声为:0.025070490315556526,减少噪声0.020437732338905334
# Epoch 597, Train Loss: 0.005682864226400852
# 验证集上的指标为:0.004629694856703281，总噪声为:0.025070490315556526,减少噪声0.02044079452753067
# Epoch 598, Train Loss: 0.004297108855098486
# 验证集上的指标为:0.004779350478202105，总噪声为:0.025070490315556526,减少噪声0.02029114030301571
# Epoch 599, Train Loss: 0.005397969391196966
# 验证集上的指标为:0.0048008575104177，总噪声为:0.025070490315556526,减少噪声0.02026963233947754
# Epoch 600, Train Loss: 0.004225609358400106
# 验证集上的指标为:0.004840595182031393，总噪声为:0.025070490315556526,减少噪声0.020229894667863846

# %%
# model = T7DAE2()
# model.to(device)

model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task7-1_model_best.pth',weights_only=True))

import numpy as np

model.eval()

with torch.no_grad():
    val_input = val_input.to(device)
    val_out = model(val_input)
    loss_val = criterion(val_out, val_label)
    orig_err = criterion(val_input, val_label)
print(f'验证集上的指标为:{loss_val}，总噪声为:{orig_err},减少噪声{orig_err-loss_val}')

# 6. 绘制原始轨迹和重建后的轨迹
plt.figure(figsize=(10, 7))

# 绘制原始轨迹
num = num-1
# num = np.random.randint(30000)
print(num)
plt.figure(figsize=[8,6])
plt.plot(val_label.cpu().numpy()[num,:,0], val_label.cpu().numpy()[num,:,1], '-o',c='blue', label='Original Data')
plt.plot(val_input.cpu().numpy()[num,:,0], val_input.cpu().numpy()[num,:,1], '-o', c='green', label='Noisy Data')
plt.plot(val_out.cpu().numpy()[num,:,0], val_out.cpu().numpy()[num,:,1], '-o', c='red', label='Reconstructed Data')
plt.title('Reconstructed Trajectory')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.axis('equal')
plt.show()
# Out:
# 验证集上的指标为:0.0045988475903868675，总噪声为:0.025070490315556526,减少噪声0.020471643656492233
# 1025

# %%
# 计算突破约束比例

# 定义临时类
# 创建一个临时类并继承 MyMixin
class TempClass(Vehicle_Model_Methods):
    pass

# 实例化临时类
temp_instance = TempClass()
ax_out_rate,delta_out_rate,traj_out_rate=temp_instance.constrain_count(val_out,10,0.25)
print('加速度突破率：',ax_out_rate)
print('转向突破率：',delta_out_rate)
print('轨迹突破率：',traj_out_rate)
# Out:
# 加速度突破率： 0.005197614897042513
# 转向突破率： 0.019251402467489243
# 轨迹突破率： 0.10998892784118652

# %%
# 计算原始数据和噪声数据

print('噪声数据')
ax_out_rate,delta_out_rate,traj_out_rate=temp_instance.constrain_count(val_input,10,0.25)
print('加速度突破率：',ax_out_rate)
print('转向突破率：',delta_out_rate)
print('轨迹突破率：',traj_out_rate)


print('\n原始数据')
ax_out_rate,delta_out_rate,traj_out_rate=temp_instance.constrain_count(val_label,10,0.25)
print('加速度突破率：',ax_out_rate)
print('转向突破率：',delta_out_rate)
print('轨迹突破率：',traj_out_rate)
# Out:
# 噪声数据
# 加速度突破率： 0.714092493057251
# 转向突破率： 0.6231790781021118
# 轨迹突破率： 0.9953458905220032
#
# 原始数据
# 加速度突破率： 0.029488330706954002
# 转向突破率： 0.01897525228559971
# 轨迹突破率： 0.18869715929031372

# %%
# 计算误差
def ADE_err(out,label):
    if isinstance(out, np.ndarray):
        out = torch.tensor(out, dtype=torch.float32)  # 将numpy.ndarray转换为Tensor
    ade = ((out - label) ** 2).sum(axis=2).sqrt().mean()
    return ade.item()

print('轨迹重构误差：',ADE_err(val_out,val_label))
# Out:
# 0.07868189364671707
