# %% [markdown]
# 训练自编码器
#
# 1. 用含噪声的数据训练
# 2. 再降噪自编码器的输出的基础上进行重构
#
# ---
#
# 训练结果：

# %%
# 直接训练
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import pickle
import os

from torch.utils.tensorboard import SummaryWriter

from model.PIAE_models import T7PIAE5,T7DAE1,Vehicle_Model_Methods

# 检查是否有可用的GPU
if torch.cuda.is_available():
    print('显卡参与训练')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 训练开始前启用 PyTorch 的异常检测
torch.autograd.set_detect_anomaly(True)
# Out:
# 显卡参与训练

# %%
# 加载数据
# 1. 加载预处理后的数据
##

def load_preprocessed_data(input_file):
    with open(input_file, 'rb') as f:
        data = pickle.load(f)
    return data

input_file = '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/data/Task2_data'  # 替换为你保存的.pkl文件路径
# 标准真值轨迹，标准噪声轨迹，标准化参数， 真值轨迹初值，噪声轨迹初值
tarin_data = load_preprocessed_data(os.path.join(input_file,'train_noisy_data.kpl'))

dataset = TensorDataset(tarin_data[0],tarin_data[1],tarin_data[3])
dataloader = DataLoader(dataset, batch_size=1000, shuffle=True)


val_data = load_preprocessed_data(os.path.join(input_file,'val_noisy_data.kpl'))

val_label = val_data[0].to(device)
val_input = val_data[1].to(device)
val_edge = val_data[3].to(device)

# %%
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()

    def forward(self,outputs, targets, actions):

        mse_loss = nn.MSELoss()(outputs, targets)

        # 平滑loss
        ax = actions[:, :, 0]
        delta = actions[:, :, 1]

        loss_ax = torch.mean(torch.abs(torch.diff(ax,dim=1)))
        loss_delta = torch.mean(torch.abs(torch.diff(delta,dim=1)))*10
    
        return mse_loss + 1e-3*(loss_ax+loss_delta)

# %%
# 3. 定义模型、损失函数和优化器
#模型
model = T7PIAE5(torch.tensor(10),torch.tensor(0.25))
model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/good_models/20250320_Task5-1_T7PIAE5.pth', weights_only=True))
model.to(device)


# DAE模型
dae_model = T7DAE1()
dae_model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/good_models/20250324_Task6-1_T7DAE1.pth', weights_only=True))

dae_model.to(device)


# 损失函数
criterion = nn.MSELoss()
criterion_train = CustomLoss()

# 优化器
optimizer = optim.Adam([
    {'params': model.parameters(), 'lr': 1e-3}, # 5.0e-4
    {'params': dae_model.parameters(), 'lr': 1e-3} # 5.0e-6
    ]) # lr=0.001

# %%
# %clear

# 创建一个SummaryWriter对象，指定日志保存的路径
writer = SummaryWriter('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/logs/log12')


# 4. 训练模型Autoencoder
epochs = 600

best_loss = float('inf')

for epoch in range(epochs):
    
    model.train()  # 确保模型处于训练模式
    for batch_idx, (label,input,edge) in enumerate(dataloader):  
        # 添加噪声
        
        label = label.to(device)  # 将输入数据移动到同一设备
        input = input.to(device)

        # with torch.no_grad():
        dae_out = dae_model(input)

        dae_loss = nn.MSELoss()(dae_out,label)

        feat = torch.diff(dae_out,dim=1)

        # # 真值边界
        # edagepoint = edge[:,0:2,:]
        # endstate = edge[:,2,:]

        # 重构的
        edagepoint = torch.stack([dae_out[:,0,:],dae_out[:,-1,:]],dim=1)
        ve = torch.sqrt((dae_out[:,-1,1]-dae_out[:,-2,1])**2 +(dae_out[:,-1,0]-dae_out[:,-2,0])**2)/torch.tensor(0.1)
        phie = torch.arctan2(dae_out[:,-1,1]-dae_out[:,-2,1],dae_out[:,-1,0]-dae_out[:,-2,0])
        endstate = torch.stack([ve,phie],dim=1)

        optimizer.zero_grad()
        outputs,actions = model(feat,edagepoint,endstate)

        loss = criterion_train(outputs, label,actions)
        # loss = criterion(outputs, dae_out)
        loss.backward()
        optimizer.step()


    model.eval()
    with torch.no_grad():
        val_dae_out = dae_model(val_input)
        val_feat = torch.diff(val_dae_out,dim=1)

        # # 真值的
        # val_edagepoint = val_edge[:,0:2,:]
        # val_endstate = val_edge[:,2,:]
        # 重构的
        val_edagepoint = torch.stack([val_dae_out[:,0,:],val_dae_out[:,-1,:]],dim=1)
        val_ve = torch.sqrt((val_dae_out[:,-1,1]-val_dae_out[:,-2,1])**2 +(val_dae_out[:,-1,0]-val_dae_out[:,-2,0])**2)/torch.tensor(0.1)
        val_phie = torch.arctan2(val_dae_out[:,-1,1]-val_dae_out[:,-2,1],val_dae_out[:,-1,0]-val_dae_out[:,-2,0])
        val_endstate = torch.stack([val_ve,val_phie],dim=1)


        val_output,val_action = model(val_feat,val_edagepoint,val_endstate)
        val_loss = criterion(val_output,val_label)
        orig_err = criterion(val_input, val_label)
        val_dae_loss = criterion(val_dae_out,val_label)

    print(f'验证集上的指标为:{val_loss}，总噪声为:{orig_err},减少噪声{orig_err-val_loss},dae上的噪声{val_dae_loss}')
    
    # torch.save(model.state_dict(), f'/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test6_piae_good/model/Task8_trained_model/model_{epoch:03}.pth')
    if val_loss.item() < best_loss :
        # 保存模型
        torch.save(model.state_dict(), '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task12_piae5_best.pth')
        torch.save(dae_model.state_dict(), '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task12_dae1_best.pth')
        best_loss = val_loss.item()


    print(f'Epoch {epoch+1}, Train Loss: {loss.item()}, Val Loss: {val_loss.item()}')
    # print()
    # 使用SummaryWriter记录数据
    writer.add_scalar('Loss/train', loss, epoch)
    writer.add_scalar('Loss/val', val_loss, epoch)


# 关闭SummaryWriter
writer.close()
# Out:
# 验证集上的指标为:0.006003472488373518，总噪声为:0.025070490315556526,减少噪声0.01906701736152172,dae上的噪声0.023441117256879807
# Epoch 1, Train Loss: 0.006690938491374254, Val Loss: 0.006003472488373518
# 验证集上的指标为:0.005944736301898956，总噪声为:0.025070490315556526,减少噪声0.01912575401365757,dae上的噪声0.02256893739104271
# Epoch 2, Train Loss: 0.005483451299369335, Val Loss: 0.005944736301898956
# 验证集上的指标为:0.005779782775789499，总噪声为:0.025070490315556526,减少噪声0.019290708005428314,dae上的噪声0.020472437143325806
# Epoch 3, Train Loss: 0.005600884556770325, Val Loss: 0.005779782775789499
# 验证集上的指标为:0.0056966389529407024，总噪声为:0.025070490315556526,减少噪声0.019373850896954536,dae上的噪声0.02337723970413208
# Epoch 4, Train Loss: 0.0050351498648524284, Val Loss: 0.0056966389529407024
# 验证集上的指标为:0.006386902648955584，总噪声为:0.025070490315556526,减少噪声0.01868358813226223,dae上的噪声0.02719663269817829
# Epoch 5, Train Loss: 0.005442446563392878, Val Loss: 0.006386902648955584
# 验证集上的指标为:0.0058654481545090675，总噪声为:0.025070490315556526,减少噪声0.019205041229724884,dae上的噪声0.02149917557835579
# Epoch 6, Train Loss: 0.005859810393303633, Val Loss: 0.0058654481545090675
# 验证集上的指标为:0.005413920618593693，总噪声为:0.025070490315556526,减少噪声0.01965656876564026,dae上的噪声0.020523902028799057
# Epoch 7, Train Loss: 0.004998286720365286, Val Loss: 0.005413920618593693
# 验证集上的指标为:0.005311280954629183，总噪声为:0.025070490315556526,减少噪声0.01975920982658863,dae上的噪声0.021071983501315117
# Epoch 8, Train Loss: 0.00803194660693407, Val Loss: 0.005311280954629183
# 验证集上的指标为:0.005993070546537638，总噪声为:0.025070490315556526,减少噪声0.019077420234680176,dae上的噪声0.021742964163422585
# Epoch 9, Train Loss: 0.005603691563010216, Val Loss: 0.005993070546537638
# 验证集上的指标为:0.005560343153774738，总噪声为:0.025070490315556526,减少噪声0.019510146230459213,dae上的噪声0.01805301383137703
# Epoch 10, Train Loss: 0.005353000480681658, Val Loss: 0.005560343153774738
# 验证集上的指标为:0.00729665020480752，总噪声为:0.025070490315556526,减少噪声0.017773840576410294,dae上的噪声0.03966391459107399
# Epoch 11, Train Loss: 0.0070029660128057, Val Loss: 0.00729665020480752
# 验证集上的指标为:0.005956545472145081，总噪声为:0.025070490315556526,减少噪声0.019113944843411446,dae上的噪声0.040096722543239594
# Epoch 12, Train Loss: 0.005627824924886227, Val Loss: 0.005956545472145081
# 验证集上的指标为:0.005406351760029793，总噪声为:0.025070490315556526,减少噪声0.019664138555526733,dae上的噪声0.04221006855368614
# Epoch 13, Train Loss: 0.005002272315323353, Val Loss: 0.005406351760029793
# 验证集上的指标为:0.005649369675666094，总噪声为:0.025070490315556526,减少噪声0.01942112110555172,dae上的噪声0.03259044885635376
# Epoch 14, Train Loss: 0.005700314417481422, Val Loss: 0.005649369675666094
# 验证集上的指标为:0.0055472031235694885，总噪声为:0.025070490315556526,减少噪声0.019523287191987038,dae上的噪声0.03772246837615967
# Epoch 15, Train Loss: 0.006304892711341381, Val Loss: 0.0055472031235694885
# 验证集上的指标为:0.00555769819766283，总噪声为:0.025070490315556526,减少噪声0.01951279118657112,dae上的噪声0.045431047677993774
# Epoch 16, Train Loss: 0.005134694278240204, Val Loss: 0.00555769819766283
# 验证集上的指标为:0.0065855178982019424，总噪声为:0.025070490315556526,减少噪声0.018484972417354584,dae上的噪声0.03471360728144646
# Epoch 17, Train Loss: 0.0055781141854822636, Val Loss: 0.0065855178982019424
# 验证集上的指标为:0.005154585000127554，总噪声为:0.025070490315556526,减少噪声0.019915904849767685,dae上的噪声0.042511776089668274
# Epoch 18, Train Loss: 0.004992825444787741, Val Loss: 0.005154585000127554
# 验证集上的指标为:0.005498242564499378，总噪声为:0.025070490315556526,减少噪声0.019572246819734573,dae上的噪声0.04420884698629379
# Epoch 19, Train Loss: 0.005902067758142948, Val Loss: 0.005498242564499378
# 验证集上的指标为:0.0065747820772230625，总噪声为:0.025070490315556526,减少噪声0.01849570870399475,dae上的噪声0.050645846873521805
# Epoch 20, Train Loss: 0.004786953795701265, Val Loss: 0.0065747820772230625
# 验证集上的指标为:0.005633181426674128，总噪声为:0.025070490315556526,减少噪声0.019437309354543686,dae上的噪声0.041020508855581284
# Epoch 21, Train Loss: 0.005658853333443403, Val Loss: 0.005633181426674128
# 验证集上的指标为:0.005293495953083038，总噪声为:0.025070490315556526,减少噪声0.019776994362473488,dae上的噪声0.050563883036375046
# Epoch 22, Train Loss: 0.005333370063453913, Val Loss: 0.005293495953083038
# 验证集上的指标为:0.005332876928150654，总噪声为:0.025070490315556526,减少噪声0.019737612456083298,dae上的噪声0.04518566280603409
# Epoch 23, Train Loss: 0.005486584268510342, Val Loss: 0.005332876928150654
# 验证集上的指标为:0.005175733007490635，总噪声为:0.025070490315556526,减少噪声0.019894756376743317,dae上的噪声0.044468846172094345
# Epoch 24, Train Loss: 0.005341062322258949, Val Loss: 0.005175733007490635
# 验证集上的指标为:0.005082333460450172，总噪声为:0.025070490315556526,减少噪声0.019988156855106354,dae上的噪声0.046151354908943176
# Epoch 25, Train Loss: 0.007845206186175346, Val Loss: 0.005082333460450172
# 验证集上的指标为:0.005551671143621206，总噪声为:0.025070490315556526,减少噪声0.019518818706274033,dae上的噪声0.04056033864617348
# Epoch 26, Train Loss: 0.006070195697247982, Val Loss: 0.005551671143621206
# 验证集上的指标为:0.0056061758659780025，总噪声为:0.025070490315556526,减少噪声0.019464313983917236,dae上的噪声0.04295274242758751
# Epoch 27, Train Loss: 0.005288420710712671, Val Loss: 0.0056061758659780025
# 验证集上的指标为:0.005230505485087633，总噪声为:0.025070490315556526,减少噪声0.01983998529613018,dae上的噪声0.046379245817661285
# Epoch 28, Train Loss: 0.00501241534948349, Val Loss: 0.005230505485087633
# 验证集上的指标为:0.005360476206988096，总噪声为:0.025070490315556526,减少噪声0.019710013642907143,dae上的噪声0.045771487057209015
# Epoch 29, Train Loss: 0.005186023190617561, Val Loss: 0.005360476206988096
# 验证集上的指标为:0.005624236073344946，总噪声为:0.025070490315556526,减少噪声0.019446253776550293,dae上的噪声0.052001968026161194
# Epoch 30, Train Loss: 0.005171946715563536, Val Loss: 0.005624236073344946
# 验证集上的指标为:0.005282986909151077，总噪声为:0.025070490315556526,减少噪声0.01978750340640545,dae上的噪声0.042472440749406815
# Epoch 31, Train Loss: 0.0052615199238061905, Val Loss: 0.005282986909151077
# 验证集上的指标为:0.0051039718091487885，总噪声为:0.025070490315556526,减少噪声0.019966518506407738,dae上的噪声0.04437189921736717
# Epoch 32, Train Loss: 0.004927807487547398, Val Loss: 0.0051039718091487885
# 验证集上的指标为:0.006162646226584911，总噪声为:0.025070490315556526,减少噪声0.01890784502029419,dae上的噪声0.040217190980911255
# Epoch 33, Train Loss: 0.005897559225559235, Val Loss: 0.006162646226584911
# 验证集上的指标为:0.00530932005494833，总噪声为:0.025070490315556526,减少噪声0.01976117119193077,dae上的噪声0.04553861543536186
# Epoch 34, Train Loss: 0.004899219609797001, Val Loss: 0.00530932005494833
# 验证集上的指标为:0.005336662754416466，总噪声为:0.025070490315556526,减少噪声0.01973382756114006,dae上的噪声0.05191567540168762
# Epoch 35, Train Loss: 0.005004323087632656, Val Loss: 0.005336662754416466
# 验证集上的指标为:0.005093041341751814，总噪声为:0.025070490315556526,减少噪声0.019977448508143425,dae上的噪声0.047272223979234695
# Epoch 36, Train Loss: 0.004785809200257063, Val Loss: 0.005093041341751814
# 验证集上的指标为:0.005216288845986128，总噪声为:0.025070490315556526,减少噪声0.01985420100390911,dae上的噪声0.045355722308158875
# Epoch 37, Train Loss: 0.00485822930932045, Val Loss: 0.005216288845986128
# 验证集上的指标为:0.005239706952124834，总噪声为:0.025070490315556526,减少噪声0.01983078382909298,dae上的噪声0.048492077738046646
# Epoch 38, Train Loss: 0.005759026855230331, Val Loss: 0.005239706952124834
# 验证集上的指标为:0.005143825430423021，总噪声为:0.025070490315556526,减少噪声0.019926665350794792,dae上的噪声0.04499165713787079
# Epoch 39, Train Loss: 0.005673618521541357, Val Loss: 0.005143825430423021
# 验证集上的指标为:0.0051045846194028854，总噪声为:0.025070490315556526,减少噪声0.01996590569615364,dae上的噪声0.04632886126637459
# Epoch 40, Train Loss: 0.005410276353359222, Val Loss: 0.0051045846194028854
# 验证集上的指标为:0.0052987090311944485，总噪声为:0.025070490315556526,减少噪声0.01977178081870079,dae上的噪声0.052248403429985046
# Epoch 41, Train Loss: 0.005332382395863533, Val Loss: 0.0052987090311944485
# 验证集上的指标为:0.005345658399164677，总噪声为:0.025070490315556526,减少噪声0.019724830985069275,dae上的噪声0.056182973086833954
# Epoch 42, Train Loss: 0.0047310637310147285, Val Loss: 0.005345658399164677
# 验证集上的指标为:0.00542052136734128，总噪声为:0.025070490315556526,减少噪声0.019649969413876534,dae上的噪声0.050633978098630905
# Epoch 43, Train Loss: 0.005235465709120035, Val Loss: 0.00542052136734128
# 验证集上的指标为:0.005112920887768269，总噪声为:0.025070490315556526,减少噪声0.019957568496465683,dae上的噪声0.050662729889154434
# Epoch 44, Train Loss: 0.0051973541267216206, Val Loss: 0.005112920887768269
# 验证集上的指标为:0.005954761523753405，总噪声为:0.025070490315556526,减少噪声0.01911572925746441,dae上的噪声0.04964003711938858
# Epoch 45, Train Loss: 0.005097029730677605, Val Loss: 0.005954761523753405
# 验证集上的指标为:0.0057857525534927845，总噪声为:0.025070490315556526,减少噪声0.01928473822772503,dae上的噪声0.0501420684158802
# Epoch 46, Train Loss: 0.005128911230713129, Val Loss: 0.0057857525534927845
# 验证集上的指标为:0.005416030064225197，总噪声为:0.025070490315556526,减少噪声0.01965446025133133,dae上的噪声0.06813237071037292
# Epoch 47, Train Loss: 0.005406140349805355, Val Loss: 0.005416030064225197
# 验证集上的指标为:0.005318507086485624，总噪声为:0.025070490315556526,减少噪声0.019751982763409615,dae上的噪声0.06539413332939148
# Epoch 48, Train Loss: 0.0046000913716852665, Val Loss: 0.005318507086485624
# 验证集上的指标为:0.005611987318843603，总噪声为:0.025070490315556526,减少噪声0.019458502531051636,dae上的噪声0.07788883149623871
# Epoch 49, Train Loss: 0.004923981614410877, Val Loss: 0.005611987318843603
# 验证集上的指标为:0.005330157466232777，总噪声为:0.025070490315556526,减少噪声0.019740331918001175,dae上的噪声0.06582653522491455
# Epoch 50, Train Loss: 0.005240380764007568, Val Loss: 0.005330157466232777
# 验证集上的指标为:0.005193515680730343，总噪声为:0.025070490315556526,减少噪声0.019876975566148758,dae上的噪声0.07235771417617798
# Epoch 51, Train Loss: 0.005820787511765957, Val Loss: 0.005193515680730343
# 验证集上的指标为:0.005240161903202534，总噪声为:0.025070490315556526,减少噪声0.019830327481031418,dae上的噪声0.0763365849852562
# Epoch 52, Train Loss: 0.005416539032012224, Val Loss: 0.005240161903202534
# 验证集上的指标为:0.005238348618149757，总噪声为:0.025070490315556526,减少噪声0.01983214169740677,dae上的噪声0.07902301102876663
# Epoch 53, Train Loss: 0.004784412682056427, Val Loss: 0.005238348618149757
# 验证集上的指标为:0.005215790122747421，总噪声为:0.025070490315556526,减少噪声0.019854700192809105,dae上的噪声0.07494455575942993
# Epoch 54, Train Loss: 0.005240593105554581, Val Loss: 0.005215790122747421
# 验证集上的指标为:0.005608061794191599，总噪声为:0.025070490315556526,减少噪声0.019462428987026215,dae上的噪声0.07263078540563583
# Epoch 55, Train Loss: 0.004965377971529961, Val Loss: 0.005608061794191599
# 验证集上的指标为:0.006094054318964481，总噪声为:0.025070490315556526,减少噪声0.01897643506526947,dae上的噪声0.07240786403417587
# Epoch 56, Train Loss: 0.004927653819322586, Val Loss: 0.006094054318964481
# 验证集上的指标为:0.007754501421004534，总噪声为:0.025070490315556526,减少噪声0.01731598936021328,dae上的噪声0.07392612099647522
# Epoch 57, Train Loss: 0.006362173706293106, Val Loss: 0.007754501421004534
# 验证集上的指标为:0.005355691537261009，总噪声为:0.025070490315556526,减少噪声0.019714798778295517,dae上的噪声0.08211777359247208
# Epoch 58, Train Loss: 0.00571909174323082, Val Loss: 0.005355691537261009
# 验证集上的指标为:0.005634615663439035，总噪声为:0.025070490315556526,减少噪声0.019435875117778778,dae上的噪声0.08376138657331467
# Epoch 59, Train Loss: 0.005668132100254297, Val Loss: 0.005634615663439035
# 验证集上的指标为:0.005040770396590233，总噪声为:0.025070490315556526,减少噪声0.020029719918966293,dae上的噪声0.09012068063020706
# Epoch 60, Train Loss: 0.004921435844153166, Val Loss: 0.005040770396590233
# 验证集上的指标为:0.0050455196760594845，总噪声为:0.025070490315556526,减少噪声0.020024970173835754,dae上的噪声0.09087849408388138
# Epoch 61, Train Loss: 0.005390314385294914, Val Loss: 0.0050455196760594845
# 验证集上的指标为:0.0053469231352210045，总噪声为:0.025070490315556526,减少噪声0.019723568111658096,dae上的噪声0.08584988862276077
# Epoch 62, Train Loss: 0.004927238915115595, Val Loss: 0.0053469231352210045
# 验证集上的指标为:0.0054721226915717125，总噪声为:0.025070490315556526,减少噪声0.01959836855530739,dae上的噪声0.0874774158000946
# Epoch 63, Train Loss: 0.005484200548380613, Val Loss: 0.0054721226915717125
# 验证集上的指标为:0.00546026136726141，总噪声为:0.025070490315556526,减少噪声0.01961022987961769,dae上的噪声0.08370615541934967
# Epoch 64, Train Loss: 0.004819765686988831, Val Loss: 0.00546026136726141
# 验证集上的指标为:0.005692557897418737，总噪声为:0.025070490315556526,减少噪声0.0193779319524765,dae上的噪声0.09782502055168152
# Epoch 65, Train Loss: 0.005151463206857443, Val Loss: 0.005692557897418737
# 验证集上的指标为:0.0054396335035562515，总噪声为:0.025070490315556526,减少噪声0.019630856812000275,dae上的噪声0.09774580597877502
# Epoch 66, Train Loss: 0.005117287393659353, Val Loss: 0.0054396335035562515
# 验证集上的指标为:0.004942237865179777，总噪声为:0.025070490315556526,减少噪声0.02012825198471546,dae上的噪声0.09207718819379807
# Epoch 67, Train Loss: 0.005292665213346481, Val Loss: 0.004942237865179777
# 验证集上的指标为:0.004941031336784363，总噪声为:0.025070490315556526,减少噪声0.020129458978772163,dae上的噪声0.09339222311973572
# Epoch 68, Train Loss: 0.005276158917695284, Val Loss: 0.004941031336784363
# 验证集上的指标为:0.00620988430455327，总噪声为:0.025070490315556526,减少噪声0.018860606476664543,dae上的噪声0.10317623615264893
# Epoch 69, Train Loss: 0.005214236676692963, Val Loss: 0.00620988430455327
# 验证集上的指标为:0.005171042867004871，总噪声为:0.025070490315556526,减少噪声0.01989944651722908,dae上的噪声0.08604612946510315
# Epoch 70, Train Loss: 0.005148293450474739, Val Loss: 0.005171042867004871
# 验证集上的指标为:0.00492524728178978，总噪声为:0.025070490315556526,减少噪声0.020145243033766747,dae上的噪声0.09266309440135956
# Epoch 71, Train Loss: 0.005150058772414923, Val Loss: 0.00492524728178978
# 验证集上的指标为:0.005304851569235325，总噪声为:0.025070490315556526,减少噪声0.019765637814998627,dae上的噪声0.0877542719244957
# Epoch 72, Train Loss: 0.005096004344522953, Val Loss: 0.005304851569235325
# 验证集上的指标为:0.00557294674217701，总噪声为:0.025070490315556526,减少噪声0.019497543573379517,dae上的噪声0.10290753841400146
# Epoch 73, Train Loss: 0.004878457169979811, Val Loss: 0.00557294674217701
# 验证集上的指标为:0.005378993693739176，总噪声为:0.025070490315556526,减少噪声0.019691497087478638,dae上的噪声0.10144264996051788
# Epoch 74, Train Loss: 0.004764258861541748, Val Loss: 0.005378993693739176
# 验证集上的指标为:0.005098732188344002，总噪声为:0.025070490315556526,减少噪声0.019971758127212524,dae上的噪声0.09509322047233582
# Epoch 75, Train Loss: 0.005106980446726084, Val Loss: 0.005098732188344002
# 验证集上的指标为:0.005594832822680473，总噪声为:0.025070490315556526,减少噪声0.019475657492876053,dae上的噪声0.08594159781932831
# Epoch 76, Train Loss: 0.0074108620174229145, Val Loss: 0.005594832822680473
# 验证集上的指标为:0.004967093002051115，总噪声为:0.025070490315556526,减少噪声0.020103396847844124,dae上的噪声0.09343481063842773
# Epoch 77, Train Loss: 0.005017805844545364, Val Loss: 0.004967093002051115
# 验证集上的指标为:0.005483797285705805，总噪声为:0.025070490315556526,减少噪声0.01958669349551201,dae上的噪声0.10211557894945145
# Epoch 78, Train Loss: 0.005452864803373814, Val Loss: 0.005483797285705805
# 验证集上的指标为:0.005133541766554117，总噪声为:0.025070490315556526,减少噪声0.019936949014663696,dae上的噪声0.08953462541103363
# Epoch 79, Train Loss: 0.004956507124006748, Val Loss: 0.005133541766554117
# 验证集上的指标为:0.005117318592965603，总噪声为:0.025070490315556526,减少噪声0.019953172653913498,dae上的噪声0.09912533313035965
# Epoch 80, Train Loss: 0.004607847426086664, Val Loss: 0.005117318592965603
# 验证集上的指标为:0.005009339656680822，总噪声为:0.025070490315556526,减少噪声0.020061150193214417,dae上的噪声0.09953539073467255
# Epoch 81, Train Loss: 0.004637456499040127, Val Loss: 0.005009339656680822
# 验证集上的指标为:0.005137520842254162，总噪声为:0.025070490315556526,减少噪声0.01993297040462494,dae上的噪声0.09194692969322205
# Epoch 82, Train Loss: 0.0049394103698432446, Val Loss: 0.005137520842254162
# 验证集上的指标为:0.005280735902488232，总噪声为:0.025070490315556526,减少噪声0.01978975534439087,dae上的噪声0.10513340681791306
# Epoch 83, Train Loss: 0.00537068210542202, Val Loss: 0.005280735902488232
# 验证集上的指标为:0.005545563995838165，总噪声为:0.025070490315556526,减少噪声0.01952492631971836,dae上的噪声0.10796666890382767
# Epoch 84, Train Loss: 0.005401517264544964, Val Loss: 0.005545563995838165
# 验证集上的指标为:0.005020009353756905，总噪声为:0.025070490315556526,减少噪声0.02005048096179962,dae上的噪声0.10254257172346115
# Epoch 85, Train Loss: 0.0052584814839065075, Val Loss: 0.005020009353756905
# 验证集上的指标为:0.0049763089045882225，总噪声为:0.025070490315556526,减少噪声0.02009418234229088,dae上的噪声0.10170833766460419
# Epoch 86, Train Loss: 0.0045441314578056335, Val Loss: 0.0049763089045882225
# 验证集上的指标为:0.005997511092573404，总噪声为:0.025070490315556526,减少噪声0.01907297968864441,dae上的噪声0.10167530179023743
# Epoch 87, Train Loss: 0.006979240104556084, Val Loss: 0.005997511092573404
# 验证集上的指标为:0.00524055166170001，总噪声为:0.025070490315556526,减少噪声0.01982993818819523,dae上的噪声0.1077873557806015
# Epoch 88, Train Loss: 0.004813486710190773, Val Loss: 0.00524055166170001
# 验证集上的指标为:0.004982094280421734，总噪声为:0.025070490315556526,减少噪声0.020088396966457367,dae上的噪声0.10951704531908035
# Epoch 89, Train Loss: 0.005589708220213652, Val Loss: 0.004982094280421734
# 验证集上的指标为:0.004932476673275232，总噪声为:0.025070490315556526,减少噪声0.02013801410794258,dae上的噪声0.10982534289360046
# Epoch 90, Train Loss: 0.004862981848418713, Val Loss: 0.004932476673275232
# 验证集上的指标为:0.005037194117903709，总噪声为:0.025070490315556526,减少噪声0.020033296197652817,dae上的噪声0.10645364224910736
# Epoch 91, Train Loss: 0.004878728184849024, Val Loss: 0.005037194117903709
# 验证集上的指标为:0.004946570843458176，总噪声为:0.025070490315556526,减少噪声0.02012391947209835,dae上的噪声0.10530094802379608
# Epoch 92, Train Loss: 0.0049811722710728645, Val Loss: 0.004946570843458176
# 验证集上的指标为:0.005038291681557894，总噪声为:0.025070490315556526,减少噪声0.02003219909965992,dae上的噪声0.10903368145227432
# Epoch 93, Train Loss: 0.004996694158762693, Val Loss: 0.005038291681557894
# 验证集上的指标为:0.0050883907824754715，总噪声为:0.025070490315556526,减少噪声0.019982099533081055,dae上的噪声0.10667755454778671
# Epoch 94, Train Loss: 0.004856926389038563, Val Loss: 0.0050883907824754715
# 验证集上的指标为:0.005051618907600641，总噪声为:0.025070490315556526,减少噪声0.020018871873617172,dae上的噪声0.10167873650789261
# Epoch 95, Train Loss: 0.004862939938902855, Val Loss: 0.005051618907600641
# 验证集上的指标为:0.005093073006719351，总噪声为:0.025070490315556526,减少噪声0.019977416843175888,dae上的噪声0.11378500610589981
# Epoch 96, Train Loss: 0.0064150504767894745, Val Loss: 0.005093073006719351
# 验证集上的指标为:0.005798515398055315，总噪声为:0.025070490315556526,减少噪声0.0192719753831625,dae上的噪声0.1043657436966896
# Epoch 97, Train Loss: 0.006503408309072256, Val Loss: 0.005798515398055315
# 验证集上的指标为:0.004984615836292505，总噪声为:0.025070490315556526,减少噪声0.020085874944925308,dae上的噪声0.1094556599855423
# Epoch 98, Train Loss: 0.0045610349625349045, Val Loss: 0.004984615836292505
# 验证集上的指标为:0.0050201271660625935，总噪声为:0.025070490315556526,减少噪声0.02005036361515522,dae上的噪声0.1107715293765068
# Epoch 99, Train Loss: 0.004932618699967861, Val Loss: 0.0050201271660625935
# 验证集上的指标为:0.00519702211022377，总噪声为:0.025070490315556526,减少噪声0.019873468205332756,dae上的噪声0.10376178473234177
# Epoch 100, Train Loss: 0.005004888400435448, Val Loss: 0.00519702211022377
# 验证集上的指标为:0.0052995276637375355，总噪声为:0.025070490315556526,减少噪声0.019770963117480278,dae上的噪声0.10598140209913254
# Epoch 101, Train Loss: 0.005116177722811699, Val Loss: 0.0052995276637375355
# 验证集上的指标为:0.005022963043302298，总噪声为:0.025070490315556526,减少噪声0.02004752680659294,dae上的噪声0.11625446379184723
# Epoch 102, Train Loss: 0.004913733806461096, Val Loss: 0.005022963043302298
# 验证集上的指标为:0.005019959527999163，总噪声为:0.025070490315556526,减少噪声0.02005053125321865,dae上的噪声0.11789610236883163
# Epoch 103, Train Loss: 0.004815840627998114, Val Loss: 0.005019959527999163
# 验证集上的指标为:0.004969375673681498，总噪声为:0.025070490315556526,减少噪声0.020101115107536316,dae上的噪声0.117239810526371
# Epoch 104, Train Loss: 0.004434429109096527, Val Loss: 0.004969375673681498
# 验证集上的指标为:0.00554250180721283，总噪声为:0.025070490315556526,减少噪声0.019527988508343697,dae上的噪声0.11256289482116699
# Epoch 105, Train Loss: 0.004989338107407093, Val Loss: 0.00554250180721283
# 验证集上的指标为:0.005114820320159197，总噪声为:0.025070490315556526,减少噪声0.019955670461058617,dae上的噪声0.11890671402215958
# Epoch 106, Train Loss: 0.004671735223382711, Val Loss: 0.005114820320159197
# 验证集上的指标为:0.005123197101056576，总噪声为:0.025070490315556526,减少噪声0.019947294145822525,dae上的噪声0.1152104064822197
# Epoch 107, Train Loss: 0.004556690342724323, Val Loss: 0.005123197101056576
# 验证集上的指标为:0.005220666527748108，总噪声为:0.025070490315556526,减少噪声0.01984982378780842,dae上的噪声0.11381997168064117
# Epoch 108, Train Loss: 0.005041445605456829, Val Loss: 0.005220666527748108
# 验证集上的指标为:0.005185029003769159，总噪声为:0.025070490315556526,减少噪声0.019885461777448654,dae上的噪声0.12380006164312363
# Epoch 109, Train Loss: 0.004301477689296007, Val Loss: 0.005185029003769159
# 验证集上的指标为:0.005373405292630196，总噪声为:0.025070490315556526,减少噪声0.01969708502292633,dae上的噪声0.13090753555297852
# Epoch 110, Train Loss: 0.0054630981758236885, Val Loss: 0.005373405292630196
# 验证集上的指标为:0.005461300257593393，总噪声为:0.025070490315556526,减少噪声0.01960919052362442,dae上的噪声0.12530836462974548
# Epoch 111, Train Loss: 0.004989772103726864, Val Loss: 0.005461300257593393
# 验证集上的指标为:0.005594103131443262，总噪声为:0.025070490315556526,减少噪声0.01947638764977455,dae上的噪声0.11785487085580826
# Epoch 112, Train Loss: 0.006199560593813658, Val Loss: 0.005594103131443262
# 验证集上的指标为:0.005017525516450405，总噪声为:0.025070490315556526,减少噪声0.020052965730428696,dae上的噪声0.1254875212907791
# Epoch 113, Train Loss: 0.005312597379088402, Val Loss: 0.005017525516450405
# 验证集上的指标为:0.005206116940826178，总噪声为:0.025070490315556526,减少噪声0.01986437290906906,dae上的噪声0.13063670694828033
# Epoch 114, Train Loss: 0.005569081287831068, Val Loss: 0.005206116940826178
# 验证集上的指标为:0.00515720946714282，总噪声为:0.025070490315556526,减少噪声0.01991328038275242,dae上的噪声0.12403841316699982
# Epoch 115, Train Loss: 0.0044456054456532, Val Loss: 0.00515720946714282
# 验证集上的指标为:0.005127397365868092，总噪声为:0.025070490315556526,减少噪声0.01994309201836586,dae上的噪声0.1294068843126297
# Epoch 116, Train Loss: 0.004312919918447733, Val Loss: 0.005127397365868092
# 验证集上的指标为:0.005161589477211237，总噪声为:0.025070490315556526,减少噪声0.019908901304006577,dae上的噪声0.11892607063055038
# Epoch 117, Train Loss: 0.004897585604339838, Val Loss: 0.005161589477211237
# 验证集上的指标为:0.005131813231855631，总噪声为:0.025070490315556526,减少噪声0.019938677549362183,dae上的噪声0.11827016621828079
# Epoch 118, Train Loss: 0.004847219213843346, Val Loss: 0.005131813231855631
# 验证集上的指标为:0.005013974849134684，总噪声为:0.025070490315556526,减少噪声0.02005651593208313,dae上的噪声0.12668946385383606
# Epoch 119, Train Loss: 0.004627069924026728, Val Loss: 0.005013974849134684
# 验证集上的指标为:0.005275651812553406，总噪声为:0.025070490315556526,减少噪声0.01979483850300312,dae上的噪声0.12962229549884796
# Epoch 120, Train Loss: 0.004583488684147596, Val Loss: 0.005275651812553406
# 验证集上的指标为:0.005204209592193365，总噪声为:0.025070490315556526,减少噪声0.019866280257701874,dae上的噪声0.13066160678863525
# Epoch 121, Train Loss: 0.004799236077815294, Val Loss: 0.005204209592193365
# 验证集上的指标为:0.005048125982284546，总噪声为:0.025070490315556526,减少噪声0.02002236433327198,dae上的噪声0.12593130767345428
# Epoch 122, Train Loss: 0.004595157224684954, Val Loss: 0.005048125982284546
# 验证集上的指标为:0.0049769701436161995，总噪声为:0.025070490315556526,减少噪声0.020093519240617752,dae上的噪声0.13565082848072052
# Epoch 123, Train Loss: 0.004719854798167944, Val Loss: 0.0049769701436161995
# 验证集上的指标为:0.005543489009141922，总噪声为:0.025070490315556526,减少噪声0.019527001306414604,dae上的噪声0.13802498579025269
# Epoch 124, Train Loss: 0.005266117863357067, Val Loss: 0.005543489009141922
# 验证集上的指标为:0.005061110947281122，总噪声为:0.025070490315556526,减少噪声0.02000937983393669,dae上的噪声0.12999796867370605
# Epoch 125, Train Loss: 0.004500295966863632, Val Loss: 0.005061110947281122
# 验证集上的指标为:0.004909059032797813，总噪声为:0.025070490315556526,减少噪声0.020161431282758713,dae上的噪声0.13030119240283966
# Epoch 126, Train Loss: 0.004665834363549948, Val Loss: 0.004909059032797813
# 验证集上的指标为:0.005381080321967602，总噪声为:0.025070490315556526,减少噪声0.0196894109249115,dae上的噪声0.12222593277692795
# Epoch 127, Train Loss: 0.004643931053578854, Val Loss: 0.005381080321967602
# 验证集上的指标为:0.00509549118578434，总噪声为:0.025070490315556526,减少噪声0.019974999129772186,dae上的噪声0.13165397942066193
# Epoch 128, Train Loss: 0.00451855082064867, Val Loss: 0.00509549118578434
# 验证集上的指标为:0.00505374139174819，总噪声为:0.025070490315556526,减少噪声0.02001674845814705,dae上的噪声0.13129045069217682
# Epoch 129, Train Loss: 0.004507225938141346, Val Loss: 0.00505374139174819
# 验证集上的指标为:0.004996692296117544，总噪声为:0.025070490315556526,减少噪声0.020073797553777695,dae上的噪声0.1318054348230362
# Epoch 130, Train Loss: 0.0049684904515743256, Val Loss: 0.004996692296117544
# 验证集上的指标为:0.00496753491461277，总噪声为:0.025070490315556526,减少噪声0.020102955400943756,dae上的噪声0.13281363248825073
# Epoch 131, Train Loss: 0.0046857185661792755, Val Loss: 0.00496753491461277
# 验证集上的指标为:0.005538737867027521，总噪声为:0.025070490315556526,减少噪声0.019531752914190292,dae上的噪声0.12515988945960999
# Epoch 132, Train Loss: 0.005444602109491825, Val Loss: 0.005538737867027521
# 验证集上的指标为:0.0052406927570700645，总噪声为:0.025070490315556526,减少噪声0.019829798489809036,dae上的噪声0.13530117273330688
# Epoch 133, Train Loss: 0.005205497611314058, Val Loss: 0.0052406927570700645
# 验证集上的指标为:0.005092755891382694，总噪声为:0.025070490315556526,减少噪声0.019977733492851257,dae上的噪声0.1402941644191742
# Epoch 134, Train Loss: 0.005011674016714096, Val Loss: 0.005092755891382694
# 验证集上的指标为:0.005332689732313156，总噪声为:0.025070490315556526,减少噪声0.01973780058324337,dae上的噪声0.13643407821655273
# Epoch 135, Train Loss: 0.006502743810415268, Val Loss: 0.005332689732313156
# 验证集上的指标为:0.005185403861105442，总噪声为:0.025070490315556526,减少噪声0.01988508552312851,dae上的噪声0.1436082422733307
# Epoch 136, Train Loss: 0.005643567536026239, Val Loss: 0.005185403861105442
# 验证集上的指标为:0.0052238209173083305，总噪声为:0.025070490315556526,减少噪声0.01984667032957077,dae上的噪声0.14756661653518677
# Epoch 137, Train Loss: 0.005217062309384346, Val Loss: 0.0052238209173083305
# 验证集上的指标为:0.005203742068260908，总噪声为:0.025070490315556526,减少噪声0.01986674778163433,dae上的噪声0.13734100759029388
# Epoch 138, Train Loss: 0.004811448510736227, Val Loss: 0.005203742068260908
# 验证集上的指标为:0.004970346111804247，总噪声为:0.025070490315556526,减少噪声0.020100144669413567,dae上的噪声0.1431618332862854
# Epoch 139, Train Loss: 0.005264017730951309, Val Loss: 0.004970346111804247
# 验证集上的指标为:0.005214672069996595，总噪声为:0.025070490315556526,减少噪声0.019855817779898643,dae上的噪声0.14804218709468842
# Epoch 140, Train Loss: 0.005052069202065468, Val Loss: 0.005214672069996595
# 验证集上的指标为:0.005033073481172323，总噪声为:0.025070490315556526,减少噪声0.020037416368722916,dae上的噪声0.14198893308639526
# Epoch 141, Train Loss: 0.005803300999104977, Val Loss: 0.005033073481172323
# 验证集上的指标为:0.005182719323784113，总噪声为:0.025070490315556526,减少噪声0.0198877714574337,dae上的噪声0.13861455023288727
# Epoch 142, Train Loss: 0.006256413646042347, Val Loss: 0.005182719323784113
# 验证集上的指标为:0.005547298584133387，总噪声为:0.025070490315556526,减少噪声0.019523192197084427,dae上的噪声0.14701099693775177
# Epoch 143, Train Loss: 0.005299303214997053, Val Loss: 0.005547298584133387
# 验证集上的指标为:0.0050993263721466064，总噪声为:0.025070490315556526,减少噪声0.01997116394340992,dae上的噪声0.1419297158718109
# Epoch 144, Train Loss: 0.004816573113203049, Val Loss: 0.0050993263721466064
# 验证集上的指标为:0.005309836473315954，总噪声为:0.025070490315556526,减少噪声0.019760653376579285,dae上的噪声0.15091189742088318
# Epoch 145, Train Loss: 0.004865918308496475, Val Loss: 0.005309836473315954
# 验证集上的指标为:0.005654837936162949，总噪声为:0.025070490315556526,减少噪声0.019415652379393578,dae上的噪声0.16125917434692383
# Epoch 146, Train Loss: 0.004719363059848547, Val Loss: 0.005654837936162949
# 验证集上的指标为:0.0051063853316009045，总噪声为:0.025070490315556526,减少噪声0.019964104518294334,dae上的噪声0.15432681143283844
# Epoch 147, Train Loss: 0.004955843091011047, Val Loss: 0.0051063853316009045
# 验证集上的指标为:0.0054354360327124596，总噪声为:0.025070490315556526,减少噪声0.01963505521416664,dae上的噪声0.14414867758750916
# Epoch 148, Train Loss: 0.004619588144123554, Val Loss: 0.0054354360327124596
# 验证集上的指标为:0.005093850661069155，总噪声为:0.025070490315556526,减少噪声0.01997664012014866,dae上的噪声0.1528862863779068
# Epoch 149, Train Loss: 0.0045430343598127365, Val Loss: 0.005093850661069155
# 验证集上的指标为:0.005114015191793442，总噪声为:0.025070490315556526,减少噪声0.019956475123763084,dae上的噪声0.15291166305541992
# Epoch 150, Train Loss: 0.004563351161777973, Val Loss: 0.005114015191793442
# 验证集上的指标为:0.005089472513645887，总噪声为:0.025070490315556526,减少噪声0.01998101733624935,dae上的噪声0.15124277770519257
# Epoch 151, Train Loss: 0.004696026910096407, Val Loss: 0.005089472513645887
# 验证集上的指标为:0.005121743306517601，总噪声为:0.025070490315556526,减少噪声0.019948747009038925,dae上的噪声0.1565820425748825
# Epoch 152, Train Loss: 0.004389126319438219, Val Loss: 0.005121743306517601
# 验证集上的指标为:0.005372077226638794，总噪声为:0.025070490315556526,减少噪声0.019698413088917732,dae上的噪声0.1638258993625641
# Epoch 153, Train Loss: 0.004451816435903311, Val Loss: 0.005372077226638794
# 验证集上的指标为:0.005015760660171509，总噪声为:0.025070490315556526,减少噪声0.020054729655385017,dae上的噪声0.15553998947143555
# Epoch 154, Train Loss: 0.005529823713004589, Val Loss: 0.005015760660171509
# 验证集上的指标为:0.0052541992627084255，总噪声为:0.025070490315556526,减少噪声0.019816290587186813,dae上的噪声0.16474571824073792
# Epoch 155, Train Loss: 0.005309094674885273, Val Loss: 0.0052541992627084255
# 验证集上的指标为:0.005043158773332834，总噪声为:0.025070490315556526,减少噪声0.02002733200788498,dae上的噪声0.15665797889232635
# Epoch 156, Train Loss: 0.005070461425930262, Val Loss: 0.005043158773332834
# 验证集上的指标为:0.005004090256989002，总噪声为:0.025070490315556526,减少噪声0.02006639912724495,dae上的噪声0.16641835868358612
# Epoch 157, Train Loss: 0.0048715961165726185, Val Loss: 0.005004090256989002
# 验证集上的指标为:0.005261910147964954，总噪声为:0.025070490315556526,减少噪声0.019808579236268997,dae上的噪声0.15229713916778564
# Epoch 158, Train Loss: 0.004481867887079716, Val Loss: 0.005261910147964954
# 验证集上的指标为:0.005143150687217712，总噪声为:0.025070490315556526,减少噪声0.019927339628338814,dae上的噪声0.15213428437709808
# Epoch 159, Train Loss: 0.004426455125212669, Val Loss: 0.005143150687217712
# 验证集上的指标为:0.005256756208837032，总噪声为:0.025070490315556526,减少噪声0.01981373503804207,dae上的噪声0.1522902399301529
# Epoch 160, Train Loss: 0.00450609577819705, Val Loss: 0.005256756208837032
# 验证集上的指标为:0.0056751202791929245，总噪声为:0.025070490315556526,减少噪声0.0193953700363636,dae上的噪声0.17071542143821716
# Epoch 161, Train Loss: 0.004965912085026503, Val Loss: 0.0056751202791929245
# 验证集上的指标为:0.005283846985548735，总噪声为:0.025070490315556526,减少噪声0.019786642864346504,dae上的噪声0.15558452904224396
# Epoch 162, Train Loss: 0.004683660343289375, Val Loss: 0.005283846985548735
# 验证集上的指标为:0.005330605898052454，总噪声为:0.025070490315556526,减少噪声0.01973988488316536,dae上的噪声0.17718522250652313
# Epoch 163, Train Loss: 0.005706374533474445, Val Loss: 0.005330605898052454
# 验证集上的指标为:0.005035975947976112，总噪声为:0.025070490315556526,减少噪声0.020034514367580414,dae上的噪声0.159295454621315
# Epoch 164, Train Loss: 0.004632314667105675, Val Loss: 0.005035975947976112
# 验证集上的指标为:0.0049622515216469765，总噪声为:0.025070490315556526,减少噪声0.020108237862586975,dae上的噪声0.1678527593612671
# Epoch 165, Train Loss: 0.004500910174101591, Val Loss: 0.0049622515216469765
# 验证集上的指标为:0.005219241138547659，总噪声为:0.025070490315556526,减少噪声0.01985124871134758,dae上的噪声0.15530383586883545
# Epoch 166, Train Loss: 0.004827310796827078, Val Loss: 0.005219241138547659
# 验证集上的指标为:0.004944341257214546，总噪声为:0.025070490315556526,减少噪声0.02012614905834198,dae上的噪声0.16405795514583588
# Epoch 167, Train Loss: 0.004672770854085684, Val Loss: 0.004944341257214546
# 验证集上的指标为:0.005065299104899168，总噪声为:0.025070490315556526,减少噪声0.02000519074499607,dae上的噪声0.1728648543357849
# Epoch 168, Train Loss: 0.004866324365139008, Val Loss: 0.005065299104899168
# 验证集上的指标为:0.005403386894613504，总噪声为:0.025070490315556526,减少噪声0.01966710388660431,dae上的噪声0.16869674623012543
# Epoch 169, Train Loss: 0.005262801423668861, Val Loss: 0.005403386894613504
# 验证集上的指标为:0.005097413435578346，总噪声为:0.025070490315556526,减少噪声0.01997307687997818,dae上的噪声0.1845911592245102
# Epoch 170, Train Loss: 0.004695586394518614, Val Loss: 0.005097413435578346
# 验证集上的指标为:0.00501460675150156，总噪声为:0.025070490315556526,减少噪声0.02005588263273239,dae上的噪声0.18638528883457184
# Epoch 171, Train Loss: 0.004685020539909601, Val Loss: 0.00501460675150156
# 验证集上的指标为:0.004976467229425907，总噪声为:0.025070490315556526,减少噪声0.020094022154808044,dae上的噪声0.17911478877067566
# Epoch 172, Train Loss: 0.004275980871170759, Val Loss: 0.004976467229425907
# 验证集上的指标为:0.005870587658137083，总噪声为:0.025070490315556526,减少噪声0.019199902191758156,dae上的噪声0.1591133028268814
# Epoch 173, Train Loss: 0.0050123147666454315, Val Loss: 0.005870587658137083
# 验证集上的指标为:0.005324929486960173，总噪声为:0.025070490315556526,减少噪声0.019745560362935066,dae上的噪声0.16878417134284973
# Epoch 174, Train Loss: 0.004741091746836901, Val Loss: 0.005324929486960173
# 验证集上的指标为:0.00542455492541194，总噪声为:0.025070490315556526,减少噪声0.0196459349244833,dae上的噪声0.17806528508663177
# Epoch 175, Train Loss: 0.005283772014081478, Val Loss: 0.00542455492541194
# 验证集上的指标为:0.0057569327764213085，总噪声为:0.025070490315556526,减少噪声0.01931355707347393,dae上的噪声0.17438864707946777
# Epoch 176, Train Loss: 0.005835437681525946, Val Loss: 0.0057569327764213085
# 验证集上的指标为:0.005060200579464436，总噪声为:0.025070490315556526,减少噪声0.020010288804769516,dae上的噪声0.1840640902519226
# Epoch 177, Train Loss: 0.004543212242424488, Val Loss: 0.005060200579464436
# 验证集上的指标为:0.00513615645468235，总噪声为:0.025070490315556526,减少噪声0.019934333860874176,dae上的噪声0.189267098903656
# Epoch 178, Train Loss: 0.00464180763810873, Val Loss: 0.00513615645468235
# 验证集上的指标为:0.005174519959837198，总噪声为:0.025070490315556526,减少噪声0.019895970821380615,dae上的噪声0.1873953938484192
# Epoch 179, Train Loss: 0.005094417370855808, Val Loss: 0.005174519959837198
# 验证集上的指标为:0.005443090572953224，总噪声为:0.025070490315556526,减少噪声0.019627399742603302,dae上的噪声0.19232793152332306
# Epoch 180, Train Loss: 0.00504295015707612, Val Loss: 0.005443090572953224
# 验证集上的指标为:0.005163098219782114，总噪声为:0.025070490315556526,减少噪声0.0199073925614357,dae上的噪声0.1816897690296173
# Epoch 181, Train Loss: 0.00479110749438405, Val Loss: 0.005163098219782114
# 验证集上的指标为:0.005423713009804487，总噪声为:0.025070490315556526,减少噪声0.01964677684009075,dae上的噪声0.20126183331012726
# Epoch 182, Train Loss: 0.004730965476483107, Val Loss: 0.005423713009804487
# 验证集上的指标为:0.005095191765576601，总噪声为:0.025070490315556526,减少噪声0.019975299015641212,dae上的噪声0.18436676263809204
# Epoch 183, Train Loss: 0.004515384323894978, Val Loss: 0.005095191765576601
# 验证集上的指标为:0.005416702013462782，总噪声为:0.025070490315556526,减少噪声0.019653787836432457,dae上的噪声0.19628387689590454
# Epoch 184, Train Loss: 0.00458959536626935, Val Loss: 0.005416702013462782
# 验证集上的指标为:0.005083281081169844，总噪声为:0.025070490315556526,减少噪声0.019987208768725395,dae上的噪声0.18317516148090363
# Epoch 185, Train Loss: 0.004960714839398861, Val Loss: 0.005083281081169844
# 验证集上的指标为:0.004943127278238535，总噪声为:0.025070490315556526,减少噪声0.02012736350297928,dae上的噪声0.19148239493370056
# Epoch 186, Train Loss: 0.005003031343221664, Val Loss: 0.004943127278238535
# 验证集上的指标为:0.004932391457259655，总噪声为:0.025070490315556526,减少噪声0.020138099789619446,dae上的噪声0.18741156160831451
# Epoch 187, Train Loss: 0.004671853501349688, Val Loss: 0.004932391457259655
# 验证集上的指标为:0.005282613914459944，总噪声为:0.025070490315556526,减少噪声0.019787875935435295,dae上的噪声0.17830459773540497
# Epoch 188, Train Loss: 0.004637901671230793, Val Loss: 0.005282613914459944
# 验证集上的指标为:0.005622793920338154，总噪声为:0.025070490315556526,减少噪声0.019447695463895798,dae上的噪声0.2012178599834442
# Epoch 189, Train Loss: 0.005440170876681805, Val Loss: 0.005622793920338154
# 验证集上的指标为:0.005239729303866625，总噪声为:0.025070490315556526,减少噪声0.01983076147735119,dae上的噪声0.20405644178390503
# Epoch 190, Train Loss: 0.005352109670639038, Val Loss: 0.005239729303866625
# 验证集上的指标为:0.004956059157848358，总噪声为:0.025070490315556526,减少噪声0.020114431157708168,dae上的噪声0.1920357644557953
# Epoch 191, Train Loss: 0.004555155523121357, Val Loss: 0.004956059157848358
# 验证集上的指标为:0.0049334438517689705，总噪声为:0.025070490315556526,减少噪声0.02013704553246498,dae上的噪声0.19313518702983856
# Epoch 192, Train Loss: 0.004413303919136524, Val Loss: 0.0049334438517689705
# 验证集上的指标为:0.0051862276159226894，总噪声为:0.025070490315556526,减少噪声0.01988426223397255,dae上的噪声0.18979308009147644
# Epoch 193, Train Loss: 0.004776818212121725, Val Loss: 0.0051862276159226894
# 验证集上的指标为:0.005363713949918747，总噪声为:0.025070490315556526,减少噪声0.01970677636563778,dae上的噪声0.1887056678533554
# Epoch 194, Train Loss: 0.004553838167339563, Val Loss: 0.005363713949918747
# 验证集上的指标为:0.0053292145021259785，总噪声为:0.025070490315556526,减少噪声0.019741276279091835,dae上的噪声0.19195204973220825
# Epoch 195, Train Loss: 0.004763373639434576, Val Loss: 0.0053292145021259785
# 验证集上的指标为:0.005128941033035517，总噪声为:0.025070490315556526,减少噪声0.019941549748182297,dae上的噪声0.19314265251159668
# Epoch 196, Train Loss: 0.004456310532987118, Val Loss: 0.005128941033035517
# 验证集上的指标为:0.005283072125166655，总噪声为:0.025070490315556526,减少噪声0.019787417724728584,dae上的噪声0.20361781120300293
# Epoch 197, Train Loss: 0.004775610286742449, Val Loss: 0.005283072125166655
# 验证集上的指标为:0.005114991217851639，总噪声为:0.025070490315556526,减少噪声0.019955499097704887,dae上的噪声0.19487370550632477
# Epoch 198, Train Loss: 0.00486097764223814, Val Loss: 0.005114991217851639
# 验证集上的指标为:0.005089857615530491，总噪声为:0.025070490315556526,减少噪声0.01998063176870346,dae上的噪声0.2058243602514267
# Epoch 199, Train Loss: 0.004998583346605301, Val Loss: 0.005089857615530491
# 验证集上的指标为:0.005105222575366497，总噪声为:0.025070490315556526,减少噪声0.019965268671512604,dae上的噪声0.19622348248958588
# Epoch 200, Train Loss: 0.004478829447180033, Val Loss: 0.005105222575366497
# 验证集上的指标为:0.005361860617995262，总噪声为:0.025070490315556526,减少噪声0.019708629697561264,dae上的噪声0.2114199697971344
# Epoch 201, Train Loss: 0.0048179770819842815, Val Loss: 0.005361860617995262
# 验证集上的指标为:0.005167639348655939，总噪声为:0.025070490315556526,减少噪声0.019902851432561874,dae上的噪声0.20923005044460297
# Epoch 202, Train Loss: 0.004651513881981373, Val Loss: 0.005167639348655939
# 验证集上的指标为:0.0052942316979169846，总噪声为:0.025070490315556526,减少噪声0.01977625861763954,dae上的噪声0.2182299941778183
# Epoch 203, Train Loss: 0.004307526163756847, Val Loss: 0.0052942316979169846
# 验证集上的指标为:0.005305587779730558，总噪声为:0.025070490315556526,减少噪声0.01976490207016468,dae上的噪声0.21352557837963104
# Epoch 204, Train Loss: 0.0046026441268622875, Val Loss: 0.005305587779730558
# 验证集上的指标为:0.005024469457566738，总噪声为:0.025070490315556526,减少噪声0.020046021789312363,dae上的噪声0.2079245001077652
# Epoch 205, Train Loss: 0.004474404267966747, Val Loss: 0.005024469457566738
# 验证集上的指标为:0.005140227731317282，总噪声为:0.025070490315556526,减少噪声0.019930262118577957,dae上的噪声0.21624818444252014
# Epoch 206, Train Loss: 0.005010079126805067, Val Loss: 0.005140227731317282
# 验证集上的指标为:0.005174547433853149，总噪声为:0.025070490315556526,减少噪声0.019895942881703377,dae上的噪声0.21605665981769562
# Epoch 207, Train Loss: 0.0054222955368459225, Val Loss: 0.005174547433853149
# 验证集上的指标为:0.005506861489266157，总噪声为:0.025070490315556526,减少噪声0.01956362836062908,dae上的噪声0.21220164000988007
# Epoch 208, Train Loss: 0.004818439949303865, Val Loss: 0.005506861489266157
# 验证集上的指标为:0.005425042472779751，总噪声为:0.025070490315556526,减少噪声0.01964544877409935,dae上的噪声0.21371422708034515
# Epoch 209, Train Loss: 0.005132652819156647, Val Loss: 0.005425042472779751
# 验证集上的指标为:0.005041369702666998，总噪声为:0.025070490315556526,减少噪声0.02002912014722824,dae上的噪声0.2174011468887329
# Epoch 210, Train Loss: 0.00454792520031333, Val Loss: 0.005041369702666998
# 验证集上的指标为:0.005355339031666517，总噪声为:0.025070490315556526,减少噪声0.01971515081822872,dae上的噪声0.204053595662117
# Epoch 211, Train Loss: 0.004874915815889835, Val Loss: 0.005355339031666517
# 验证集上的指标为:0.005235561169683933，总噪声为:0.025070490315556526,减少噪声0.01983492821455002,dae上的噪声0.20864897966384888
# Epoch 212, Train Loss: 0.004884182941168547, Val Loss: 0.005235561169683933
# 验证集上的指标为:0.0051803430542349815，总噪声为:0.025070490315556526,减少噪声0.01989014819264412,dae上的噪声0.20463569462299347
# Epoch 213, Train Loss: 0.005455720704048872, Val Loss: 0.0051803430542349815
# 验证集上的指标为:0.006586040370166302，总噪声为:0.025070490315556526,减少噪声0.0184844508767128,dae上的噪声0.22853103280067444
# Epoch 214, Train Loss: 0.0055381846614181995, Val Loss: 0.006586040370166302
# 验证集上的指标为:0.00585685670375824，总噪声为:0.025070490315556526,减少噪声0.019213633611798286,dae上的噪声0.2277151346206665
# Epoch 215, Train Loss: 0.005339996889233589, Val Loss: 0.00585685670375824
# 验证集上的指标为:0.004942276515066624，总噪声为:0.025070490315556526,减少噪声0.020128212869167328,dae上的噪声0.21983307600021362
# Epoch 216, Train Loss: 0.0050069126300513744, Val Loss: 0.004942276515066624
# 验证集上的指标为:0.005895938258618116，总噪声为:0.025070490315556526,减少噪声0.019174551591277122,dae上的噪声0.21115009486675262
# Epoch 217, Train Loss: 0.0051752543076872826, Val Loss: 0.005895938258618116
# 验证集上的指标为:0.005007047206163406，总噪声为:0.025070490315556526,减少噪声0.02006344310939312,dae上的噪声0.22299033403396606
# Epoch 218, Train Loss: 0.005070467479526997, Val Loss: 0.005007047206163406
# 验证集上的指标为:0.010331589728593826，总噪声为:0.025070490315556526,减少噪声0.0147389005869627,dae上的噪声0.231485515832901
# Epoch 219, Train Loss: 0.009884633123874664, Val Loss: 0.010331589728593826
# 验证集上的指标为:0.005273889750242233，总噪声为:0.025070490315556526,减少噪声0.019796600565314293,dae上的噪声0.2103641927242279
# Epoch 220, Train Loss: 0.005143163725733757, Val Loss: 0.005273889750242233
# 验证集上的指标为:0.005258892197161913，总噪声为:0.025070490315556526,减少噪声0.0198115985840559,dae上的噪声0.2174689769744873
# Epoch 221, Train Loss: 0.004756178241223097, Val Loss: 0.005258892197161913
# 验证集上的指标为:0.005191241391003132，总噪声为:0.025070490315556526,减少噪声0.01987924799323082,dae上的噪声0.22814635932445526
# Epoch 222, Train Loss: 0.004932939074933529, Val Loss: 0.005191241391003132
# 验证集上的指标为:0.005164318718016148，总噪声为:0.025070490315556526,减少噪声0.019906170666217804,dae上的噪声0.2151574343442917
# Epoch 223, Train Loss: 0.004480007104575634, Val Loss: 0.005164318718016148
# 验证集上的指标为:0.005330565385520458，总噪声为:0.025070490315556526,减少噪声0.019739925861358643,dae上的噪声0.2125527709722519
# Epoch 224, Train Loss: 0.005129232537001371, Val Loss: 0.005330565385520458
# 验证集上的指标为:0.005035850685089827，总噪声为:0.025070490315556526,减少噪声0.020034639164805412,dae上的噪声0.2172447293996811
# Epoch 225, Train Loss: 0.004825254436582327, Val Loss: 0.005035850685089827
# 验证集上的指标为:0.0062638032250106335，总噪声为:0.025070490315556526,减少噪声0.018806686624884605,dae上的噪声0.2233176827430725
# Epoch 226, Train Loss: 0.005089021287858486, Val Loss: 0.0062638032250106335
# 验证集上的指标为:0.005572948604822159，总噪声为:0.025070490315556526,减少噪声0.019497541710734367,dae上的噪声0.23488347232341766
# Epoch 227, Train Loss: 0.004980931058526039, Val Loss: 0.005572948604822159
# 验证集上的指标为:0.0050938865169882774，总噪声为:0.025070490315556526,减少噪声0.019976604729890823,dae上的噪声0.22661130130290985
# Epoch 228, Train Loss: 0.004993444308638573, Val Loss: 0.0050938865169882774
# 验证集上的指标为:0.0052217901684343815，总噪声为:0.025070490315556526,减少噪声0.019848700612783432,dae上的噪声0.23137903213500977
# Epoch 229, Train Loss: 0.004833612125366926, Val Loss: 0.0052217901684343815
# 验证集上的指标为:0.0051269750110805035，总噪声为:0.025070490315556526,减少噪声0.019943514838814735,dae上的噪声0.22106260061264038
# Epoch 230, Train Loss: 0.004673473536968231, Val Loss: 0.0051269750110805035
# 验证集上的指标为:0.005029669962823391，总噪声为:0.025070490315556526,减少噪声0.02004082128405571,dae上的噪声0.2269136607646942
# Epoch 231, Train Loss: 0.005264222621917725, Val Loss: 0.005029669962823391
# 验证集上的指标为:0.0051491037011146545，总噪声为:0.025070490315556526,减少噪声0.01992138661444187,dae上的噪声0.2229396253824234
# Epoch 232, Train Loss: 0.004919566214084625, Val Loss: 0.0051491037011146545
# 验证集上的指标为:0.005042721051722765，总噪声为:0.025070490315556526,减少噪声0.02002776972949505,dae上的噪声0.23010417819023132
# Epoch 233, Train Loss: 0.005029203835874796, Val Loss: 0.005042721051722765
# 验证集上的指标为:0.005169668234884739，总噪声为:0.025070490315556526,减少噪声0.019900821149349213,dae上的噪声0.2388623207807541
# Epoch 234, Train Loss: 0.004802598152309656, Val Loss: 0.005169668234884739
# 验证集上的指标为:0.005577768664807081，总噪声为:0.025070490315556526,减少噪声0.019492721185088158,dae上的噪声0.22412264347076416
# Epoch 235, Train Loss: 0.0048407684080302715, Val Loss: 0.005577768664807081
# 验证集上的指标为:0.005047245882451534，总噪声为:0.025070490315556526,减少噪声0.020023245364427567,dae上的噪声0.23184506595134735
# Epoch 236, Train Loss: 0.005541425198316574, Val Loss: 0.005047245882451534
# 验证集上的指标为:0.004905516281723976，总噪声为:0.025070490315556526,减少噪声0.02016497403383255,dae上的噪声0.23084330558776855
# Epoch 237, Train Loss: 0.005074742250144482, Val Loss: 0.004905516281723976
# 验证集上的指标为:0.004859671462327242，总噪声为:0.025070490315556526,减少噪声0.02021081931889057,dae上的噪声0.23351897299289703
# Epoch 238, Train Loss: 0.00418981583788991, Val Loss: 0.004859671462327242
# 验证集上的指标为:0.004905508831143379，总噪声为:0.025070490315556526,减少噪声0.020164981484413147,dae上的噪声0.23228584229946136
# Epoch 239, Train Loss: 0.004421033896505833, Val Loss: 0.004905508831143379
# 验证集上的指标为:0.0050361971370875835，总噪声为:0.025070490315556526,减少噪声0.020034292712807655,dae上的噪声0.2278260439634323
# Epoch 240, Train Loss: 0.00540973711758852, Val Loss: 0.0050361971370875835
# 验证集上的指标为:0.005263546481728554，总噪声为:0.025070490315556526,减少噪声0.019806943833827972,dae上的噪声0.22669556736946106
# Epoch 241, Train Loss: 0.00488954596221447, Val Loss: 0.005263546481728554
# 验证集上的指标为:0.005404184106737375，总噪声为:0.025070490315556526,减少噪声0.019666306674480438,dae上的噪声0.2566765546798706
# Epoch 242, Train Loss: 0.0051075066439807415, Val Loss: 0.005404184106737375
# 验证集上的指标为:0.005110809579491615，总噪声为:0.025070490315556526,减少噪声0.01995968073606491,dae上的噪声0.24480842053890228
# Epoch 243, Train Loss: 0.005114781204611063, Val Loss: 0.005110809579491615
# 验证集上的指标为:0.005229540169239044，总噪声为:0.025070490315556526,减少噪声0.019840950146317482,dae上的噪声0.24699781835079193
# Epoch 244, Train Loss: 0.004506964702159166, Val Loss: 0.005229540169239044
# 验证集上的指标为:0.004937715828418732，总噪声为:0.025070490315556526,减少噪声0.020132774487137794,dae上的噪声0.24934150278568268
# Epoch 245, Train Loss: 0.004726095590740442, Val Loss: 0.004937715828418732
# 验证集上的指标为:0.005260456819087267，总噪声为:0.025070490315556526,减少噪声0.019810033962130547,dae上的噪声0.231950581073761
# Epoch 246, Train Loss: 0.00488493824377656, Val Loss: 0.005260456819087267
# 验证集上的指标为:0.0049840351566672325，总噪声为:0.025070490315556526,减少噪声0.02008645609021187,dae上的噪声0.2496410608291626
# Epoch 247, Train Loss: 0.0048326714895665646, Val Loss: 0.0049840351566672325
# 验证集上的指标为:0.0054003107361495495，总噪声为:0.025070490315556526,减少噪声0.01967017911374569,dae上的噪声0.257890522480011
# Epoch 248, Train Loss: 0.004878385923802853, Val Loss: 0.0054003107361495495
# 验证集上的指标为:0.004925502929836512，总噪声为:0.025070490315556526,减少噪声0.020144987851381302,dae上的噪声0.2544856071472168
# Epoch 249, Train Loss: 0.004772057756781578, Val Loss: 0.004925502929836512
# 验证集上的指标为:0.005731115583330393，总噪声为:0.025070490315556526,减少噪声0.01933937519788742,dae上的噪声0.22645984590053558
# Epoch 250, Train Loss: 0.004916188772767782, Val Loss: 0.005731115583330393
# 验证集上的指标为:0.004954054951667786，总噪声为:0.025070490315556526,减少噪声0.02011643536388874,dae上的噪声0.2461501657962799
# Epoch 251, Train Loss: 0.004751036409288645, Val Loss: 0.004954054951667786
# 验证集上的指标为:0.005153467878699303，总噪声为:0.025070490315556526,减少噪声0.019917022436857224,dae上的噪声0.2637108266353607
# Epoch 252, Train Loss: 0.005020326003432274, Val Loss: 0.005153467878699303
# 验证集上的指标为:0.005050459876656532，总噪声为:0.025070490315556526,减少噪声0.020020030438899994,dae上的噪声0.2627376317977905
# Epoch 253, Train Loss: 0.006389236077666283, Val Loss: 0.005050459876656532
# 验证集上的指标为:0.005799056496471167，总噪声为:0.025070490315556526,减少噪声0.019271433353424072,dae上的噪声0.26175224781036377
# Epoch 254, Train Loss: 0.004492481239140034, Val Loss: 0.005799056496471167
# 验证集上的指标为:0.004997552838176489，总噪声为:0.025070490315556526,减少噪声0.02007293701171875,dae上的噪声0.2559412717819214
# Epoch 255, Train Loss: 0.005092105362564325, Val Loss: 0.004997552838176489
# 验证集上的指标为:0.0049874987453222275，总噪声为:0.025070490315556526,减少噪声0.0200829915702343,dae上的噪声0.2603450417518616
# Epoch 256, Train Loss: 0.005306137725710869, Val Loss: 0.0049874987453222275
# 验证集上的指标为:0.00612060958519578，总噪声为:0.025070490315556526,减少噪声0.018949881196022034,dae上的噪声0.2678270936012268
# Epoch 257, Train Loss: 0.004947935231029987, Val Loss: 0.00612060958519578
# 验证集上的指标为:0.0049139815382659435，总噪声为:0.025070490315556526,减少噪声0.020156508311629295,dae上的噪声0.257031112909317
# Epoch 258, Train Loss: 0.004634988959878683, Val Loss: 0.0049139815382659435
# 验证集上的指标为:0.005056212656199932，总噪声为:0.025070490315556526,减少噪声0.02001427859067917,dae上的噪声0.2666933834552765
# Epoch 259, Train Loss: 0.005088976584374905, Val Loss: 0.005056212656199932
# 验证集上的指标为:0.005204669199883938，总噪声为:0.025070490315556526,减少噪声0.019865822046995163,dae上的噪声0.25230929255485535
# Epoch 260, Train Loss: 0.005394405219703913, Val Loss: 0.005204669199883938
# 验证集上的指标为:0.005049203522503376，总噪声为:0.025070490315556526,减少噪声0.020021285861730576,dae上的噪声0.2525239884853363
# Epoch 261, Train Loss: 0.00450904481112957, Val Loss: 0.005049203522503376
# 验证集上的指标为:0.005480414256453514，总噪声为:0.025070490315556526,减少噪声0.019590076059103012,dae上的噪声0.25124844908714294
# Epoch 262, Train Loss: 0.006549780257046223, Val Loss: 0.005480414256453514
# ...
# Epoch 513, Train Loss: 0.0044883182272315025, Val Loss: 0.005081211216747761
# 验证集上的指标为:0.004974947310984135，总噪声为:0.025070490315556526,减少噪声0.020095542073249817,dae上的噪声0.4841221570968628
# Epoch 514, Train Loss: 0.00481620104983449, Val Loss: 0.004974947310984135
# 验证集上的指标为:0.0052991327829658985，总噪声为:0.025070490315556526,减少噪声0.019771357998251915,dae上的噪声0.4971078038215637
# Epoch 515, Train Loss: 0.004707037936896086, Val Loss: 0.0052991327829658985
# 验证集上的指标为:0.00529001047834754，总噪声为:0.025070490315556526,减少噪声0.0197804793715477,dae上的噪声0.4970671236515045
# Epoch 516, Train Loss: 0.004738952964544296, Val Loss: 0.00529001047834754
# 验证集上的指标为:0.004937663674354553，总噪声为:0.025070490315556526,减少噪声0.020132826641201973,dae上的噪声0.49770814180374146
# Epoch 517, Train Loss: 0.00522508705034852, Val Loss: 0.004937663674354553
# 验证集上的指标为:0.005437732674181461，总噪声为:0.025070490315556526,减少噪声0.01963275671005249,dae上的噪声0.5058525204658508
# Epoch 518, Train Loss: 0.005614493042230606, Val Loss: 0.005437732674181461
# 验证集上的指标为:0.0049845133908092976，总噪声为:0.025070490315556526,减少噪声0.020085977390408516,dae上的噪声0.4883524477481842
# Epoch 519, Train Loss: 0.004703416023403406, Val Loss: 0.0049845133908092976
# 验证集上的指标为:0.005519818048924208，总噪声为:0.025070490315556526,减少噪声0.01955067180097103,dae上的噪声0.5052152276039124
# Epoch 520, Train Loss: 0.00501967640593648, Val Loss: 0.005519818048924208
# 验证集上的指标为:0.006099552381783724，总噪声为:0.025070490315556526,减少噪声0.01897093839943409,dae上的噪声0.5089137554168701
# Epoch 521, Train Loss: 0.005917815491557121, Val Loss: 0.006099552381783724
# 验证集上的指标为:0.0049914107657969，总噪声为:0.025070490315556526,减少噪声0.020079080015420914,dae上的噪声0.4745902419090271
# Epoch 522, Train Loss: 0.00466173468157649, Val Loss: 0.0049914107657969
# 验证集上的指标为:0.005590622313320637，总噪声为:0.025070490315556526,减少噪声0.019479867070913315,dae上的噪声0.5073614716529846
# Epoch 523, Train Loss: 0.00547129986807704, Val Loss: 0.005590622313320637
# 验证集上的指标为:0.005446994677186012，总噪声为:0.025070490315556526,减少噪声0.019623495638370514,dae上的噪声0.4907071888446808
# Epoch 524, Train Loss: 0.005180371925234795, Val Loss: 0.005446994677186012
# 验证集上的指标为:0.005050813313573599，总噪声为:0.025070490315556526,减少噪声0.02001967653632164,dae上的噪声0.503849446773529
# Epoch 525, Train Loss: 0.007876098155975342, Val Loss: 0.005050813313573599
# 验证集上的指标为:0.004954773932695389，总噪声为:0.025070490315556526,减少噪声0.020115716382861137,dae上的噪声0.5070878863334656
# Epoch 526, Train Loss: 0.004832438658922911, Val Loss: 0.004954773932695389
# 验证集上的指标为:0.00537719763815403，总噪声为:0.025070490315556526,减少噪声0.019693292677402496,dae上的噪声0.5290167927742004
# Epoch 527, Train Loss: 0.004876133985817432, Val Loss: 0.00537719763815403
# 验证集上的指标为:0.006002104841172695，总噪声为:0.025070490315556526,减少噪声0.019068386405706406,dae上的噪声0.46870794892311096
# Epoch 528, Train Loss: 0.00523056834936142, Val Loss: 0.006002104841172695
# 验证集上的指标为:0.005031817127019167，总噪声为:0.025070490315556526,减少噪声0.020038673654198647,dae上的噪声0.5127606987953186
# Epoch 529, Train Loss: 0.004517784342169762, Val Loss: 0.005031817127019167
# 验证集上的指标为:0.004928921815007925，总噪声为:0.025070490315556526,减少噪声0.020141568034887314,dae上的噪声0.4958263337612152
# Epoch 530, Train Loss: 0.004546480253338814, Val Loss: 0.004928921815007925
# 验证集上的指标为:0.005110789556056261，总噪声为:0.025070490315556526,减少噪声0.019959701225161552,dae上的噪声0.5007971525192261
# Epoch 531, Train Loss: 0.0046128504909574986, Val Loss: 0.005110789556056261
# 验证集上的指标为:0.005147390533238649，总噪声为:0.025070490315556526,减少噪声0.019923100247979164,dae上的噪声0.4999414086341858
# Epoch 532, Train Loss: 0.004693205468356609, Val Loss: 0.005147390533238649
# 验证集上的指标为:0.004936330020427704，总噪声为:0.025070490315556526,减少噪声0.020134160295128822,dae上的噪声0.48993468284606934
# Epoch 533, Train Loss: 0.0045323302038013935, Val Loss: 0.004936330020427704
# 验证集上的指标为:0.005620426032692194，总噪声为:0.025070490315556526,减少噪声0.01945006474852562,dae上的噪声0.516170859336853
# Epoch 534, Train Loss: 0.006564500741660595, Val Loss: 0.005620426032692194
# 验证集上的指标为:0.005577355157583952，总噪声为:0.025070490315556526,减少噪声0.019493134692311287,dae上的噪声0.47998446226119995
# Epoch 535, Train Loss: 0.005031874403357506, Val Loss: 0.005577355157583952
# 验证集上的指标为:0.005136006511747837，总噪声为:0.025070490315556526,减少噪声0.019934482872486115,dae上的噪声0.503665566444397
# Epoch 536, Train Loss: 0.004906199406832457, Val Loss: 0.005136006511747837
# 验证集上的指标为:0.004993653390556574，总噪声为:0.025070490315556526,减少噪声0.02007683739066124,dae上的噪声0.5059875249862671
# Epoch 537, Train Loss: 0.0050642965361475945, Val Loss: 0.004993653390556574
# 验证集上的指标为:0.005092279519885778，总噪声为:0.025070490315556526,减少噪声0.01997821033000946,dae上的噪声0.48256340622901917
# Epoch 538, Train Loss: 0.004680236801505089, Val Loss: 0.005092279519885778
# 验证集上的指标为:0.005030161701142788，总噪声为:0.025070490315556526,减少噪声0.020040329545736313,dae上的噪声0.4958195090293884
# Epoch 539, Train Loss: 0.0049005053006112576, Val Loss: 0.005030161701142788
# 验证集上的指标为:0.005204937886446714，总噪声为:0.025070490315556526,减少噪声0.019865551963448524,dae上的噪声0.5265560746192932
# Epoch 540, Train Loss: 0.004695916082710028, Val Loss: 0.005204937886446714
# 验证集上的指标为:0.005368400365114212，总噪声为:0.025070490315556526,减少噪声0.019702089950442314,dae上的噪声0.5073150396347046
# Epoch 541, Train Loss: 0.004739478696137667, Val Loss: 0.005368400365114212
# 验证集上的指标为:0.005091993138194084，总噪声为:0.025070490315556526,减少噪声0.019978497177362442,dae上的噪声0.5051822066307068
# Epoch 542, Train Loss: 0.005287858657538891, Val Loss: 0.005091993138194084
# 验证集上的指标为:0.005031574051827192，总噪声为:0.025070490315556526,减少噪声0.020038915798068047,dae上的噪声0.5137810707092285
# Epoch 543, Train Loss: 0.004418900236487389, Val Loss: 0.005031574051827192
# 验证集上的指标为:0.005439563654363155，总噪声为:0.025070490315556526,减少噪声0.019630927592515945,dae上的噪声0.5146740078926086
# Epoch 544, Train Loss: 0.004831000231206417, Val Loss: 0.005439563654363155
# 验证集上的指标为:0.005217761732637882，总噪声为:0.025070490315556526,减少噪声0.01985272765159607,dae上的噪声0.49438685178756714
# Epoch 545, Train Loss: 0.005196195561438799, Val Loss: 0.005217761732637882
# 验证集上的指标为:0.005177783779799938，总噪声为:0.025070490315556526,减少噪声0.019892707467079163,dae上的噪声0.45549720525741577
# Epoch 546, Train Loss: 0.005061928648501635, Val Loss: 0.005177783779799938
# 验证集上的指标为:0.005012388341128826，总噪声为:0.025070490315556526,减少噪声0.020058102905750275,dae上的噪声0.4909908175468445
# Epoch 547, Train Loss: 0.005911681801080704, Val Loss: 0.005012388341128826
# 验证集上的指标为:0.005067041143774986，总噪声为:0.025070490315556526,减少噪声0.02000344917178154,dae上的噪声0.4765593707561493
# Epoch 548, Train Loss: 0.004798600450158119, Val Loss: 0.005067041143774986
# 验证集上的指标为:0.00503270048648119，总噪声为:0.025070490315556526,减少噪声0.020037788897752762,dae上的噪声0.501105010509491
# Epoch 549, Train Loss: 0.004664134234189987, Val Loss: 0.00503270048648119
# 验证集上的指标为:0.005113469436764717，总噪声为:0.025070490315556526,减少噪声0.01995702087879181,dae上的噪声0.48961713910102844
# Epoch 550, Train Loss: 0.004600435961037874, Val Loss: 0.005113469436764717
# 验证集上的指标为:0.005078813526779413，总噪声为:0.025070490315556526,减少噪声0.0199916772544384,dae上的噪声0.5252004861831665
# Epoch 551, Train Loss: 0.005301675759255886, Val Loss: 0.005078813526779413
# 验证集上的指标为:0.0050438749603927135，总噪声为:0.025070490315556526,减少噪声0.020026614889502525,dae上的噪声0.525202214717865
# Epoch 552, Train Loss: 0.005247113294899464, Val Loss: 0.0050438749603927135
# 验证集上的指标为:0.005003796890377998，总噪声为:0.025070490315556526,减少噪声0.020066693425178528,dae上的噪声0.5067132711410522
# Epoch 553, Train Loss: 0.004809428006410599, Val Loss: 0.005003796890377998
# 验证集上的指标为:0.005042091943323612，总噪声为:0.025070490315556526,减少噪声0.02002839744091034,dae上的噪声0.49850016832351685
# Epoch 554, Train Loss: 0.005613452754914761, Val Loss: 0.005042091943323612
# 验证集上的指标为:0.004967643413692713，总噪声为:0.025070490315556526,减少噪声0.0201028473675251,dae上的噪声0.5159281492233276
# Epoch 555, Train Loss: 0.0045749591663479805, Val Loss: 0.004967643413692713
# 验证集上的指标为:0.005579392425715923，总噪声为:0.025070490315556526,减少噪声0.019491098821163177,dae上的噪声0.5300485491752625
# Epoch 556, Train Loss: 0.004919340834021568, Val Loss: 0.005579392425715923
# 验证集上的指标为:0.0051012178882956505，总噪声为:0.025070490315556526,减少噪声0.01996927335858345,dae上的噪声0.5065805315971375
# Epoch 557, Train Loss: 0.004772847518324852, Val Loss: 0.0051012178882956505
# 验证集上的指标为:0.005448841955512762，总噪声为:0.025070490315556526,减少噪声0.019621647894382477,dae上的噪声0.5278341770172119
# Epoch 558, Train Loss: 0.005055712535977364, Val Loss: 0.005448841955512762
# 验证集上的指标为:0.006045096088200808，总噪声为:0.025070490315556526,减少噪声0.019025394693017006,dae上的噪声0.4763265550136566
# Epoch 559, Train Loss: 0.005788610782474279, Val Loss: 0.006045096088200808
# 验证集上的指标为:0.005053636152297258，总噪声为:0.025070490315556526,减少噪声0.020016854628920555,dae上的噪声0.5056160092353821
# Epoch 560, Train Loss: 0.005004002712666988, Val Loss: 0.005053636152297258
# 验证集上的指标为:0.005129465367645025，总噪声为:0.025070490315556526,减少噪声0.019941024482250214,dae上的噪声0.509985625743866
# Epoch 561, Train Loss: 0.004864260088652372, Val Loss: 0.005129465367645025
# 验证集上的指标为:0.0050664073787629604，总噪声为:0.025070490315556526,减少噪声0.02000408247113228,dae上的噪声0.5029909014701843
# Epoch 562, Train Loss: 0.004698002710938454, Val Loss: 0.0050664073787629604
# 验证集上的指标为:0.005285290535539389，总噪声为:0.025070490315556526,减少噪声0.01978519931435585,dae上的噪声0.5309115052223206
# Epoch 563, Train Loss: 0.004804291296750307, Val Loss: 0.005285290535539389
# 验证集上的指标为:0.005194026045501232，总噪声为:0.025070490315556526,减少噪声0.01987646520137787,dae上的噪声0.5397617220878601
# Epoch 564, Train Loss: 0.004647506400942802, Val Loss: 0.005194026045501232
# 验证集上的指标为:0.0051246145740151405，总噪声为:0.025070490315556526,减少噪声0.01994587481021881,dae上的噪声0.5103080868721008
# Epoch 565, Train Loss: 0.004565193317830563, Val Loss: 0.0051246145740151405
# 验证集上的指标为:0.004918653052300215，总噪声为:0.025070490315556526,减少噪声0.020151836797595024,dae上的噪声0.5248998403549194
# Epoch 566, Train Loss: 0.0048253522254526615, Val Loss: 0.004918653052300215
# 验证集上的指标为:0.004970269277691841，总噪声为:0.025070490315556526,减少噪声0.020100221037864685,dae上的噪声0.5191402435302734
# Epoch 567, Train Loss: 0.004504444543272257, Val Loss: 0.004970269277691841
# 验证集上的指标为:0.005169074982404709，总噪声为:0.025070490315556526,减少噪声0.019901415333151817,dae上的噪声0.5101094841957092
# Epoch 568, Train Loss: 0.004531309474259615, Val Loss: 0.005169074982404709
# 验证集上的指标为:0.005125765223056078，总噪声为:0.025070490315556526,减少噪声0.019944725558161736,dae上的噪声0.5250574946403503
# Epoch 569, Train Loss: 0.004950738977640867, Val Loss: 0.005125765223056078
# 验证集上的指标为:0.007588018663227558，总噪声为:0.025070490315556526,减少噪声0.017482470721006393,dae上的噪声0.5602014064788818
# Epoch 570, Train Loss: 0.0069441297091543674, Val Loss: 0.007588018663227558
# 验证集上的指标为:0.005415438208729029，总噪声为:0.025070490315556526,减少噪声0.019655052572488785,dae上的噪声0.49907252192497253
# Epoch 571, Train Loss: 0.0048258607275784016, Val Loss: 0.005415438208729029
# 验证集上的指标为:0.005448286421597004，总噪声为:0.025070490315556526,减少噪声0.019622202962636948,dae上的噪声0.534349799156189
# Epoch 572, Train Loss: 0.004991856869310141, Val Loss: 0.005448286421597004
# 验证集上的指标为:0.004960876889526844，总噪声为:0.025070490315556526,减少噪声0.020109612494707108,dae上的噪声0.5140383839607239
# Epoch 573, Train Loss: 0.004392470233142376, Val Loss: 0.004960876889526844
# 验证集上的指标为:0.005057020112872124，总噪声为:0.025070490315556526,减少噪声0.020013470202684402,dae上的噪声0.5208947658538818
# Epoch 574, Train Loss: 0.0045192609541118145, Val Loss: 0.005057020112872124
# 验证集上的指标为:0.005054154898971319，总噪声为:0.025070490315556526,减少噪声0.02001633495092392,dae上的噪声0.544942319393158
# Epoch 575, Train Loss: 0.004623983055353165, Val Loss: 0.005054154898971319
# 验证集上的指标为:0.005366783123463392，总噪声为:0.025070490315556526,减少噪声0.019703706726431847,dae上的噪声0.5220203399658203
# Epoch 576, Train Loss: 0.004532745108008385, Val Loss: 0.005366783123463392
# 验证集上的指标为:0.004986010491847992，总噪声为:0.025070490315556526,减少噪声0.020084479823708534,dae上的噪声0.5181565284729004
# Epoch 577, Train Loss: 0.004669307731091976, Val Loss: 0.004986010491847992
# 验证集上的指标为:0.005170766729861498，总噪声为:0.025070490315556526,减少噪声0.019899724051356316,dae上的噪声0.5194889307022095
# Epoch 578, Train Loss: 0.004471661522984505, Val Loss: 0.005170766729861498
# 验证集上的指标为:0.005341097712516785，总噪声为:0.025070490315556526,减少噪声0.01972939260303974,dae上的噪声0.5443657040596008
# Epoch 579, Train Loss: 0.004526128061115742, Val Loss: 0.005341097712516785
# 验证集上的指标为:0.005193402525037527，总噪声为:0.025070490315556526,减少噪声0.019877087324857712,dae上的噪声0.5497134327888489
# Epoch 580, Train Loss: 0.005250273738056421, Val Loss: 0.005193402525037527
# 验证集上的指标为:0.0050157103687524796，总噪声为:0.025070490315556526,减少噪声0.020054779946804047,dae上的噪声0.5280202031135559
# Epoch 581, Train Loss: 0.0043797059915959835, Val Loss: 0.0050157103687524796
# 验证集上的指标为:0.005063381977379322，总噪声为:0.025070490315556526,减少噪声0.02000710740685463,dae上的噪声0.5432407259941101
# Epoch 582, Train Loss: 0.004689827095717192, Val Loss: 0.005063381977379322
# 验证集上的指标为:0.005586766637861729，总噪声为:0.025070490315556526,减少噪声0.019483722746372223,dae上的噪声0.5547885298728943
# Epoch 583, Train Loss: 0.005588792730122805, Val Loss: 0.005586766637861729
# 验证集上的指标为:0.0052016121335327625，总噪声为:0.025070490315556526,减少噪声0.01986887864768505,dae上的噪声0.5473723411560059
# Epoch 584, Train Loss: 0.004802617710083723, Val Loss: 0.0052016121335327625
# 验证集上的指标为:0.005016771610826254，总噪声为:0.025070490315556526,减少噪声0.020053718239068985,dae上的噪声0.5452041625976562
# Epoch 585, Train Loss: 0.005007556173950434, Val Loss: 0.005016771610826254
# 验证集上的指标为:0.004982552491128445，总噪声为:0.025070490315556526,减少噪声0.020087938755750656,dae上的噪声0.5407414436340332
# Epoch 586, Train Loss: 0.004586437717080116, Val Loss: 0.004982552491128445
# 验证集上的指标为:0.00500351469963789，总噪声为:0.025070490315556526,减少噪声0.02006697654724121,dae上的噪声0.539211094379425
# Epoch 587, Train Loss: 0.004647628404200077, Val Loss: 0.00500351469963789
# 验证集上的指标为:0.005470791831612587，总噪声为:0.025070490315556526,减少噪声0.01959969848394394,dae上的噪声0.5590856671333313
# Epoch 588, Train Loss: 0.0049963416531682014, Val Loss: 0.005470791831612587
# 验证集上的指标为:0.006411395035684109，总噪声为:0.025070490315556526,减少噪声0.018659096211194992,dae上的噪声0.5744243264198303
# Epoch 589, Train Loss: 0.007307400926947594, Val Loss: 0.006411395035684109
# 验证集上的指标为:0.005207929760217667，总噪声为:0.025070490315556526,减少噪声0.01986256055533886,dae上的噪声0.5358644723892212
# Epoch 590, Train Loss: 0.004541956353932619, Val Loss: 0.005207929760217667
# 验证集上的指标为:0.005006630439311266，总噪声为:0.025070490315556526,减少噪声0.020063860341906548,dae上的噪声0.5434873700141907
# Epoch 591, Train Loss: 0.004548028111457825, Val Loss: 0.005006630439311266
# 验证集上的指标为:0.005028560757637024，总噪声为:0.025070490315556526,减少噪声0.020041929557919502,dae上的噪声0.5369190573692322
# Epoch 592, Train Loss: 0.0045836628414690495, Val Loss: 0.005028560757637024
# 验证集上的指标为:0.005714825354516506，总噪声为:0.025070490315556526,减少噪声0.019355665892362595,dae上的噪声0.5270683765411377
# Epoch 593, Train Loss: 0.00508100027218461, Val Loss: 0.005714825354516506
# 验证集上的指标为:0.005073668900877237，总噪声为:0.025070490315556526,减少噪声0.019996821880340576,dae上的噪声0.5574786067008972
# Epoch 594, Train Loss: 0.0045257508754730225, Val Loss: 0.005073668900877237
# 验证集上的指标为:0.005136220715939999，总噪声为:0.025070490315556526,减少噪声0.019934270530939102,dae上的噪声0.5281871557235718
# Epoch 595, Train Loss: 0.005696347448974848, Val Loss: 0.005136220715939999
# 验证集上的指标为:0.0050930664874613285，总噪声为:0.025070490315556526,减少噪声0.019977424293756485,dae上的噪声0.5599867105484009
# Epoch 596, Train Loss: 0.004708981141448021, Val Loss: 0.0050930664874613285
# 验证集上的指标为:0.005152176134288311，总噪声为:0.025070490315556526,减少噪声0.01991831511259079,dae上的噪声0.5572317838668823
# Epoch 597, Train Loss: 0.004636474419385195, Val Loss: 0.005152176134288311
# 验证集上的指标为:0.005258422344923019，总噪声为:0.025070490315556526,减少噪声0.019812067970633507,dae上的噪声0.561717689037323
# Epoch 598, Train Loss: 0.005890719126909971, Val Loss: 0.005258422344923019
# 验证集上的指标为:0.005053270608186722，总噪声为:0.025070490315556526,减少噪声0.020017219707369804,dae上的噪声0.5427624583244324
# Epoch 599, Train Loss: 0.004511481150984764, Val Loss: 0.005053270608186722
# 验证集上的指标为:0.005572948604822159，总噪声为:0.025070490315556526,减少噪声0.019497541710734367,dae上的噪声0.5124963521957397
# Epoch 600, Train Loss: 0.005109848920255899, Val Loss: 0.005572948604822159

# %%
model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task12_piae5_best.pth', weights_only=True))
dae_model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task12_dae1_best.pth', weights_only=True))

model.eval()
with torch.no_grad():
    val_dae_out = dae_model(val_input)
    val_feat = torch.diff(val_dae_out,dim=1)

    # # 真值的
    # val_edagepoint = val_edge[:,0:2,:]
    # val_endstate = val_edge[:,2,:]
    
    # 重构的
    val_edagepoint = torch.stack([val_dae_out[:,0,:],val_dae_out[:,-1,:]],dim=1)
    val_ve = torch.sqrt((val_dae_out[:,-1,1]-val_dae_out[:,-2,1])**2 +(val_dae_out[:,-1,0]-val_dae_out[:,-2,0])**2)/torch.tensor(0.1)
    val_phie = torch.arctan2(val_dae_out[:,-1,1]-val_dae_out[:,-2,1],val_dae_out[:,-1,0]-val_dae_out[:,-2,0])
    val_endstate = torch.stack([val_ve,val_phie],dim=1)

    val_output,val_action = model(val_feat,val_edagepoint,val_endstate)
    val_loss = criterion(val_output,val_label)
    orig_err = criterion(val_input, val_label)

print(f'验证集上的指标为:{val_loss}，总噪声为:{orig_err},减少噪声{orig_err-val_loss}')
# Out:
# 验证集上的指标为:0.004859671462327242，总噪声为:0.025070490315556526,减少噪声0.02021081931889057

# %%
plt.figure(figsize=(8, 6))
# 绘制原始轨迹
import numpy as np
# num = 845
num = np.random.randint(0,30000)
# num = 0
plt.plot(val_label.cpu().numpy()[num, :,0], val_label.cpu().numpy()[num, :,1], '-o',c='blue', label='Original Data')
plt.plot(val_input.cpu().numpy()[num, :,0], val_input.cpu().numpy()[num, :,1], '.-',c='g', label='Noisy Data')
plt.plot(val_dae_out.cpu().numpy()[num, :,0], val_dae_out.cpu().numpy()[num, :,1], '.-',c='c', label='DAE Data')
plt.plot(val_output.cpu().numpy()[num, :,0], val_output.cpu().numpy()[num, :,1], '*-', c='red', label='Reconstructed Data')
plt.title('Reconstructed Trajectory')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.axis('equal')
plt.show()

# %%
# 定义专门用来重构轨迹的类, 计算误差ADE

class Reconstruct_Traj(Vehicle_Model_Methods):

    def __init__(self):
        super(Reconstruct_Traj, self).__init__()

    def ADE_err(self,out,label):
        ade = ((out - label) ** 2).sum(dim=2).sqrt().mean()
        return ade
    
    def calculate(self,actions,edagepoint,endstate,mode,labels):

        ax = actions[:,:,0]
        delta = actions[:,:,1]

        if mode == 'init_one':
            out = self.initial_unidirectional_reconstruct(ax,delta,edagepoint,endstate)
        elif mode == 'init_two':
            out = self.initial_bidirectional_reconstruct(ax,delta,edagepoint,endstate)
        elif mode == 'two_point':
            out,condtion = self.two_point_reconstruct(ax, delta, edagepoint, endstate)
        else:
            print(f'没有重构模式{mode}')
            out = torch.zeros(labels.shape, dtype=torch.float32, device=labels.device)
        
        loss_err = self.ADE_err(out,labels)

        loss_err = loss_err.cpu().numpy()

        return loss_err

# %%
recon_tarj = Reconstruct_Traj()

err_init_one = recon_tarj.calculate(val_action,val_edagepoint,val_endstate,'init_one',val_label)
print('单点单向重构误差',err_init_one)

err_init_two = recon_tarj.calculate(val_action,val_edagepoint,val_endstate,'init_two',val_label)
print('单点双向重构误差',err_init_two)

err_two_point = recon_tarj.calculate(val_action,val_edagepoint,val_endstate,'two_point',val_label)
print('单点单向重构误差',err_two_point)
# Out:
# 单点单向重构误差 0.41712937
# 单点双向重构误差 0.079154834
# 求解成了～           单点单向重构误差 0.23021017
