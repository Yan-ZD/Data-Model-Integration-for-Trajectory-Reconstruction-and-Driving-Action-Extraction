# %% [markdown]
# 训练自编码器
#
# 1. 用含噪声的数据训练
# 2. 再降噪自编码器的输出的基础上进行重构
#
# ---
#
# 训练结果：

# %%
# 直接训练
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import pickle
import os

from torch.utils.tensorboard import SummaryWriter

from model.PIAE_models import T7PIAE5,T7DAE1,Vehicle_Model_Methods

# 检查是否有可用的GPU
if torch.cuda.is_available():
    print('显卡参与训练')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 训练开始前启用 PyTorch 的异常检测
torch.autograd.set_detect_anomaly(True)
# Out:
# 显卡参与训练

# %%
# 加载数据
# 1. 加载预处理后的数据
##

def load_preprocessed_data(input_file):
    with open(input_file, 'rb') as f:
        data = pickle.load(f)
    return data

input_file = '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/data/Task2_data'  # 替换为你保存的.pkl文件路径
# 标准真值轨迹，标准噪声轨迹，标准化参数， 真值轨迹初值，噪声轨迹初值
tarin_data = load_preprocessed_data(os.path.join(input_file,'train_noisy_data.kpl'))

dataset = TensorDataset(tarin_data[0],tarin_data[1],tarin_data[3])
dataloader = DataLoader(dataset, batch_size=1000, shuffle=True)


val_data = load_preprocessed_data(os.path.join(input_file,'val_noisy_data.kpl'))

val_label = val_data[0].to(device)
val_input = val_data[1].to(device)
val_edge = val_data[3].to(device)

# %%
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()

    def forward(self,outputs, targets, actions):

        mse_loss = nn.MSELoss()(outputs, targets)

        # 平滑loss
        ax = actions[:, :, 0]
        delta = actions[:, :, 1]

        loss_ax = torch.mean(torch.abs(torch.diff(ax,dim=1)))
        loss_delta = torch.mean(torch.abs(torch.diff(delta,dim=1)))*10
    
        return mse_loss + 1e-3*(loss_ax+loss_delta)

# %%
# 3. 定义模型、损失函数和优化器
#模型
model = T7PIAE5(torch.tensor(10),torch.tensor(0.25))
model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/good_models/20250320_Task5-1_T7PIAE5.pth', weights_only=True))
model.to(device)


# DAE模型
dae_model = T7DAE1()
dae_model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/good_models/20250316_Task6_T7DAE1.pth', weights_only=True))

dae_model.to(device)


# 损失函数
criterion = nn.MSELoss()
criterion_train = CustomLoss()

# 优化器
optimizer = optim.Adam([
    {'params': model.parameters(), 'lr': 1.0e-4},
    {'params': dae_model.parameters(), 'lr': 1.0e-6}
    ]) # lr=0.001

# %%
# %clear

# 创建一个SummaryWriter对象，指定日志保存的路径
writer = SummaryWriter('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/logs/log9')


# 4. 训练模型Autoencoder
epochs = 600

best_loss = float('inf')

for epoch in range(epochs):
    
    model.train()  # 确保模型处于训练模式
    for batch_idx, (label,input,edge) in enumerate(dataloader):  
        # 添加噪声
        
        label = label.to(device)  # 将输入数据移动到同一设备
        input = input.to(device)

        # with torch.no_grad():
        dae_out = dae_model(input)

        dae_loss = nn.MSELoss()(dae_out,label)

        feat = torch.diff(dae_out,dim=1)

        # # 真值边界
        # edagepoint = edge[:,0:2,:]
        # endstate = edge[:,2,:]

        # 重构的
        edagepoint = torch.stack([dae_out[:,0,:],dae_out[:,-1,:]],dim=1)
        ve = torch.sqrt((dae_out[:,-1,1]-dae_out[:,-2,1])**2 +(dae_out[:,-1,0]-dae_out[:,-2,0])**2)/torch.tensor(0.1)
        phie = torch.arctan2(dae_out[:,-1,1]-dae_out[:,-2,1],dae_out[:,-1,0]-dae_out[:,-2,0])
        endstate = torch.stack([ve,phie],dim=1)

        optimizer.zero_grad()
        outputs,actions = model(feat,edagepoint,endstate)

        loss = criterion_train(outputs, label,actions)
        # loss = criterion(outputs, dae_out)
        loss.backward()
        optimizer.step()


    model.eval()
    with torch.no_grad():
        val_dae_out = dae_model(val_input)
        val_feat = torch.diff(val_dae_out,dim=1)

        # # 真值的
        # val_edagepoint = val_edge[:,0:2,:]
        # val_endstate = val_edge[:,2,:]
        # 重构的
        val_edagepoint = torch.stack([val_dae_out[:,0,:],val_dae_out[:,-1,:]],dim=1)
        val_ve = torch.sqrt((val_dae_out[:,-1,1]-val_dae_out[:,-2,1])**2 +(val_dae_out[:,-1,0]-val_dae_out[:,-2,0])**2)/torch.tensor(0.1)
        val_phie = torch.arctan2(val_dae_out[:,-1,1]-val_dae_out[:,-2,1],val_dae_out[:,-1,0]-val_dae_out[:,-2,0])
        val_endstate = torch.stack([val_ve,val_phie],dim=1)


        val_output,val_action = model(val_feat,val_edagepoint,val_endstate)
        val_loss = criterion(val_output,val_label)
        orig_err = criterion(val_input, val_label)
        val_dae_loss = criterion(val_dae_out,val_label)

    print(f'验证集上的指标为:{val_loss}，总噪声为:{orig_err},减少噪声{orig_err-val_loss},dae上的噪声{val_dae_loss}')
    
    # torch.save(model.state_dict(), f'/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test6_piae_good/model/Task8_trained_model/model_{epoch:03}.pth')
    if val_loss.item() < best_loss :
        # 保存模型
        torch.save(model.state_dict(), '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task9_piae5_best.pth')
        torch.save(dae_model.state_dict(), '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task9_dae1_best.pth')
        best_loss = val_loss.item()


    print(f'Epoch {epoch+1}, Train Loss: {loss.item()}, Val Loss: {val_loss.item()}')
    # print()
    # 使用SummaryWriter记录数据
    writer.add_scalar('Loss/train', loss, epoch)
    writer.add_scalar('Loss/val', val_loss, epoch)


# 关闭SummaryWriter
writer.close()
# Out:
# 验证集上的指标为:0.009650759398937225，总噪声为:0.025070490315556526,减少噪声0.0154197309166193,dae上的噪声0.0071573760360479355
# Epoch 1, Train Loss: 0.008908663876354694, Val Loss: 0.009650759398937225
# 验证集上的指标为:0.008175434544682503，总噪声为:0.025070490315556526,减少噪声0.016895055770874023,dae上的噪声0.007147179450839758
# Epoch 2, Train Loss: 0.009391529485583305, Val Loss: 0.008175434544682503
# 验证集上的指标为:0.007481961976736784，总噪声为:0.025070490315556526,减少噪声0.017588527873158455,dae上的噪声0.007150210440158844
# Epoch 3, Train Loss: 0.008483479730784893, Val Loss: 0.007481961976736784
# 验证集上的指标为:0.0071358210407197475，总噪声为:0.025070490315556526,减少噪声0.01793466880917549,dae上的噪声0.007146583870053291
# Epoch 4, Train Loss: 0.015534310601651669, Val Loss: 0.0071358210407197475
# 验证集上的指标为:0.006944930646568537，总噪声为:0.025070490315556526,减少噪声0.018125560134649277,dae上的噪声0.007132656406611204
# Epoch 5, Train Loss: 0.006880470551550388, Val Loss: 0.006944930646568537
# 验证集上的指标为:0.006772003136575222，总噪声为:0.025070490315556526,减少噪声0.01829848811030388,dae上的噪声0.007070602849125862
# Epoch 6, Train Loss: 0.006548394914716482, Val Loss: 0.006772003136575222
# 验证集上的指标为:0.006642555817961693，总噪声为:0.025070490315556526,减少噪声0.018427934497594833,dae上的噪声0.007052642293274403
# Epoch 7, Train Loss: 0.005787086207419634, Val Loss: 0.006642555817961693
# 验证集上的指标为:0.006541496142745018，总噪声为:0.025070490315556526,减少噪声0.018528994172811508,dae上的噪声0.007023886311799288
# Epoch 8, Train Loss: 0.007307611405849457, Val Loss: 0.006541496142745018
# 验证集上的指标为:0.006509765051305294，总噪声为:0.025070490315556526,减少噪声0.018560726195573807,dae上的噪声0.007020681165158749
# Epoch 9, Train Loss: 0.007147766649723053, Val Loss: 0.006509765051305294
# 验证集上的指标为:0.006400549318641424，总噪声为:0.025070490315556526,减少噪声0.018669940531253815,dae上的噪声0.007001257035881281
# Epoch 10, Train Loss: 0.005881747230887413, Val Loss: 0.006400549318641424
# 验证集上的指标为:0.0063466900028288364，总噪声为:0.025070490315556526,减少噪声0.018723800778388977,dae上的噪声0.006999630946666002
# Epoch 11, Train Loss: 0.006591123063117266, Val Loss: 0.0063466900028288364
# 验证集上的指标为:0.006301297806203365，总噪声为:0.025070490315556526,减少噪声0.018769193440675735,dae上的噪声0.007003129925578833
# Epoch 12, Train Loss: 0.0066521186381578445, Val Loss: 0.006301297806203365
# 验证集上的指标为:0.006257054395973682，总噪声为:0.025070490315556526,减少噪声0.01881343498826027,dae上的噪声0.006990168243646622
# Epoch 13, Train Loss: 0.007226632442325354, Val Loss: 0.006257054395973682
# 验证集上的指标为:0.006224341690540314，总噪声为:0.025070490315556526,减少噪声0.018846148625016212,dae上的噪声0.007004698272794485
# Epoch 14, Train Loss: 0.006259635556489229, Val Loss: 0.006224341690540314
# 验证集上的指标为:0.006189280189573765，总噪声为:0.025070490315556526,减少噪声0.018881209194660187,dae上的噪声0.007014696951955557
# Epoch 15, Train Loss: 0.005174035672098398, Val Loss: 0.006189280189573765
# 验证集上的指标为:0.006163282319903374，总噪声为:0.025070490315556526,减少噪声0.018907207995653152,dae上的噪声0.007037914823740721
# Epoch 16, Train Loss: 0.006076858378946781, Val Loss: 0.006163282319903374
# 验证集上的指标为:0.006137227173894644，总噪声为:0.025070490315556526,减少噪声0.018933262676000595,dae上的噪声0.007044720929116011
# Epoch 17, Train Loss: 0.009416397660970688, Val Loss: 0.006137227173894644
# 验证集上的指标为:0.00611899234354496，总噪声为:0.025070490315556526,减少噪声0.018951497972011566,dae上的噪声0.00706129427999258
# Epoch 18, Train Loss: 0.0057367924600839615, Val Loss: 0.00611899234354496
# 验证集上的指标为:0.00610231701284647，总噪声为:0.025070490315556526,减少噪声0.01896817237138748,dae上的噪声0.0070859105326235294
# Epoch 19, Train Loss: 0.005702918395400047, Val Loss: 0.00610231701284647
# 验证集上的指标为:0.006077357102185488，总噪声为:0.025070490315556526,减少噪声0.018993133679032326,dae上的噪声0.007109339348971844
# Epoch 20, Train Loss: 0.006264142692089081, Val Loss: 0.006077357102185488
# 验证集上的指标为:0.0060743121430277824，总噪声为:0.025070490315556526,减少噪声0.01899617910385132,dae上的噪声0.0071286046877503395
# Epoch 21, Train Loss: 0.0054471478797495365, Val Loss: 0.0060743121430277824
# 验证集上的指标为:0.006024952977895737，总噪声为:0.025070490315556526,减少噪声0.01904553733766079,dae上的噪声0.007153800223022699
# Epoch 22, Train Loss: 0.006180224474519491, Val Loss: 0.006024952977895737
# 验证集上的指标为:0.006028373725712299，总噪声为:0.025070490315556526,减少噪声0.019042115658521652,dae上的噪声0.007182196248322725
# Epoch 23, Train Loss: 0.00830162689089775, Val Loss: 0.006028373725712299
# 验证集上的指标为:0.006009525153785944，总噪声为:0.025070490315556526,减少噪声0.01906096562743187,dae上的噪声0.007207035087049007
# Epoch 24, Train Loss: 0.006680010352283716, Val Loss: 0.006009525153785944
# 验证集上的指标为:0.005983774084597826，总噪声为:0.025070490315556526,减少噪声0.019086716696619987,dae上的噪声0.007238402497023344
# Epoch 25, Train Loss: 0.006528199650347233, Val Loss: 0.005983774084597826
# 验证集上的指标为:0.006014593876898289，总噪声为:0.025070490315556526,减少噪声0.019055895507335663,dae上的噪声0.007262533530592918
# Epoch 26, Train Loss: 0.005592533387243748, Val Loss: 0.006014593876898289
# 验证集上的指标为:0.005964916665107012，总噪声为:0.025070490315556526,减少噪声0.0191055741161108,dae上的噪声0.007297311443835497
# Epoch 27, Train Loss: 0.005666188430041075, Val Loss: 0.005964916665107012
# 验证集上的指标为:0.005951631814241409，总噪声为:0.025070490315556526,减少噪声0.019118858501315117,dae上的噪声0.007329638581722975
# Epoch 28, Train Loss: 0.0049579935148358345, Val Loss: 0.005951631814241409
# 验证集上的指标为:0.005934383254498243，总噪声为:0.025070490315556526,减少噪声0.019136106595396996,dae上的噪声0.007374018896371126
# Epoch 29, Train Loss: 0.005929699633270502, Val Loss: 0.005934383254498243
# 验证集上的指标为:0.005938260350376368，总噪声为:0.025070490315556526,减少噪声0.019132230430841446,dae上的噪声0.0074012731201946735
# Epoch 30, Train Loss: 0.0052846092730760574, Val Loss: 0.005938260350376368
# 验证集上的指标为:0.005914412438869476，总噪声为:0.025070490315556526,减少噪声0.01915607787668705,dae上的噪声0.0074373879469931126
# Epoch 31, Train Loss: 0.006331670098006725, Val Loss: 0.005914412438869476
# 验证集上的指标为:0.0059137712232768536，总噪声为:0.025070490315556526,减少噪声0.019156718626618385,dae上的噪声0.007481482811272144
# Epoch 32, Train Loss: 0.010182816535234451, Val Loss: 0.0059137712232768536
# 验证集上的指标为:0.005908967461436987，总噪声为:0.025070490315556526,减少噪声0.019161522388458252,dae上的噪声0.007536882534623146
# Epoch 33, Train Loss: 0.00621417723596096, Val Loss: 0.005908967461436987
# 验证集上的指标为:0.005906022619456053，总噪声为:0.025070490315556526,减少噪声0.019164467230439186,dae上的噪声0.0075686960481107235
# Epoch 34, Train Loss: 0.00597967766225338, Val Loss: 0.005906022619456053
# 验证集上的指标为:0.005892554763704538，总噪声为:0.025070490315556526,减少噪声0.019177936017513275,dae上的噪声0.0076020751148462296
# Epoch 35, Train Loss: 0.0056700799614191055, Val Loss: 0.005892554763704538
# 验证集上的指标为:0.005864582024514675，总噪声为:0.025070490315556526,减少噪声0.019205909222364426,dae上的噪声0.007630674168467522
# Epoch 36, Train Loss: 0.006050579249858856, Val Loss: 0.005864582024514675
# 验证集上的指标为:0.005853723734617233，总噪声为:0.025070490315556526,减少噪声0.019216766580939293,dae上的噪声0.007662407122552395
# Epoch 37, Train Loss: 0.005507900845259428, Val Loss: 0.005853723734617233
# 验证集上的指标为:0.005866783671081066，总噪声为:0.025070490315556526,减少噪声0.019203707575798035,dae上的噪声0.007711309473961592
# Epoch 38, Train Loss: 0.006200807169079781, Val Loss: 0.005866783671081066
# 验证集上的指标为:0.005842800717800856，总噪声为:0.025070490315556526,减少噪声0.019227689132094383,dae上的噪声0.007734909653663635
# Epoch 39, Train Loss: 0.005733134690672159, Val Loss: 0.005842800717800856
# 验证集上的指标为:0.005855258088558912，总噪声为:0.025070490315556526,减少噪声0.019215231761336327,dae上的噪声0.007779951673001051
# Epoch 40, Train Loss: 0.0059025464579463005, Val Loss: 0.005855258088558912
# 验证集上的指标为:0.0058433013036847115，总噪声为:0.025070490315556526,减少噪声0.01922718808054924,dae上的噪声0.007822155021131039
# Epoch 41, Train Loss: 0.00545648206025362, Val Loss: 0.0058433013036847115
# 验证集上的指标为:0.005830805283039808，总噪声为:0.025070490315556526,减少噪声0.01923968456685543,dae上的噪声0.00784356240183115
# Epoch 42, Train Loss: 0.0055146547965705395, Val Loss: 0.005830805283039808
# 验证集上的指标为:0.005816843826323748，总噪声为:0.025070490315556526,减少噪声0.019253646954894066,dae上的噪声0.007875669747591019
# Epoch 43, Train Loss: 0.005174791440367699, Val Loss: 0.005816843826323748
# 验证集上的指标为:0.00581470737233758，总噪声为:0.025070490315556526,减少噪声0.019255783408880234,dae上的噪声0.0078959409147501
# Epoch 44, Train Loss: 0.004900453146547079, Val Loss: 0.00581470737233758
# 验证集上的指标为:0.005810861475765705，总噪声为:0.025070490315556526,减少噪声0.019259627908468246,dae上的噪声0.007937322370707989
# Epoch 45, Train Loss: 0.006207956001162529, Val Loss: 0.005810861475765705
# 验证集上的指标为:0.0057970499619841576，总噪声为:0.025070490315556526,减少噪声0.019273441284894943,dae上的噪声0.007966147735714912
# Epoch 46, Train Loss: 0.005146844778209925, Val Loss: 0.0057970499619841576
# 验证集上的指标为:0.005803594831377268，总噪声为:0.025070490315556526,减少噪声0.019266895949840546,dae上的噪声0.007999274879693985
# Epoch 47, Train Loss: 0.01045276690274477, Val Loss: 0.005803594831377268
# 验证集上的指标为:0.005793314427137375，总噪声为:0.025070490315556526,减少噪声0.01927717588841915,dae上的噪声0.008043790236115456
# Epoch 48, Train Loss: 0.006447154097259045, Val Loss: 0.005793314427137375
# 验证集上的指标为:0.005778318736702204，总噪声为:0.025070490315556526,减少噪声0.01929217204451561,dae上的噪声0.008069225586950779
# Epoch 49, Train Loss: 0.005285242572426796, Val Loss: 0.005778318736702204
# 验证集上的指标为:0.0058220503851771355，总噪声为:0.025070490315556526,减少噪声0.019248440861701965,dae上的噪声0.00810239464044571
# Epoch 50, Train Loss: 0.004858318716287613, Val Loss: 0.0058220503851771355
# 验证集上的指标为:0.005785135552287102，总噪声为:0.025070490315556526,减少噪声0.019285354763269424,dae上的噪声0.008113883435726166
# Epoch 51, Train Loss: 0.005098532885313034, Val Loss: 0.005785135552287102
# 验证集上的指标为:0.005775968544185162，总噪声为:0.025070490315556526,减少噪声0.01929452270269394,dae上的噪声0.00815331470221281
# Epoch 52, Train Loss: 0.005357544403523207, Val Loss: 0.005775968544185162
# 验证集上的指标为:0.005770488176494837，总噪声为:0.025070490315556526,减少噪声0.019300002604722977,dae上的噪声0.008184665814042091
# Epoch 53, Train Loss: 0.005305643193423748, Val Loss: 0.005770488176494837
# 验证集上的指标为:0.005803244654089212，总噪声为:0.025070490315556526,减少噪声0.0192672461271286,dae上的噪声0.008240076713263988
# Epoch 54, Train Loss: 0.005567681510001421, Val Loss: 0.005803244654089212
# 验证集上的指标为:0.005747203715145588，总噪声为:0.025070490315556526,减少噪声0.019323285669088364,dae上的噪声0.008259872905910015
# Epoch 55, Train Loss: 0.004756504204124212, Val Loss: 0.005747203715145588
# 验证集上的指标为:0.005738658830523491，总噪声为:0.025070490315556526,减少噪声0.019331831485033035,dae上的噪声0.008283953182399273
# Epoch 56, Train Loss: 0.005671977531164885, Val Loss: 0.005738658830523491
# 验证集上的指标为:0.005740941036492586，总噪声为:0.025070490315556526,减少噪声0.019329549744725227,dae上的噪声0.008299676701426506
# Epoch 57, Train Loss: 0.005540257319808006, Val Loss: 0.005740941036492586
# 验证集上的指标为:0.005742884706705809，总噪声为:0.025070490315556526,减少噪声0.01932760514318943,dae上的噪声0.008331534452736378
# Epoch 58, Train Loss: 0.006200528237968683, Val Loss: 0.005742884706705809
# 验证集上的指标为:0.0057312059216201305，总噪声为:0.025070490315556526,减少噪声0.01933928392827511,dae上的噪声0.008354914374649525
# Epoch 59, Train Loss: 0.006848905235528946, Val Loss: 0.0057312059216201305
# 验证集上的指标为:0.0057195033878088，总噪声为:0.025070490315556526,减少噪声0.019350986927747726,dae上的噪声0.008379884995520115
# Epoch 60, Train Loss: 0.00511153694242239, Val Loss: 0.0057195033878088
# 验证集上的指标为:0.005730576813220978，总噪声为:0.025070490315556526,减少噪声0.01933991350233555,dae上的噪声0.008384275250136852
# Epoch 61, Train Loss: 0.005495356395840645, Val Loss: 0.005730576813220978
# 验证集上的指标为:0.005709968041628599，总噪声为:0.025070490315556526,减少噪声0.01936052180826664,dae上的噪声0.008417305536568165
# Epoch 62, Train Loss: 0.006412860471755266, Val Loss: 0.005709968041628599
# 验证集上的指标为:0.005716952960938215，总噪声为:0.025070490315556526,减少噪声0.019353536888957024,dae上的噪声0.0084458002820611
# Epoch 63, Train Loss: 0.006002733483910561, Val Loss: 0.005716952960938215
# 验证集上的指标为:0.005717213731259108，总噪声为:0.025070490315556526,减少噪声0.01935327611863613,dae上的噪声0.00846647098660469
# Epoch 64, Train Loss: 0.006854581646621227, Val Loss: 0.005717213731259108
# 验证集上的指标为:0.005702364258468151，总噪声为:0.025070490315556526,减少噪声0.01936812698841095,dae上的噪声0.00848566647619009
# Epoch 65, Train Loss: 0.005126784555613995, Val Loss: 0.005702364258468151
# 验证集上的指标为:0.0057173073291778564，总噪声为:0.025070490315556526,减少噪声0.01935318298637867,dae上的噪声0.00850130058825016
# Epoch 66, Train Loss: 0.007356743793934584, Val Loss: 0.0057173073291778564
# 验证集上的指标为:0.00570852542296052，总噪声为:0.025070490315556526,减少噪声0.019361965358257294,dae上的噪声0.008493048138916492
# Epoch 67, Train Loss: 0.0058297147043049335, Val Loss: 0.00570852542296052
# 验证集上的指标为:0.00571020832285285，总噪声为:0.025070490315556526,减少噪声0.01936028152704239,dae上的噪声0.008533432148396969
# Epoch 68, Train Loss: 0.005972321145236492, Val Loss: 0.00571020832285285
# 验证集上的指标为:0.0057106614112854，总噪声为:0.025070490315556526,减少噪声0.019359828904271126,dae上的噪声0.008550355210900307
# Epoch 69, Train Loss: 0.004927435889840126, Val Loss: 0.0057106614112854
# 验证集上的指标为:0.005686445627361536，总噪声为:0.025070490315556526,减少噪声0.019384045153856277,dae上的噪声0.008575520478188992
# Epoch 70, Train Loss: 0.0071970927529037, Val Loss: 0.005686445627361536
# 验证集上的指标为:0.005681605543941259，总噪声为:0.025070490315556526,减少噪声0.01938888430595398,dae上的噪声0.008586634881794453
# Epoch 71, Train Loss: 0.005550845991820097, Val Loss: 0.005681605543941259
# 验证集上的指标为:0.00568727683275938，总噪声为:0.025070490315556526,减少噪声0.01938321441411972,dae上的噪声0.00862305611371994
# Epoch 72, Train Loss: 0.006089907605201006, Val Loss: 0.00568727683275938
# 验证集上的指标为:0.005675753578543663，总噪声为:0.025070490315556526,减少噪声0.019394736737012863,dae上的噪声0.008621233515441418
# Epoch 73, Train Loss: 0.005430160090327263, Val Loss: 0.005675753578543663
# 验证集上的指标为:0.0056839194148778915，总噪声为:0.025070490315556526,减少噪声0.019386570900678635,dae上的噪声0.008658986538648605
# Epoch 74, Train Loss: 0.008729726076126099, Val Loss: 0.0056839194148778915
# 验证集上的指标为:0.005684984382241964，总噪声为:0.025070490315556526,减少噪声0.019385505467653275,dae上的噪声0.008678013458848
# Epoch 75, Train Loss: 0.005314217880368233, Val Loss: 0.005684984382241964
# 验证集上的指标为:0.005668873433023691，总噪声为:0.025070490315556526,减少噪声0.019401617348194122,dae上的噪声0.00870659202337265
# Epoch 76, Train Loss: 0.00541944894939661, Val Loss: 0.005668873433023691
# 验证集上的指标为:0.005684486124664545，总噪声为:0.025070490315556526,减少噪声0.01938600465655327,dae上的噪声0.008742918260395527
# Epoch 77, Train Loss: 0.005337268579751253, Val Loss: 0.005684486124664545
# 验证集上的指标为:0.005723392590880394，总噪声为:0.025070490315556526,减少噪声0.019347097724676132,dae上的噪声0.008768192492425442
# Epoch 78, Train Loss: 0.005415365565568209, Val Loss: 0.005723392590880394
# 验证集上的指标为:0.005668821278959513，总噪声为:0.025070490315556526,减少噪声0.0194016695022583,dae上的噪声0.008784504607319832
# Epoch 79, Train Loss: 0.006284672766923904, Val Loss: 0.005668821278959513
# 验证集上的指标为:0.0056593939661979675，总噪声为:0.025070490315556526,减少噪声0.01941109634935856,dae上的噪声0.008800791576504707
# Epoch 80, Train Loss: 0.005632983986288309, Val Loss: 0.0056593939661979675
# 验证集上的指标为:0.005670696031302214，总噪声为:0.025070490315556526,减少噪声0.019399793818593025,dae上的噪声0.00884249061346054
# Epoch 81, Train Loss: 0.005306245759129524, Val Loss: 0.005670696031302214
# 验证集上的指标为:0.005653322674334049，总噪声为:0.025070490315556526,减少噪声0.019417166709899902,dae上的噪声0.008896431885659695
# Epoch 82, Train Loss: 0.00499515188857913, Val Loss: 0.005653322674334049
# 验证集上的指标为:0.005649440921843052，总噪声为:0.025070490315556526,减少噪声0.0194210484623909,dae上的噪声0.008903706446290016
# Epoch 83, Train Loss: 0.005140780471265316, Val Loss: 0.005649440921843052
# 验证集上的指标为:0.005646358709782362，总噪声为:0.025070490315556526,减少噪声0.019424131140112877,dae上的噪声0.00892573595046997
# Epoch 84, Train Loss: 0.0055051581002771854, Val Loss: 0.005646358709782362
# 验证集上的指标为:0.005638352129608393，总噪声为:0.025070490315556526,减少噪声0.01943213865160942,dae上的噪声0.008964812383055687
# Epoch 85, Train Loss: 0.005685234908014536, Val Loss: 0.005638352129608393
# 验证集上的指标为:0.005637963302433491，总噪声为:0.025070490315556526,减少噪声0.01943252608180046,dae上的噪声0.008995341137051582
# Epoch 86, Train Loss: 0.00559200718998909, Val Loss: 0.005637963302433491
# 验证集上的指标为:0.0056352694518864155，总噪声为:0.025070490315556526,减少噪声0.019435221329331398,dae上的噪声0.00902552716434002
# Epoch 87, Train Loss: 0.005164525005966425, Val Loss: 0.0056352694518864155
# 验证集上的指标为:0.005654472857713699，总噪声为:0.025070490315556526,减少噪声0.019416017457842827,dae上的噪声0.00906117632985115
# Epoch 88, Train Loss: 0.005407427903264761, Val Loss: 0.005654472857713699
# 验证集上的指标为:0.005630686413496733，总噪声为:0.025070490315556526,减少噪声0.019439803436398506,dae上的噪声0.009074502624571323
# Epoch 89, Train Loss: 0.005435596685856581, Val Loss: 0.005630686413496733
# 验证集上的指标为:0.005624941550195217，总噪声为:0.025070490315556526,减少噪声0.019445549696683884,dae上的噪声0.009101090021431446
# Epoch 90, Train Loss: 0.00698460265994072, Val Loss: 0.005624941550195217
# 验证集上的指标为:0.005619211122393608，总噪声为:0.025070490315556526,减少噪声0.019451279193162918,dae上的噪声0.00914438720792532
# Epoch 91, Train Loss: 0.010254018940031528, Val Loss: 0.005619211122393608
# 验证集上的指标为:0.005625238176435232，总噪声为:0.025070490315556526,减少噪声0.019445251673460007,dae上的噪声0.009176677092909813
# Epoch 92, Train Loss: 0.005395113490521908, Val Loss: 0.005625238176435232
# 验证集上的指标为:0.005638637114316225，总噪声为:0.025070490315556526,减少噪声0.01943185366690159,dae上的噪声0.009203613735735416
# Epoch 93, Train Loss: 0.005668063648045063, Val Loss: 0.005638637114316225
# 验证集上的指标为:0.005627951119095087，总噪声为:0.025070490315556526,减少噪声0.019442539662122726,dae上的噪声0.009242027066648006
# Epoch 94, Train Loss: 0.007880148477852345, Val Loss: 0.005627951119095087
# 验证集上的指标为:0.005611421074718237，总噪声为:0.025070490315556526,减少噪声0.019459068775177002,dae上的噪声0.009261514991521835
# Epoch 95, Train Loss: 0.005958798341453075, Val Loss: 0.005611421074718237
# 验证集上的指标为:0.005618698429316282，总噪声为:0.025070490315556526,减少噪声0.019451791420578957,dae上的噪声0.009250260889530182
# Epoch 96, Train Loss: 0.005637773312628269, Val Loss: 0.005618698429316282
# 验证集上的指标为:0.0056086331605911255，总噪声为:0.025070490315556526,减少噪声0.0194618571549654,dae上的噪声0.009289049543440342
# Epoch 97, Train Loss: 0.005053348373621702, Val Loss: 0.0056086331605911255
# 验证集上的指标为:0.005608504172414541，总噪声为:0.025070490315556526,减少噪声0.019461985677480698,dae上的噪声0.009320637211203575
# Epoch 98, Train Loss: 0.005205665715038776, Val Loss: 0.005608504172414541
# 验证集上的指标为:0.00563017325475812，总噪声为:0.025070490315556526,减少噪声0.019440317526459694,dae上的噪声0.00936098862439394
# Epoch 99, Train Loss: 0.006328547839075327, Val Loss: 0.00563017325475812
# 验证集上的指标为:0.005603721830993891，总噪声为:0.025070490315556526,减少噪声0.019466768950223923,dae上的噪声0.009346541948616505
# Epoch 100, Train Loss: 0.006035108119249344, Val Loss: 0.005603721830993891
# 验证集上的指标为:0.005609032232314348，总噪声为:0.025070490315556526,减少噪声0.019461458548903465,dae上的噪声0.009390286169946194
# Epoch 101, Train Loss: 0.005248095374554396, Val Loss: 0.005609032232314348
# 验证集上的指标为:0.005615335889160633，总噪声为:0.025070490315556526,减少噪声0.01945515349507332,dae上的噪声0.009413337334990501
# Epoch 102, Train Loss: 0.00527375191450119, Val Loss: 0.005615335889160633
# 验证集上的指标为:0.005620896816253662，总噪声为:0.025070490315556526,减少噪声0.019449593499302864,dae上的噪声0.009454750455915928
# Epoch 103, Train Loss: 0.0052440776489675045, Val Loss: 0.005620896816253662
# 验证集上的指标为:0.0055998568423092365，总噪声为:0.025070490315556526,减少噪声0.019470633938908577,dae上的噪声0.009498550556600094
# Epoch 104, Train Loss: 0.005230313632637262, Val Loss: 0.0055998568423092365
# 验证集上的指标为:0.0055903843604028225，总噪声为:0.025070490315556526,减少噪声0.019480105489492416,dae上的噪声0.009494446218013763
# Epoch 105, Train Loss: 0.005338498391211033, Val Loss: 0.0055903843604028225
# 验证集上的指标为:0.005594825837761164，总噪声为:0.025070490315556526,减少噪声0.01947566494345665,dae上的噪声0.009519137442111969
# Epoch 106, Train Loss: 0.005584747530519962, Val Loss: 0.005594825837761164
# 验证集上的指标为:0.005590107291936874，总噪声为:0.025070490315556526,减少噪声0.019480383023619652,dae上的噪声0.009525726549327374
# Epoch 107, Train Loss: 0.005020954646170139, Val Loss: 0.005590107291936874
# 验证集上的指标为:0.005584141705185175，总噪声为:0.025070490315556526,减少噪声0.01948634907603264,dae上的噪声0.009539232589304447
# Epoch 108, Train Loss: 0.0050790319219231606, Val Loss: 0.005584141705185175
# 验证集上的指标为:0.005577634088695049，总噪声为:0.025070490315556526,减少噪声0.01949285715818405,dae上的噪声0.009586754254996777
# Epoch 109, Train Loss: 0.005625447258353233, Val Loss: 0.005577634088695049
# 验证集上的指标为:0.005598763003945351，总噪声为:0.025070490315556526,减少噪声0.019471727311611176,dae上的噪声0.009618548676371574
# Epoch 110, Train Loss: 0.005155487917363644, Val Loss: 0.005598763003945351
# 验证集上的指标为:0.005597585812211037，总噪声为:0.025070490315556526,减少噪声0.01947290450334549,dae上的噪声0.00965951383113861
# Epoch 111, Train Loss: 0.005581153091043234, Val Loss: 0.005597585812211037
# 验证集上的指标为:0.005615465808659792，总噪声为:0.025070490315556526,减少噪声0.01945502497255802,dae上的噪声0.00967432651668787
# Epoch 112, Train Loss: 0.005102137569338083, Val Loss: 0.005615465808659792
# 验证集上的指标为:0.005589673295617104，总噪声为:0.025070490315556526,减少噪声0.019480817019939423,dae上的噪声0.009706156328320503
# Epoch 113, Train Loss: 0.0050041163340210915, Val Loss: 0.005589673295617104
# 验证集上的指标为:0.005578541196882725，总噪声为:0.025070490315556526,减少噪声0.019491948187351227,dae上的噪声0.009727244265377522
# Epoch 114, Train Loss: 0.005342612974345684, Val Loss: 0.005578541196882725
# 验证集上的指标为:0.005588900297880173，总噪声为:0.025070490315556526,减少噪声0.019481590017676353,dae上的噪声0.009763387963175774
# Epoch 115, Train Loss: 0.006225121673196554, Val Loss: 0.005588900297880173
# 验证集上的指标为:0.0056052785366773605，总噪声为:0.025070490315556526,减少噪声0.019465211778879166,dae上的噪声0.009790615178644657
# Epoch 116, Train Loss: 0.005238601937890053, Val Loss: 0.0056052785366773605
# 验证集上的指标为:0.005581269972026348，总噪声为:0.025070490315556526,减少噪声0.019489221274852753,dae上的噪声0.009806531481444836
# Epoch 117, Train Loss: 0.005881460849195719, Val Loss: 0.005581269972026348
# 验证集上的指标为:0.0055877892300486565，总噪声为:0.025070490315556526,减少噪声0.019482702016830444,dae上的噪声0.009807237423956394
# Epoch 118, Train Loss: 0.005912578199058771, Val Loss: 0.0055877892300486565
# 验证集上的指标为:0.005573665257543325，总噪声为:0.025070490315556526,减少噪声0.019496824592351913,dae上的噪声0.009809649549424648
# Epoch 119, Train Loss: 0.006102324463427067, Val Loss: 0.005573665257543325
# 验证集上的指标为:0.005620242096483707，总噪声为:0.025070490315556526,减少噪声0.019450247287750244,dae上的噪声0.00983854103833437
# Epoch 120, Train Loss: 0.005126204341650009, Val Loss: 0.005620242096483707
# 验证集上的指标为:0.005563270300626755，总噪声为:0.025070490315556526,减少噪声0.01950722001492977,dae上的噪声0.009856540709733963
# Epoch 121, Train Loss: 0.005158964544534683, Val Loss: 0.005563270300626755
# 验证集上的指标为:0.005565100349485874，总噪声为:0.025070490315556526,减少噪声0.019505389034748077,dae上的噪声0.009857325814664364
# Epoch 122, Train Loss: 0.005023206118494272, Val Loss: 0.005565100349485874
# 验证集上的指标为:0.005555035080760717，总噪声为:0.025070490315556526,减少噪声0.01951545476913452,dae上的噪声0.009868470020592213
# Epoch 123, Train Loss: 0.004999176599085331, Val Loss: 0.005555035080760717
# 验证集上的指标为:0.005561166442930698，总噪声为:0.025070490315556526,减少噪声0.019509322941303253,dae上的噪声0.009882805868983269
# Epoch 124, Train Loss: 0.005579216871410608, Val Loss: 0.005561166442930698
# 验证集上的指标为:0.005551337730139494，总噪声为:0.025070490315556526,减少噪声0.019519152119755745,dae上的噪声0.009913085959851742
# Epoch 125, Train Loss: 0.007545622531324625, Val Loss: 0.005551337730139494
# 验证集上的指标为:0.005548103712499142，总噪声为:0.025070490315556526,减少噪声0.01952238753437996,dae上的噪声0.009905592538416386
# Epoch 126, Train Loss: 0.0052312747575342655, Val Loss: 0.005548103712499142
# 验证集上的指标为:0.005570633802562952，总噪声为:0.025070490315556526,减少噪声0.01949985697865486,dae上的噪声0.009962329640984535
# Epoch 127, Train Loss: 0.005253905896097422, Val Loss: 0.005570633802562952
# 验证集上的指标为:0.00557479215785861，总噪声为:0.025070490315556526,减少噪声0.01949569769203663,dae上的噪声0.009996592067182064
# Epoch 128, Train Loss: 0.005221412982791662, Val Loss: 0.00557479215785861
# 验证集上的指标为:0.005565144587308168，总噪声为:0.025070490315556526,减少噪声0.019505346193909645,dae上的噪声0.010043174959719181
# Epoch 129, Train Loss: 0.006367632187902927, Val Loss: 0.005565144587308168
# 验证集上的指标为:0.005564882420003414，总噪声为:0.025070490315556526,减少噪声0.019505608826875687,dae上的噪声0.010037273168563843
# Epoch 130, Train Loss: 0.007118403445929289, Val Loss: 0.005564882420003414
# 验证集上的指标为:0.005563704762607813，总噪声为:0.025070490315556526,减少噪声0.01950678601861,dae上的噪声0.010051117278635502
# Epoch 131, Train Loss: 0.005217375233769417, Val Loss: 0.005563704762607813
# 验证集上的指标为:0.0055422550067305565，总噪声为:0.025070490315556526,减少噪声0.019528236240148544,dae上的噪声0.010082127526402473
# Epoch 132, Train Loss: 0.005244760774075985, Val Loss: 0.0055422550067305565
# 验证集上的指标为:0.0055516306310892105，总噪声为:0.025070490315556526,减少噪声0.019518859684467316,dae上的噪声0.010083109140396118
# Epoch 133, Train Loss: 0.005084341857582331, Val Loss: 0.0055516306310892105
# 验证集上的指标为:0.0055625527165830135，总噪声为:0.025070490315556526,减少噪声0.019507937133312225,dae上的噪声0.010099880397319794
# Epoch 134, Train Loss: 0.005932224448770285, Val Loss: 0.0055625527165830135
# 验证集上的指标为:0.005554121918976307，总噪声为:0.025070490315556526,减少噪声0.019516367465257645,dae上的噪声0.010118606500327587
# Epoch 135, Train Loss: 0.007815614342689514, Val Loss: 0.005554121918976307
# 验证集上的指标为:0.005532609298825264，总噪声为:0.025070490315556526,减少噪声0.019537881016731262,dae上的噪声0.010160665959119797
# Epoch 136, Train Loss: 0.0051831468008458614, Val Loss: 0.005532609298825264
# 验证集上的指标为:0.005563996732234955，总噪声为:0.025070490315556526,减少噪声0.01950649358332157,dae上的噪声0.010183638893067837
# Epoch 137, Train Loss: 0.004580487031489611, Val Loss: 0.005563996732234955
# 验证集上的指标为:0.005553369410336018，总噪声为:0.025070490315556526,减少噪声0.019517119973897934,dae上的噪声0.010182694531977177
# Epoch 138, Train Loss: 0.005320833995938301, Val Loss: 0.005553369410336018
# 验证集上的指标为:0.005536163225769997，总噪声为:0.025070490315556526,减少噪声0.01953432708978653,dae上的噪声0.010208142921328545
# Epoch 139, Train Loss: 0.006239443551748991, Val Loss: 0.005536163225769997
# 验证集上的指标为:0.005544739775359631，总噪声为:0.025070490315556526,减少噪声0.01952575147151947,dae上的噪声0.010217834264039993
# Epoch 140, Train Loss: 0.005620914977043867, Val Loss: 0.005544739775359631
# 验证集上的指标为:0.005553653929382563，总噪声为:0.025070490315556526,减少噪声0.01951683685183525,dae上的噪声0.010269464924931526
# Epoch 141, Train Loss: 0.008749355562031269, Val Loss: 0.005553653929382563
# 验证集上的指标为:0.005526999477297068，总噪声为:0.025070490315556526,减少噪声0.019543491303920746,dae上的噪声0.010261214338243008
# Epoch 142, Train Loss: 0.005221828818321228, Val Loss: 0.005526999477297068
# 验证集上的指标为:0.0055238124914467335，总噪声为:0.025070490315556526,减少噪声0.01954667828977108,dae上的噪声0.010244285687804222
# Epoch 143, Train Loss: 0.005026358645409346, Val Loss: 0.0055238124914467335
# 验证集上的指标为:0.005575163755565882，总噪声为:0.025070490315556526,减少噪声0.019495327025651932,dae上的噪声0.010271430015563965
# Epoch 144, Train Loss: 0.005007903091609478, Val Loss: 0.005575163755565882
# 验证集上的指标为:0.0055321999825537205，总噪声为:0.025070490315556526,减少噪声0.019538290798664093,dae上的噪声0.010314096696674824
# Epoch 145, Train Loss: 0.0052328770980238914, Val Loss: 0.0055321999825537205
# 验证集上的指标为:0.0055589391849935055，总噪声为:0.025070490315556526,减少噪声0.019511550664901733,dae上的噪声0.01031809113919735
# Epoch 146, Train Loss: 0.00520987156778574, Val Loss: 0.0055589391849935055
# 验证集上的指标为:0.00552712008357048，总噪声为:0.025070490315556526,减少噪声0.019543370231986046,dae上的噪声0.010320285335183144
# Epoch 147, Train Loss: 0.00587716419249773, Val Loss: 0.00552712008357048
# 验证集上的指标为:0.005523180589079857，总噪声为:0.025070490315556526,减少噪声0.01954730972647667,dae上的噪声0.010362562723457813
# Epoch 148, Train Loss: 0.005157554522156715, Val Loss: 0.005523180589079857
# 验证集上的指标为:0.005520326551049948，总噪声为:0.025070490315556526,减少噪声0.01955016329884529,dae上的噪声0.010368685238063335
# Epoch 149, Train Loss: 0.01083451695740223, Val Loss: 0.005520326551049948
# 验证集上的指标为:0.005542370490729809，总噪声为:0.025070490315556526,减少噪声0.019528120756149292,dae上的噪声0.010397120378911495
# Epoch 150, Train Loss: 0.005585692822933197, Val Loss: 0.005542370490729809
# 验证集上的指标为:0.005522314924746752，总噪声为:0.025070490315556526,减少噪声0.01954817585647106,dae上的噪声0.010411708615720272
# Epoch 151, Train Loss: 0.004973440431058407, Val Loss: 0.005522314924746752
# 验证集上的指标为:0.005520091857761145，总噪声为:0.025070490315556526,减少噪声0.019550397992134094,dae上的噪声0.010407705791294575
# Epoch 152, Train Loss: 0.00530156260356307, Val Loss: 0.005520091857761145
# 验证集上的指标为:0.0055070132948458195，总噪声为:0.025070490315556526,减少噪声0.019563477486371994,dae上的噪声0.01042276993393898
# Epoch 153, Train Loss: 0.00512779550626874, Val Loss: 0.0055070132948458195
# 验证集上的指标为:0.005519519094377756，总噪声为:0.025070490315556526,减少噪声0.019550971686840057,dae上的噪声0.010470062494277954
# Epoch 154, Train Loss: 0.005162704735994339, Val Loss: 0.005519519094377756
# 验证集上的指标为:0.005543478298932314，总噪声为:0.025070490315556526,减少噪声0.0195270124822855,dae上的噪声0.010442396625876427
# Epoch 155, Train Loss: 0.006580647546797991, Val Loss: 0.005543478298932314
# 验证集上的指标为:0.005516781937330961，总噪声为:0.025070490315556526,减少噪声0.019553707912564278,dae上的噪声0.010477970354259014
# Epoch 156, Train Loss: 0.004929680842906237, Val Loss: 0.005516781937330961
# 验证集上的指标为:0.005534620489925146，总噪声为:0.025070490315556526,减少噪声0.019535869359970093,dae上的噪声0.01049285102635622
# Epoch 157, Train Loss: 0.006058025173842907, Val Loss: 0.005534620489925146
# 验证集上的指标为:0.0055200643837451935，总噪声为:0.025070490315556526,减少噪声0.019550425931811333,dae上的噪声0.010526732541620731
# Epoch 158, Train Loss: 0.005223827436566353, Val Loss: 0.0055200643837451935
# 验证集上的指标为:0.005502795800566673，总噪声为:0.025070490315556526,减少噪声0.019567694514989853,dae上的噪声0.010541433468461037
# Epoch 159, Train Loss: 0.00525013729929924, Val Loss: 0.005502795800566673
# 验证集上的指标为:0.005505576729774475，总噪声为:0.025070490315556526,减少噪声0.01956491358578205,dae上的噪声0.010548131540417671
# Epoch 160, Train Loss: 0.005100158508867025, Val Loss: 0.005505576729774475
# 验证集上的指标为:0.005521208513528109，总噪声为:0.025070490315556526,减少噪声0.019549282267689705,dae上的噪声0.010592776350677013
# Epoch 161, Train Loss: 0.004818011540919542, Val Loss: 0.005521208513528109
# 验证集上的指标为:0.005505988374352455，总噪声为:0.025070490315556526,减少噪声0.01956450194120407,dae上的噪声0.010607128962874413
# Epoch 162, Train Loss: 0.004949463531374931, Val Loss: 0.005505988374352455
# 验证集上的指标为:0.005493553355336189，总噪声为:0.025070490315556526,减少噪声0.019576936960220337,dae上的噪声0.010645302943885326
# Epoch 163, Train Loss: 0.004735116846859455, Val Loss: 0.005493553355336189
# 验证集上的指标为:0.005533354822546244，总噪声为:0.025070490315556526,减少噪声0.01953713595867157,dae上的噪声0.010688149370253086
# Epoch 164, Train Loss: 0.004889215342700481, Val Loss: 0.005533354822546244
# 验证集上的指标为:0.005527988541871309，总噪声为:0.025070490315556526,减少噪声0.019542502239346504,dae上的噪声0.010712762363255024
# Epoch 165, Train Loss: 0.005266179330646992, Val Loss: 0.005527988541871309
# 验证集上的指标为:0.0055215987376868725，总噪声为:0.025070490315556526,减少噪声0.019548891112208366,dae上的噪声0.01075564231723547
# Epoch 166, Train Loss: 0.009237751364707947, Val Loss: 0.0055215987376868725
# 验证集上的指标为:0.005501406732946634，总噪声为:0.025070490315556526,减少噪声0.01956908404827118,dae上的噪声0.010756485164165497
# Epoch 167, Train Loss: 0.005526088643819094, Val Loss: 0.005501406732946634
# 验证集上的指标为:0.005492539145052433，总噪声为:0.025070490315556526,减少噪声0.01957795023918152,dae上的噪声0.010764026083052158
# Epoch 168, Train Loss: 0.007589302025735378, Val Loss: 0.005492539145052433
# 验证集上的指标为:0.005513874348253012，总噪声为:0.025070490315556526,减少噪声0.019556615501642227,dae上的噪声0.010806393809616566
# Epoch 169, Train Loss: 0.005208488553762436, Val Loss: 0.005513874348253012
# 验证集上的指标为:0.005496075376868248，总噪声为:0.025070490315556526,减少噪声0.019574414938688278,dae上的噪声0.01083462592214346
# Epoch 170, Train Loss: 0.006416452117264271, Val Loss: 0.005496075376868248
# 验证集上的指标为:0.005499598570168018，总噪声为:0.025070490315556526,减少噪声0.019570890814065933,dae上的噪声0.010902510955929756
# Epoch 171, Train Loss: 0.005589356180280447, Val Loss: 0.005499598570168018
# 验证集上的指标为:0.005506438668817282，总噪声为:0.025070490315556526,减少噪声0.019564051181077957,dae上的噪声0.010895726270973682
# Epoch 172, Train Loss: 0.0071718222461640835, Val Loss: 0.005506438668817282
# 验证集上的指标为:0.00552450492978096，总噪声为:0.025070490315556526,减少噪声0.019545985385775566,dae上的噪声0.010932768695056438
# Epoch 173, Train Loss: 0.00784858874976635, Val Loss: 0.00552450492978096
# 验证集上的指标为:0.00550867198035121，总噪声为:0.025070490315556526,减少噪声0.01956181786954403,dae上的噪声0.010935992002487183
# Epoch 174, Train Loss: 0.006698934361338615, Val Loss: 0.00550867198035121
# 验证集上的指标为:0.0055146608501672745，总噪声为:0.025070490315556526,减少噪声0.01955582946538925,dae上的噪声0.010932891629636288
# Epoch 175, Train Loss: 0.007029385771602392, Val Loss: 0.0055146608501672745
# 验证集上的指标为:0.005492750555276871，总噪声为:0.025070490315556526,减少噪声0.019577739760279655,dae上的噪声0.010955589823424816
# Epoch 176, Train Loss: 0.00580030819401145, Val Loss: 0.005492750555276871
# 验证集上的指标为:0.005485462956130505，总噪声为:0.025070490315556526,减少噪声0.019585028290748596,dae上的噪声0.010965947061777115
# Epoch 177, Train Loss: 0.006654296535998583, Val Loss: 0.005485462956130505
# 验证集上的指标为:0.00548168458044529，总噪声为:0.025070490315556526,减少噪声0.019588805735111237,dae上的噪声0.010969392023980618
# Epoch 178, Train Loss: 0.006699828431010246, Val Loss: 0.00548168458044529
# 验证集上的指标为:0.0054838648065924644，总噪声为:0.025070490315556526,减少噪声0.019586626440286636,dae上的噪声0.01096474938094616
# Epoch 179, Train Loss: 0.0049248975701630116, Val Loss: 0.0054838648065924644
# 验证集上的指标为:0.005477413069456816，总噪声为:0.025070490315556526,减少噪声0.019593076780438423,dae上的噪声0.011011912487447262
# Epoch 180, Train Loss: 0.005861584562808275, Val Loss: 0.005477413069456816
# 验证集上的指标为:0.005494385026395321，总噪声为:0.025070490315556526,减少噪声0.01957610622048378,dae上的噪声0.011044224724173546
# Epoch 181, Train Loss: 0.006317994091659784, Val Loss: 0.005494385026395321
# 验证集上的指标为:0.005532683804631233，总噪声为:0.025070490315556526,减少噪声0.019537806510925293,dae上的噪声0.011047118343412876
# Epoch 182, Train Loss: 0.0051288786344230175, Val Loss: 0.005532683804631233
# 验证集上的指标为:0.005481741391122341，总噪声为:0.025070490315556526,减少噪声0.01958874985575676,dae上的噪声0.011070401407778263
# Epoch 183, Train Loss: 0.0051614027470350266, Val Loss: 0.005481741391122341
# 验证集上的指标为:0.005489500239491463，总噪声为:0.025070490315556526,减少噪声0.019580990076065063,dae上的噪声0.011080916970968246
# Epoch 184, Train Loss: 0.005211528390645981, Val Loss: 0.005489500239491463
# 验证集上的指标为:0.005477759521454573，总噪声为:0.025070490315556526,减少噪声0.019592730328440666,dae上的噪声0.011074395850300789
# Epoch 185, Train Loss: 0.005104328040033579, Val Loss: 0.005477759521454573
# 验证集上的指标为:0.005484039895236492，总噪声为:0.025070490315556526,减少噪声0.01958645135164261,dae上的噪声0.011092310771346092
# Epoch 186, Train Loss: 0.005331225227564573, Val Loss: 0.005484039895236492
# 验证集上的指标为:0.005494426470249891，总噪声为:0.025070490315556526,减少噪声0.019576063379645348,dae上的噪声0.011113558895885944
# Epoch 187, Train Loss: 0.004747845232486725, Val Loss: 0.005494426470249891
# 验证集上的指标为:0.005481818225234747，总噪声为:0.025070490315556526,减少噪声0.019588671624660492,dae上的噪声0.011131069622933865
# Epoch 188, Train Loss: 0.005370301194489002, Val Loss: 0.005481818225234747
# 验证集上的指标为:0.005478480830788612，总噪声为:0.025070490315556526,减少噪声0.019592009484767914,dae上的噪声0.011169147677719593
# Epoch 189, Train Loss: 0.005277528427541256, Val Loss: 0.005478480830788612
# 验证集上的指标为:0.005467889364808798，总噪声为:0.025070490315556526,减少噪声0.01960260048508644,dae上的噪声0.011174185201525688
# Epoch 190, Train Loss: 0.00491626700386405, Val Loss: 0.005467889364808798
# 验证集上的指标为:0.005493589676916599，总噪声为:0.025070490315556526,减少噪声0.019576899707317352,dae上的噪声0.011193840764462948
# Epoch 191, Train Loss: 0.005671732127666473, Val Loss: 0.005493589676916599
# 验证集上的指标为:0.005477781407535076，总噪声为:0.025070490315556526,减少噪声0.019592709839344025,dae上的噪声0.011225763708353043
# Epoch 192, Train Loss: 0.005200712475925684, Val Loss: 0.005477781407535076
# 验证集上的指标为:0.0054665072821080685，总噪声为:0.025070490315556526,减少噪声0.01960398256778717,dae上的噪声0.01121514942497015
# Epoch 193, Train Loss: 0.004444494843482971, Val Loss: 0.0054665072821080685
# 验证集上的指标为:0.0054821292869746685，总噪声为:0.025070490315556526,减少噪声0.01958836056292057,dae上的噪声0.011235963553190231
# Epoch 194, Train Loss: 0.004931674338877201, Val Loss: 0.0054821292869746685
# 验证集上的指标为:0.005463475827127695，总噪声为:0.025070490315556526,减少噪声0.01960701495409012,dae上的噪声0.011272473260760307
# Epoch 195, Train Loss: 0.00578422611579299, Val Loss: 0.005463475827127695
# 验证集上的指标为:0.0054602171294391155，总噪声为:0.025070490315556526,减少噪声0.019610272720456123,dae上的噪声0.011266312561929226
# Epoch 196, Train Loss: 0.005306747276335955, Val Loss: 0.0054602171294391155
# 验证集上的指标为:0.0054599991999566555，总噪声为:0.025070490315556526,减少噪声0.019610490649938583,dae上的噪声0.011271396651864052
# Epoch 197, Train Loss: 0.00522543815895915, Val Loss: 0.0054599991999566555
# 验证集上的指标为:0.005464291665703058，总噪声为:0.025070490315556526,减少噪声0.019606199115514755,dae上的噪声0.011289193294942379
# Epoch 198, Train Loss: 0.005006789695471525, Val Loss: 0.005464291665703058
# 验证集上的指标为:0.005478772800415754，总噪声为:0.025070490315556526,减少噪声0.019591717049479485,dae上的噪声0.011288432404398918
# Epoch 199, Train Loss: 0.00500039616599679, Val Loss: 0.005478772800415754
# 验证集上的指标为:0.005467796698212624，总噪声为:0.025070490315556526,减少噪声0.019602693617343903,dae上的噪声0.011302552185952663
# Epoch 200, Train Loss: 0.004743065219372511, Val Loss: 0.005467796698212624
# 验证集上的指标为:0.005461182910948992，总噪声为:0.025070490315556526,减少噪声0.01960930787026882,dae上的噪声0.011373958550393581
# Epoch 201, Train Loss: 0.005233921110630035, Val Loss: 0.005461182910948992
# 验证集上的指标为:0.005468280985951424，总噪声为:0.025070490315556526,减少噪声0.019602209329605103,dae上的噪声0.011355951428413391
# Epoch 202, Train Loss: 0.004992246627807617, Val Loss: 0.005468280985951424
# 验证集上的指标为:0.005461756139993668，总噪声为:0.025070490315556526,减少噪声0.01960873417556286,dae上的噪声0.011387838050723076
# Epoch 203, Train Loss: 0.0053688762709498405, Val Loss: 0.005461756139993668
# 验证集上的指标为:0.005471984855830669，总噪声为:0.025070490315556526,减少噪声0.01959850639104843,dae上的噪声0.011375282891094685
# Epoch 204, Train Loss: 0.006874866783618927, Val Loss: 0.005471984855830669
# 验证集上的指标为:0.005453254096210003，总噪声为:0.025070490315556526,减少噪声0.019617237150669098,dae上的噪声0.011395083740353584
# Epoch 205, Train Loss: 0.005642964970320463, Val Loss: 0.005453254096210003
# 验证集上的指标为:0.005473026540130377，总噪声为:0.025070490315556526,减少噪声0.019597463309764862,dae上的噪声0.01143142394721508
# Epoch 206, Train Loss: 0.005389097612351179, Val Loss: 0.005473026540130377
# 验证集上的指标为:0.005467613693326712，总噪声为:0.025070490315556526,减少噪声0.019602876156568527,dae上的噪声0.011404561810195446
# Epoch 207, Train Loss: 0.006381673738360405, Val Loss: 0.005467613693326712
# 验证集上的指标为:0.005465290974825621，总噪声为:0.025070490315556526,减少噪声0.019605198875069618,dae上的噪声0.01141851395368576
# Epoch 208, Train Loss: 0.005589175969362259, Val Loss: 0.005465290974825621
# 验证集上的指标为:0.005459075793623924，总噪声为:0.025070490315556526,减少噪声0.019611414521932602,dae上的噪声0.011439863592386246
# Epoch 209, Train Loss: 0.0056077237240970135, Val Loss: 0.005459075793623924
# 验证集上的指标为:0.005454956088215113，总噪声为:0.025070490315556526,减少噪声0.0196155346930027,dae上的噪声0.011433598585426807
# Epoch 210, Train Loss: 0.005073912907391787, Val Loss: 0.005454956088215113
# 验证集上的指标为:0.005472439806908369，总噪声为:0.025070490315556526,减少噪声0.01959805004298687,dae上的噪声0.011439992114901543
# Epoch 211, Train Loss: 0.005401876289397478, Val Loss: 0.005472439806908369
# 验证集上的指标为:0.005462349392473698，总噪声为:0.025070490315556526,减少噪声0.019608139991760254,dae上的噪声0.011474649421870708
# Epoch 212, Train Loss: 0.0051593477837741375, Val Loss: 0.005462349392473698
# 验证集上的指标为:0.005450427532196045，总噪声为:0.025070490315556526,减少噪声0.01962006278336048,dae上的噪声0.011470873840153217
# Epoch 213, Train Loss: 0.005518111865967512, Val Loss: 0.005450427532196045
# 验证集上的指标为:0.005470212083309889，总噪声为:0.025070490315556526,减少噪声0.01960027776658535,dae上的噪声0.011467008851468563
# Epoch 214, Train Loss: 0.004936174023896456, Val Loss: 0.005470212083309889
# 验证集上的指标为:0.005448219366371632，总噪声为:0.025070490315556526,减少噪声0.01962227001786232,dae上的噪声0.011499526910483837
# Epoch 215, Train Loss: 0.0060584936290979385, Val Loss: 0.005448219366371632
# 验证集上的指标为:0.005451485514640808，总噪声为:0.025070490315556526,减少噪声0.019619004800915718,dae上的噪声0.011534560471773148
# Epoch 216, Train Loss: 0.00472612539306283, Val Loss: 0.005451485514640808
# 验证集上的指标为:0.005448287818580866，总噪声为:0.025070490315556526,减少噪声0.019622202962636948,dae上的噪声0.011548268608748913
# Epoch 217, Train Loss: 0.004900564439594746, Val Loss: 0.005448287818580866
# 验证集上的指标为:0.005448078271001577，总噪声为:0.025070490315556526,减少噪声0.01962241157889366,dae上的噪声0.01154884323477745
# Epoch 218, Train Loss: 0.005064168479293585, Val Loss: 0.005448078271001577
# 验证集上的指标为:0.005449147429317236，总噪声为:0.025070490315556526,减少噪声0.019621342420578003,dae上的噪声0.011564642190933228
# Epoch 219, Train Loss: 0.005655079148709774, Val Loss: 0.005449147429317236
# 验证集上的指标为:0.005450560711324215，总噪声为:0.025070490315556526,减少噪声0.019619930535554886,dae上的噪声0.011589168570935726
# Epoch 220, Train Loss: 0.006323940120637417, Val Loss: 0.005450560711324215
# 验证集上的指标为:0.005454478319734335，总噪声为:0.025070490315556526,减少噪声0.019616011530160904,dae上的噪声0.01164125557988882
# Epoch 221, Train Loss: 0.006366320885717869, Val Loss: 0.005454478319734335
# 验证集上的指标为:0.005444181151688099，总噪声为:0.025070490315556526,减少噪声0.019626308232545853,dae上的噪声0.011669675819575787
# Epoch 222, Train Loss: 0.005290539003908634, Val Loss: 0.005444181151688099
# 验证集上的指标为:0.005442548543214798，总噪声为:0.025070490315556526,减少噪声0.019627941772341728,dae上的噪声0.011667300015687943
# Epoch 223, Train Loss: 0.007142575923353434, Val Loss: 0.005442548543214798
# 验证集上的指标为:0.0054567432962358，总噪声为:0.025070490315556526,减少噪声0.01961374655365944,dae上的噪声0.011690355837345123
# Epoch 224, Train Loss: 0.005895857699215412, Val Loss: 0.0054567432962358
# 验证集上的指标为:0.005439281463623047，总噪声为:0.025070490315556526,减少噪声0.01963120885193348,dae上的噪声0.01169317215681076
# Epoch 225, Train Loss: 0.004890975076705217, Val Loss: 0.005439281463623047
# 验证集上的指标为:0.005470118019729853，总噪声为:0.025070490315556526,减少噪声0.01960037276148796,dae上的噪声0.01171774510294199
# Epoch 226, Train Loss: 0.009527325630187988, Val Loss: 0.005470118019729853
# 验证集上的指标为:0.005440379027277231，总噪声为:0.025070490315556526,减少噪声0.019630111753940582,dae上的噪声0.011729237623512745
# Epoch 227, Train Loss: 0.005352156236767769, Val Loss: 0.005440379027277231
# 验证集上的指标为:0.005431078840047121，总噪声为:0.025070490315556526,减少噪声0.019639411941170692,dae上的噪声0.011726949363946915
# Epoch 228, Train Loss: 0.006399698089808226, Val Loss: 0.005431078840047121
# 验证集上的指标为:0.005431847646832466，总噪声为:0.025070490315556526,减少噪声0.01963864266872406,dae上的噪声0.011746435426175594
# Epoch 229, Train Loss: 0.005186057649552822, Val Loss: 0.005431847646832466
# 验证集上的指标为:0.005435509141534567，总噪声为:0.025070490315556526,减少噪声0.019634980708360672,dae上的噪声0.011756476014852524
# Epoch 230, Train Loss: 0.009642178192734718, Val Loss: 0.005435509141534567
# 验证集上的指标为:0.00543956970795989，总噪声为:0.025070490315556526,减少噪声0.01963092014193535,dae上的噪声0.011768413707613945
# Epoch 231, Train Loss: 0.005794355180114508, Val Loss: 0.00543956970795989
# 验证集上的指标为:0.005466870032250881，总噪声为:0.025070490315556526,减少噪声0.01960362121462822,dae上的噪声0.011793308891355991
# Epoch 232, Train Loss: 0.005410090554505587, Val Loss: 0.005466870032250881
# 验证集上的指标为:0.005476037506014109，总噪声为:0.025070490315556526,减少噪声0.019594453275203705,dae上的噪声0.01180271990597248
# Epoch 233, Train Loss: 0.0045954445376992226, Val Loss: 0.005476037506014109
# 验证集上的指标为:0.005429835524410009，总噪声为:0.025070490315556526,减少噪声0.01964065432548523,dae上的噪声0.011827309615910053
# Epoch 234, Train Loss: 0.005041290074586868, Val Loss: 0.005429835524410009
# 验证集上的指标为:0.005436836276203394，总噪声为:0.025070490315556526,减少噪声0.01963365450501442,dae上的噪声0.011842825450003147
# Epoch 235, Train Loss: 0.009836781769990921, Val Loss: 0.005436836276203394
# 验证集上的指标为:0.0054847770370543，总噪声为:0.025070490315556526,减少噪声0.019585713744163513,dae上的噪声0.011825969442725182
# Epoch 236, Train Loss: 0.0050886645913124084, Val Loss: 0.0054847770370543
# 验证集上的指标为:0.005431710742413998，总噪声为:0.025070490315556526,减少噪声0.019638780504465103,dae上的噪声0.01185257826000452
# Epoch 237, Train Loss: 0.004766914993524551, Val Loss: 0.005431710742413998
# 验证集上的指标为:0.005445243790745735，总噪声为:0.025070490315556526,减少噪声0.01962524652481079,dae上的噪声0.011836931109428406
# Epoch 238, Train Loss: 0.004922022577375174, Val Loss: 0.005445243790745735
# 验证集上的指标为:0.0054390523582696915，总噪声为:0.025070490315556526,减少噪声0.019631437957286835,dae上的噪声0.011845090426504612
# Epoch 239, Train Loss: 0.004579612519592047, Val Loss: 0.0054390523582696915
# 验证集上的指标为:0.005429953336715698，总噪声为:0.025070490315556526,减少噪声0.019640536978840828,dae上的噪声0.011885604821145535
# Epoch 240, Train Loss: 0.005154534243047237, Val Loss: 0.005429953336715698
# 验证集上的指标为:0.005433087237179279，总噪声为:0.025070490315556526,减少噪声0.019637402147054672,dae上的噪声0.011868000030517578
# Epoch 241, Train Loss: 0.009707232937216759, Val Loss: 0.005433087237179279
# 验证集上的指标为:0.005453045479953289，总噪声为:0.025070490315556526,减少噪声0.019617445766925812,dae上的噪声0.01188957504928112
# Epoch 242, Train Loss: 0.005855964496731758, Val Loss: 0.005453045479953289
# 验证集上的指标为:0.005443222355097532，总噪声为:0.025070490315556526,减少噪声0.019627267494797707,dae上的噪声0.011878307908773422
# Epoch 243, Train Loss: 0.005135171581059694, Val Loss: 0.005443222355097532
# 验证集上的指标为:0.005427155178040266，总噪声为:0.025070490315556526,减少噪声0.019643334671854973,dae上的噪声0.011887975968420506
# Epoch 244, Train Loss: 0.005002234131097794, Val Loss: 0.005427155178040266
# 验证集上的指标为:0.005423910915851593，总噪声为:0.025070490315556526,减少噪声0.019646579399704933,dae上的噪声0.011950653977692127
# Epoch 245, Train Loss: 0.00473580090329051, Val Loss: 0.005423910915851593
# 验证集上的指标为:0.005439025349915028，总噪声为:0.025070490315556526,减少噪声0.019631464034318924,dae上的噪声0.011923668906092644
# Epoch 246, Train Loss: 0.005673346109688282, Val Loss: 0.005439025349915028
# 验证集上的指标为:0.005482785869389772，总噪声为:0.025070490315556526,减少噪声0.01958770491182804,dae上的噪声0.011942257173359394
# Epoch 247, Train Loss: 0.008681458421051502, Val Loss: 0.005482785869389772
# 验证集上的指标为:0.00543058430776，总噪声为:0.025070490315556526,减少噪声0.01963990554213524,dae上的噪声0.011951658874750137
# Epoch 248, Train Loss: 0.004674308001995087, Val Loss: 0.00543058430776
# 验证集上的指标为:0.0054350136779248714，总噪声为:0.025070490315556526,减少噪声0.019635476171970367,dae上的噪声0.011979578994214535
# Epoch 249, Train Loss: 0.005084941163659096, Val Loss: 0.0054350136779248714
# 验证集上的指标为:0.0054521216079592705，总噪声为:0.025070490315556526,减少噪声0.01961836963891983,dae上的噪声0.011979413218796253
# Epoch 250, Train Loss: 0.005519533529877663, Val Loss: 0.0054521216079592705
# 验证集上的指标为:0.005440488923341036，总噪声为:0.025070490315556526,减少噪声0.019630001857876778,dae上的噪声0.01199630368500948
# Epoch 251, Train Loss: 0.005746432114392519, Val Loss: 0.005440488923341036
# 验证集上的指标为:0.005420421715825796，总噪声为:0.025070490315556526,减少噪声0.019650068134069443,dae上的噪声0.012030388228595257
# Epoch 252, Train Loss: 0.005791012197732925, Val Loss: 0.005420421715825796
# 验证集上的指标为:0.005437537562102079，总噪声为:0.025070490315556526,减少噪声0.01963295228779316,dae上的噪声0.012045860290527344
# Epoch 253, Train Loss: 0.005542239639908075, Val Loss: 0.005437537562102079
# 验证集上的指标为:0.0054183523170650005，总噪声为:0.025070490315556526,减少噪声0.01965213753283024,dae上的噪声0.012069620192050934
# Epoch 254, Train Loss: 0.005209211725741625, Val Loss: 0.0054183523170650005
# 验证集上的指标为:0.0054133012890815735，总噪声为:0.025070490315556526,减少噪声0.019657189026474953,dae上的噪声0.01207586657255888
# Epoch 255, Train Loss: 0.004709777422249317, Val Loss: 0.0054133012890815735
# 验证集上的指标为:0.005433136131614447，总噪声为:0.025070490315556526,减少噪声0.019637353718280792,dae上的噪声0.012032021768391132
# Epoch 256, Train Loss: 0.00535953976213932, Val Loss: 0.005433136131614447
# 验证集上的指标为:0.00543100805953145，总噪声为:0.025070490315556526,减少噪声0.019639482721686363,dae上的噪声0.012068294920027256
# Epoch 257, Train Loss: 0.0061285970732569695, Val Loss: 0.00543100805953145
# 验证集上的指标为:0.005415080580860376，总噪声为:0.025070490315556526,减少噪声0.019655410200357437,dae上的噪声0.012100830674171448
# Epoch 258, Train Loss: 0.005103311967104673, Val Loss: 0.005415080580860376
# 验证集上的指标为:0.0054472326301038265，总噪声为:0.025070490315556526,减少噪声0.019623257219791412,dae上的噪声0.012094228528439999
# Epoch 259, Train Loss: 0.0049376594834029675, Val Loss: 0.0054472326301038265
# 验证集上的指标为:0.005422667134553194，总噪声为:0.025070490315556526,减少噪声0.01964782364666462,dae上的噪声0.012110898271203041
# Epoch 260, Train Loss: 0.0052518355660140514, Val Loss: 0.005422667134553194
# 验证集上的指标为:0.005453846883028746，总噪声为:0.025070490315556526,减少噪声0.019616642966866493,dae上的噪声0.012114830315113068
# ...
# Epoch 514, Train Loss: 0.005972160492092371, Val Loss: 0.005322914570569992
# 验证集上的指标为:0.005342463962733746，总噪声为:0.025070490315556526,减少噪声0.019728027284145355,dae上的噪声0.013468469493091106
# Epoch 515, Train Loss: 0.005734624806791544, Val Loss: 0.005342463962733746
# 验证集上的指标为:0.005351118743419647，总噪声为:0.025070490315556526,减少噪声0.01971937157213688,dae上的噪声0.013492089696228504
# Epoch 516, Train Loss: 0.004688008222728968, Val Loss: 0.005351118743419647
# 验证集上的指标为:0.005324159283190966，总噪声为:0.025070490315556526,减少噪声0.019746331498026848,dae上的噪声0.01351737417280674
# Epoch 517, Train Loss: 0.004996918607503176, Val Loss: 0.005324159283190966
# 验证集上的指标为:0.005318010225892067，总噪声为:0.025070490315556526,减少噪声0.01975248008966446,dae上的噪声0.013514836318790913
# Epoch 518, Train Loss: 0.005085825454443693, Val Loss: 0.005318010225892067
# 验证集上的指标为:0.0053322152234613895，总噪声为:0.025070490315556526,减少噪声0.019738275557756424,dae上的噪声0.013509434647858143
# Epoch 519, Train Loss: 0.00588260916993022, Val Loss: 0.0053322152234613895
# 验证集上的指标为:0.005344584118574858，总噪声为:0.025070490315556526,减少噪声0.01972590573132038,dae上的噪声0.013495292514562607
# Epoch 520, Train Loss: 0.0050239707343280315, Val Loss: 0.005344584118574858
# 验证集上的指标为:0.005355932284146547，总噪声为:0.025070490315556526,减少噪声0.019714558497071266,dae上的噪声0.01348891668021679
# Epoch 521, Train Loss: 0.00521894171833992, Val Loss: 0.005355932284146547
# 验证集上的指标为:0.005339742172509432，总噪声为:0.025070490315556526,减少噪声0.01973074860870838,dae上的噪声0.013494083657860756
# Epoch 522, Train Loss: 0.00525573268532753, Val Loss: 0.005339742172509432
# 验证集上的指标为:0.005331673193722963，总噪声为:0.025070490315556526,减少噪声0.01973881758749485,dae上的噪声0.013510746881365776
# Epoch 523, Train Loss: 0.005398002918809652, Val Loss: 0.005331673193722963
# 验证集上的指标为:0.005315660499036312，总噪声为:0.025070490315556526,减少噪声0.01975483074784279,dae上的噪声0.01351321954280138
# Epoch 524, Train Loss: 0.005473810713738203, Val Loss: 0.005315660499036312
# 验证集上的指标为:0.005319118034094572，总噪声为:0.025070490315556526,减少噪声0.019751371815800667,dae上的噪声0.013500050641596317
# Epoch 525, Train Loss: 0.005953280720859766, Val Loss: 0.005319118034094572
# 验证集上的指标为:0.005324261263012886，总噪声为:0.025070490315556526,减少噪声0.01974622905254364,dae上的噪声0.013496789149940014
# Epoch 526, Train Loss: 0.008343618363142014, Val Loss: 0.005324261263012886
# 验证集上的指标为:0.005321382079273462，总噪声为:0.025070490315556526,减少噪声0.01974910870194435,dae上的噪声0.013456310145556927
# Epoch 527, Train Loss: 0.0051693664863705635, Val Loss: 0.005321382079273462
# 验证集上的指标为:0.005325664766132832，总噪声为:0.025070490315556526,减少噪声0.01974482461810112,dae上的噪声0.013529838994145393
# Epoch 528, Train Loss: 0.005233910866081715, Val Loss: 0.005325664766132832
# 验证集上的指标为:0.005326048005372286，总噪声为:0.025070490315556526,减少噪声0.019744442775845528,dae上的噪声0.013516221195459366
# Epoch 529, Train Loss: 0.004936877638101578, Val Loss: 0.005326048005372286
# 验证集上的指标为:0.0053375414572656155，总噪声为:0.025070490315556526,减少噪声0.019732948392629623,dae上的噪声0.013528848066926003
# Epoch 530, Train Loss: 0.006086917594075203, Val Loss: 0.0053375414572656155
# 验证集上的指标为:0.005324422847479582，总噪声为:0.025070490315556526,减少噪声0.019746067002415657,dae上的噪声0.01349602546542883
# Epoch 531, Train Loss: 0.004960501566529274, Val Loss: 0.005324422847479582
# 验证集上的指标为:0.005329567939043045，总噪声为:0.025070490315556526,减少噪声0.01974092237651348,dae上的噪声0.013527744449675083
# Epoch 532, Train Loss: 0.005894656293094158, Val Loss: 0.005329567939043045
# 验证集上的指标为:0.0053467657417058945，总噪声为:0.025070490315556526,减少噪声0.01972372457385063,dae上的噪声0.013493032194674015
# Epoch 533, Train Loss: 0.005009711254388094, Val Loss: 0.0053467657417058945
# 验证集上的指标为:0.005336546339094639，总噪声为:0.025070490315556526,减少噪声0.019733943045139313,dae上的噪声0.013443605974316597
# Epoch 534, Train Loss: 0.004961428698152304, Val Loss: 0.005336546339094639
# 验证集上的指标为:0.005331771913915873，总噪声为:0.025070490315556526,减少噪声0.01973871886730194,dae上的噪声0.01350338663905859
# Epoch 535, Train Loss: 0.0048574586398899555, Val Loss: 0.005331771913915873
# 验证集上的指标为:0.005339242052286863，总噪声为:0.025070490315556526,减少噪声0.019731247797608376,dae上的噪声0.013495655730366707
# Epoch 536, Train Loss: 0.005014763213694096, Val Loss: 0.005339242052286863
# 验证集上的指标为:0.005324115976691246，总噪声为:0.025070490315556526,减少噪声0.01974637433886528,dae上的噪声0.013468201272189617
# Epoch 537, Train Loss: 0.0055253831669688225, Val Loss: 0.005324115976691246
# 验证集上的指标为:0.005345086567103863，总噪声为:0.025070490315556526,减少噪声0.019725404679775238,dae上的噪声0.013466045260429382
# Epoch 538, Train Loss: 0.005372225772589445, Val Loss: 0.005345086567103863
# 验证集上的指标为:0.005317102652043104，总噪声为:0.025070490315556526,减少噪声0.019753387197852135,dae上的噪声0.013478117063641548
# Epoch 539, Train Loss: 0.004981997422873974, Val Loss: 0.005317102652043104
# 验证集上的指标为:0.005318621173501015，总噪声为:0.025070490315556526,减少噪声0.01975186914205551,dae上的噪声0.01347426138818264
# Epoch 540, Train Loss: 0.00528300367295742, Val Loss: 0.005318621173501015
# 验证集上的指标为:0.005336876958608627，总噪声为:0.025070490315556526,减少噪声0.0197336133569479,dae上的噪声0.013509473763406277
# Epoch 541, Train Loss: 0.005142400972545147, Val Loss: 0.005336876958608627
# 验证集上的指标为:0.005310593638569117，总噪声为:0.025070490315556526,减少噪声0.019759897142648697,dae上的噪声0.013474592939019203
# Epoch 542, Train Loss: 0.005395555403083563, Val Loss: 0.005310593638569117
# 验证集上的指标为:0.005312777124345303，总噪声为:0.025070490315556526,减少噪声0.019757714122533798,dae上的噪声0.013475015759468079
# Epoch 543, Train Loss: 0.004703898914158344, Val Loss: 0.005312777124345303
# 验证集上的指标为:0.00531884515658021，总噪声为:0.025070490315556526,减少噪声0.019751645624637604,dae上的噪声0.01349995844066143
# Epoch 544, Train Loss: 0.004749863874167204, Val Loss: 0.00531884515658021
# 验证集上的指标为:0.005325677338987589，总噪声为:0.025070490315556526,减少噪声0.019744813442230225,dae上的噪声0.013533288612961769
# Epoch 545, Train Loss: 0.005002422258257866, Val Loss: 0.005325677338987589
# 验证集上的指标为:0.005322054959833622，总噪声为:0.025070490315556526,减少噪声0.01974843442440033,dae上的噪声0.013555735349655151
# Epoch 546, Train Loss: 0.005129831377416849, Val Loss: 0.005322054959833622
# 验证集上的指标为:0.005337861366569996，总噪声为:0.025070490315556526,减少噪声0.019732628017663956,dae上的噪声0.013551131822168827
# Epoch 547, Train Loss: 0.00594939524307847, Val Loss: 0.005337861366569996
# 验证集上的指标为:0.005318925715982914，总噪声为:0.025070490315556526,减少噪声0.019751563668251038,dae上的噪声0.0135478675365448
# Epoch 548, Train Loss: 0.005120104644447565, Val Loss: 0.005318925715982914
# 验证集上的指标为:0.005334693007171154，总噪声为:0.025070490315556526,减少噪声0.019735798239707947,dae上的噪声0.013568134978413582
# Epoch 549, Train Loss: 0.0048582241870462894, Val Loss: 0.005334693007171154
# 验证集上的指标为:0.005331538151949644，总噪声为:0.025070490315556526,减少噪声0.019738951697945595,dae上的噪声0.01358108501881361
# Epoch 550, Train Loss: 0.00566892372444272, Val Loss: 0.005331538151949644
# 验证集上的指标为:0.005329355597496033，总噪声为:0.025070490315556526,减少噪声0.019741134718060493,dae上的噪声0.013538903556764126
# Epoch 551, Train Loss: 0.005588199477642775, Val Loss: 0.005329355597496033
# 验证集上的指标为:0.005325932987034321，总噪声为:0.025070490315556526,减少噪声0.01974455639719963,dae上的噪声0.013534528203308582
# Epoch 552, Train Loss: 0.0047863381914794445, Val Loss: 0.005325932987034321
# 验证集上的指标为:0.005314537789672613，总噪声为:0.025070490315556526,减少噪声0.019755952060222626,dae上的噪声0.013547922484576702
# Epoch 553, Train Loss: 0.005053287837654352, Val Loss: 0.005314537789672613
# 验证集上的指标为:0.005338171496987343，总噪声为:0.025070490315556526,减少噪声0.019732318818569183,dae上的噪声0.013516615144908428
# Epoch 554, Train Loss: 0.007109259255230427, Val Loss: 0.005338171496987343
# 验证集上的指标为:0.005330749321728945，总噪声为:0.025070490315556526,减少噪声0.01973974145948887,dae上的噪声0.013528219424188137
# Epoch 555, Train Loss: 0.0048421528190374374, Val Loss: 0.005330749321728945
# 验证集上的指标为:0.005335652735084295，总噪声为:0.025070490315556526,减少噪声0.019734837114810944,dae上的噪声0.013492144644260406
# Epoch 556, Train Loss: 0.005905287805944681, Val Loss: 0.005335652735084295
# 验证集上的指标为:0.005319978576153517，总噪声为:0.025070490315556526,减少噪声0.019750511273741722,dae上的噪声0.013537725433707237
# Epoch 557, Train Loss: 0.005371219478547573, Val Loss: 0.005319978576153517
# 验证集上的指标为:0.0053413682617247105，总噪声为:0.025070490315556526,减少噪声0.019729122519493103,dae上的噪声0.01351901050657034
# Epoch 558, Train Loss: 0.005543767940253019, Val Loss: 0.0053413682617247105
# 验证集上的指标为:0.005359146744012833，总噪声为:0.025070490315556526,减少噪声0.019711343571543694,dae上的噪声0.013531419448554516
# Epoch 559, Train Loss: 0.005802986212074757, Val Loss: 0.005359146744012833
# 验证集上的指标为:0.005318040493875742，总噪声为:0.025070490315556526,减少噪声0.01975245028734207,dae上的噪声0.013552122749388218
# Epoch 560, Train Loss: 0.0045760320499539375, Val Loss: 0.005318040493875742
# 验证集上的指标为:0.005318223033100367，总噪声为:0.025070490315556526,减少噪声0.019752267748117447,dae上的噪声0.013525061309337616
# Epoch 561, Train Loss: 0.004746362566947937, Val Loss: 0.005318223033100367
# 验证集上的指标为:0.005319630261510611，总噪声为:0.025070490315556526,减少噪声0.01975085958838463,dae上的噪声0.013523570261895657
# Epoch 562, Train Loss: 0.004819278605282307, Val Loss: 0.005319630261510611
# 验证集上的指标为:0.005307197105139494，总噪声为:0.025070490315556526,减少噪声0.019763292744755745,dae上的噪声0.013544927351176739
# Epoch 563, Train Loss: 0.004955061711370945, Val Loss: 0.005307197105139494
# 验证集上的指标为:0.0053269644267857075，总噪声为:0.025070490315556526,减少噪声0.019743526354432106,dae上的噪声0.013562357984483242
# Epoch 564, Train Loss: 0.006007674615830183, Val Loss: 0.0053269644267857075
# 验证集上的指标为:0.0053329989314079285，总噪声为:0.025070490315556526,减少噪声0.019737491384148598,dae上的噪声0.01355538610368967
# Epoch 565, Train Loss: 0.005638028960675001, Val Loss: 0.0053329989314079285
# 验证集上的指标为:0.0053221555426716805，总噪声为:0.025070490315556526,减少噪声0.01974833384156227,dae上的噪声0.01354879979044199
# Epoch 566, Train Loss: 0.004806410986930132, Val Loss: 0.0053221555426716805
# 验证集上的指标为:0.005339300259947777，总噪声为:0.025070490315556526,减少噪声0.01973119005560875,dae上的噪声0.01356623787432909
# Epoch 567, Train Loss: 0.0045472499914467335, Val Loss: 0.005339300259947777
# 验证集上的指标为:0.005312668159604073，总噪声为:0.025070490315556526,减少噪声0.019757822155952454,dae上的噪声0.0134999118745327
# Epoch 568, Train Loss: 0.004943219944834709, Val Loss: 0.005312668159604073
# 验证集上的指标为:0.005318345036357641，总噪声为:0.025070490315556526,减少噪声0.019752144813537598,dae上的噪声0.01352206151932478
# Epoch 569, Train Loss: 0.008542032912373543, Val Loss: 0.005318345036357641
# 验证集上的指标为:0.005325374659150839，总噪声为:0.025070490315556526,减少噪声0.0197451151907444,dae上的噪声0.013534998521208763
# Epoch 570, Train Loss: 0.004481067880988121, Val Loss: 0.005325374659150839
# 验证集上的指标为:0.005315090995281935，总噪声为:0.025070490315556526,减少噪声0.019755398854613304,dae上的噪声0.013519254513084888
# Epoch 571, Train Loss: 0.005071310792118311, Val Loss: 0.005315090995281935
# 验证集上的指标为:0.005325918085873127，总噪声为:0.025070490315556526,减少噪声0.019744571298360825,dae上的噪声0.013525843620300293
# Epoch 572, Train Loss: 0.00539563549682498, Val Loss: 0.005325918085873127
# 验证集上的指标为:0.0053035421296954155，总噪声为:0.025070490315556526,减少噪声0.019766949117183685,dae上的噪声0.013506869785487652
# Epoch 573, Train Loss: 0.008342924527823925, Val Loss: 0.0053035421296954155
# 验证集上的指标为:0.00533725880086422，总噪声为:0.025070490315556526,减少噪声0.019733231514692307,dae上的噪声0.013512330129742622
# Epoch 574, Train Loss: 0.005528839770704508, Val Loss: 0.00533725880086422
# 验证集上的指标为:0.005330127198249102，总噪声为:0.025070490315556526,减少噪声0.019740363582968712,dae上的噪声0.013519732281565666
# Epoch 575, Train Loss: 0.004733696114271879, Val Loss: 0.005330127198249102
# 验证集上的指标为:0.00533377705141902，总噪声为:0.025070490315556526,减少噪声0.01973671279847622,dae上的噪声0.013513770885765553
# Epoch 576, Train Loss: 0.005044572055339813, Val Loss: 0.00533377705141902
# 验证集上的指标为:0.005316839553415775，总噪声为:0.025070490315556526,减少噪声0.019753649830818176,dae上的噪声0.013489492237567902
# Epoch 577, Train Loss: 0.004907860886305571, Val Loss: 0.005316839553415775
# 验证集上的指标为:0.005352003034204245，总噪声为:0.025070490315556526,减少噪声0.019718486815690994,dae上的噪声0.013485987670719624
# Epoch 578, Train Loss: 0.005094956606626511, Val Loss: 0.005352003034204245
# 验证集上的指标为:0.005320659838616848，总噪声为:0.025070490315556526,减少噪声0.019749831408262253,dae上的噪声0.013490520417690277
# Epoch 579, Train Loss: 0.005350594874471426, Val Loss: 0.005320659838616848
# 验证集上的指标为:0.0053159380331635475，总噪声为:0.025070490315556526,减少噪声0.019754551351070404,dae上的噪声0.013486836105585098
# Epoch 580, Train Loss: 0.004860000219196081, Val Loss: 0.0053159380331635475
# 验证集上的指标为:0.005323927383869886，总噪声为:0.025070490315556526,减少噪声0.019746562466025352,dae上的噪声0.01348989736288786
# Epoch 581, Train Loss: 0.005662389099597931, Val Loss: 0.005323927383869886
# 验证集上的指标为:0.005333087872713804，总噪声为:0.025070490315556526,减少噪声0.019737401977181435,dae上的噪声0.013487770222127438
# Epoch 582, Train Loss: 0.0046851192601025105, Val Loss: 0.005333087872713804
# 验证集上的指标为:0.005328246392309666，总噪声为:0.025070490315556526,减少噪声0.019742242991924286,dae上的噪声0.0134629150852561
# Epoch 583, Train Loss: 0.005284713581204414, Val Loss: 0.005328246392309666
# 验证集上的指标为:0.005324134603142738，总噪声为:0.025070490315556526,减少噪声0.019746355712413788,dae上的噪声0.01346237026154995
# Epoch 584, Train Loss: 0.006736500188708305, Val Loss: 0.005324134603142738
# 验证集上的指标为:0.0053254384547472，总噪声为:0.025070490315556526,减少噪声0.019745051860809326,dae上的噪声0.013504711911082268
# Epoch 585, Train Loss: 0.005576984025537968, Val Loss: 0.0053254384547472
# 验证集上的指标为:0.005315725691616535，总噪声为:0.025070490315556526,减少噪声0.019754763692617416,dae上的噪声0.013532588258385658
# Epoch 586, Train Loss: 0.005048906430602074, Val Loss: 0.005315725691616535
# 验证集上的指标为:0.005325092002749443，总噪声为:0.025070490315556526,减少噪声0.019745398312807083,dae上的噪声0.013494303449988365
# Epoch 587, Train Loss: 0.006596139166504145, Val Loss: 0.005325092002749443
# 验证集上的指标为:0.005314430687576532，总噪声为:0.025070490315556526,减少噪声0.01975606009364128,dae上的噪声0.013544496148824692
# Epoch 588, Train Loss: 0.004920451436191797, Val Loss: 0.005314430687576532
# 验证集上的指标为:0.005318512208759785，总噪声为:0.025070490315556526,减少噪声0.019751977175474167,dae上的噪声0.013506501913070679
# Epoch 589, Train Loss: 0.00626073032617569, Val Loss: 0.005318512208759785
# 验证集上的指标为:0.005313776433467865，总噪声为:0.025070490315556526,减少噪声0.01975671388208866,dae上的噪声0.013518685474991798
# Epoch 590, Train Loss: 0.005191585049033165, Val Loss: 0.005313776433467865
# 验证集上的指标为:0.005301302764564753，总噪声为:0.025070490315556526,减少噪声0.01976918801665306,dae上的噪声0.013519217260181904
# Epoch 591, Train Loss: 0.008568625897169113, Val Loss: 0.005301302764564753
# 验证集上的指标为:0.005305494647473097，总噪声为:0.025070490315556526,减少噪声0.019764995202422142,dae上的噪声0.013503826223313808
# Epoch 592, Train Loss: 0.004896862898021936, Val Loss: 0.005305494647473097
# 验证集上的指标为:0.00531923770904541，总噪声为:0.025070490315556526,减少噪声0.019751252606511116,dae上的噪声0.013522695749998093
# Epoch 593, Train Loss: 0.004620781634002924, Val Loss: 0.00531923770904541
# 验证集上的指标为:0.005332944914698601，总噪声为:0.025070490315556526,减少噪声0.019737545400857925,dae上的噪声0.013547702692449093
# Epoch 594, Train Loss: 0.004975602962076664, Val Loss: 0.005332944914698601
# 验证集上的指标为:0.005318637937307358，总噪声为:0.025070490315556526,减少噪声0.01975185237824917,dae上的噪声0.01355813629925251
# Epoch 595, Train Loss: 0.0050887130200862885, Val Loss: 0.005318637937307358
# 验证集上的指标为:0.005305036436766386，总噪声为:0.025070490315556526,减少噪声0.019765453413128853,dae上的噪声0.01354187447577715
# Epoch 596, Train Loss: 0.006003116257488728, Val Loss: 0.005305036436766386
# 验证集上的指标为:0.005301228258758783，总噪声为:0.025070490315556526,减少噪声0.01976926252245903,dae上的噪声0.013575433753430843
# Epoch 597, Train Loss: 0.004872452467679977, Val Loss: 0.005301228258758783
# 验证集上的指标为:0.0053329626098275185，总噪声为:0.025070490315556526,减少噪声0.019737526774406433,dae上的噪声0.013557630591094494
# Epoch 598, Train Loss: 0.005317170638591051, Val Loss: 0.0053329626098275185
# 验证集上的指标为:0.005326097831130028，总噪声为:0.025070490315556526,减少噪声0.0197443924844265,dae上的噪声0.013563496060669422
# Epoch 599, Train Loss: 0.004684947896748781, Val Loss: 0.005326097831130028
# 验证集上的指标为:0.005319118034094572，总噪声为:0.025070490315556526,减少噪声0.019751371815800667,dae上的噪声0.013508221134543419
# Epoch 600, Train Loss: 0.004745227750390768, Val Loss: 0.005319118034094572

# %%
model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task9_piae5_best.pth', weights_only=True))
dae_model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task9_dae1_best.pth', weights_only=True))

model.eval()
with torch.no_grad():
    val_dae_out = dae_model(val_input)
    val_feat = torch.diff(val_dae_out,dim=1)

    # # 真值的
    # val_edagepoint = val_edge[:,0:2,:]
    # val_endstate = val_edge[:,2,:]
    
    # 重构的
    val_edagepoint = torch.stack([val_dae_out[:,0,:],val_dae_out[:,-1,:]],dim=1)
    val_ve = torch.sqrt((val_dae_out[:,-1,1]-val_dae_out[:,-2,1])**2 +(val_dae_out[:,-1,0]-val_dae_out[:,-2,0])**2)/torch.tensor(0.1)
    val_phie = torch.arctan2(val_dae_out[:,-1,1]-val_dae_out[:,-2,1],val_dae_out[:,-1,0]-val_dae_out[:,-2,0])
    val_endstate = torch.stack([val_ve,val_phie],dim=1)

    val_output,val_action = model(val_feat,val_edagepoint,val_endstate)
    val_loss = criterion(val_output,val_label)
    orig_err = criterion(val_input, val_label)

print(f'验证集上的指标为:{val_loss}，总噪声为:{orig_err},减少噪声{orig_err-val_loss}')
# Out:
# 验证集上的指标为:0.005301228258758783，总噪声为:0.025070490315556526,减少噪声0.01976926252245903

# %%
plt.figure(figsize=(8, 6))
# 绘制原始轨迹
import numpy as np
# num = 845
num = np.random.randint(0,30000)
# num = 0
plt.plot(val_label.cpu().numpy()[num, :,0], val_label.cpu().numpy()[num, :,1], '-o',c='blue', label='Original Data')
plt.plot(val_input.cpu().numpy()[num, :,0], val_input.cpu().numpy()[num, :,1], '.-',c='g', label='Noisy Data')
plt.plot(val_dae_out.cpu().numpy()[num, :,0], val_dae_out.cpu().numpy()[num, :,1], '.-',c='c', label='DAE Data')
plt.plot(val_output.cpu().numpy()[num, :,0], val_output.cpu().numpy()[num, :,1], '*-', c='red', label='Reconstructed Data')
plt.title('Reconstructed Trajectory')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.axis('equal')
plt.show()

# %%
# 定义专门用来重构轨迹的类, 计算误差ADE

class Reconstruct_Traj(Vehicle_Model_Methods):

    def __init__(self):
        super(Reconstruct_Traj, self).__init__()

    def ADE_err(self,out,label):
        ade = ((out - label) ** 2).sum(dim=2).sqrt().mean()
        return ade
    
    def calculate(self,actions,edagepoint,endstate,mode,labels):

        ax = actions[:,:,0]
        delta = actions[:,:,1]

        if mode == 'init_one':
            out = self.initial_unidirectional_reconstruct(ax,delta,edagepoint,endstate)
        elif mode == 'init_two':
            out = self.initial_bidirectional_reconstruct(ax,delta,edagepoint,endstate)
        elif mode == 'two_point':
            out,condtion = self.two_point_reconstruct(ax, delta, edagepoint, endstate)
        else:
            print(f'没有重构模式{mode}')
            out = torch.zeros(labels.shape, dtype=torch.float32, device=labels.device)
        
        loss_err = self.ADE_err(out,labels)

        loss_err = loss_err.cpu().numpy()

        return loss_err

# %%
recon_tarj = Reconstruct_Traj()

err_init_one = recon_tarj.calculate(val_action,val_edagepoint,val_endstate,'init_one',val_label)
print('单点单向重构误差',err_init_one)

err_init_two = recon_tarj.calculate(val_action,val_edagepoint,val_endstate,'init_two',val_label)
print('单点双向重构误差',err_init_two)

err_two_point = recon_tarj.calculate(val_action,val_edagepoint,val_endstate,'two_point',val_label)
print('单点单向重构误差',err_two_point)
# Out:
# 单点单向重构误差 0.102220766
# 单点双向重构误差 0.080858864
# 求解成了～           单点单向重构误差 0.08855617
