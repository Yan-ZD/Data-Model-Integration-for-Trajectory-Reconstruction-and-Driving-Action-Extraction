# %% [markdown]
# 训练自编码器
#
# 用现在筛选过的数据训练自编码器
#
# 卷积+MLP
#
# ---
#
# 效果：0.007598
#
# 0.007041404023766518 - 保存
#
# 无约束：
#
# 0.004592605400830507
#
# 修改约束函数再来

# %%
# 直接训练
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import pickle
import os

from torch.utils.tensorboard import SummaryWriter


from model.PIAE_models import T7DAE1,Vehicle_Model_Methods

# 检查是否有可用的GPU
if torch.cuda.is_available():
    print('显卡参与训练')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# 显卡参与训练

# %%
# 1. 加载预处理后的数据
def load_preprocessed_data(input_file):
    with open(input_file, 'rb') as f:
        data = pickle.load(f)
    return data


input_file = '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/data/Task2_data'  # 替换为你保存的.pkl文件路径

tarin_data = load_preprocessed_data(os.path.join(input_file,'train_noisy_data.kpl'))
dataset = TensorDataset(tarin_data[1],tarin_data[0])
dataloader = DataLoader(dataset, batch_size=100, shuffle=True)


val_data = load_preprocessed_data(os.path.join(input_file,'val_noisy_data.kpl'))
val_input = val_data[1].to(device)
val_label = val_data[0].to(device)

# %%
class CustomLoss(nn.Module,Vehicle_Model_Methods):
    def __init__(self):
        super(CustomLoss, self).__init__()


    def forward(self, outputs, targets):

        # 计算自定义损失
        # 首先均方误差作为基础，保证平滑结果和原来数据的相似性
        mse_loss = nn.MSELoss()(outputs, targets)

        ax_limit_loss,delta_limit_loss=self.constrain_loss(outputs)

        custom_loss = mse_loss + ax_limit_loss*1e-1  + delta_limit_loss*1e1
        # custom_loss =  ax_limit_loss*1e-1  + delta_limit_loss*1e1
        # custom_loss =  mse_loss + loss_x*5e-2  + loss_y*5e-1 + ax_limit_loss*1e-1  + delta_limit_loss*1e1
        return custom_loss

# %%
# 3. 定义模型、损失函数和优化器
model = T7DAE1()
criterion = nn.MSELoss()
criterion2 = CustomLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-3)

model.to(device)
# Out:
# T7DAE1(
#   (encoder): Sequential(
#     (0): Conv1d(2, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): ReLU()
#     (2): Conv1d(10, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#     (3): ReLU()
#     (4): Conv1d(20, 30, kernel_size=(3,), stride=(1,), padding=(1,))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=600, out_features=400, bias=True)
#     (8): ReLU()
#     (9): Linear(in_features=400, out_features=100, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=100, out_features=400, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=400, out_features=600, bias=True)
#     (3): Unflatten(dim=1, unflattened_size=(30, 20))
#     (4): ReLU()
#     (5): Conv1d(30, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#     (6): ReLU()
#     (7): Conv1d(20, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#     (8): ReLU()
#     (9): Conv1d(10, 2, kernel_size=(3,), stride=(1,), padding=(1,))
#   )
# )

# %%
# 4. 训练模型Autoencoder


# 创建一个SummaryWriter对象，指定日志保存的路径
writer = SummaryWriter('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/logs/log6-1')
# log6 有模型惩罚约束
# log6-1 无罚约束

epochs = 600
best_loss = float('inf')

for epoch in range(epochs):
    for batch_idx, (inputs,label) in enumerate(dataloader):  
        # 添加噪声
        inputs = inputs.to(device)  # 将输入数据移动到同一设备
        label = label.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        # print('output shape:',outputs.shape)
        # loss = criterion2(outputs, label) # 没有-1
        loss = criterion(outputs, label) # 有-1

        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}, Train Loss: {loss.item()}')

    with torch.no_grad():
        
        val_out = model(val_input)
        loss_val = criterion(val_out, val_label)
        orig_err = criterion(val_input, val_label)
    
    print(f'验证集上的指标为:{loss_val}，总噪声为:{orig_err},减少噪声{orig_err-loss_val}')
    
    if loss_val.item() < best_loss :
        # 保存模型
        torch.save(model.state_dict(), '/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task6-1_model_best.pth')
        best_loss = loss_val.item()

    # 使用SummaryWriter记录数据
    writer.add_scalar('Loss/train', loss, epoch)
    writer.add_scalar('Loss/val', loss_val, epoch)

# 关闭SummaryWriter
writer.close()
# Out:
# Epoch 1, Train Loss: 12.299250602722168
# 验证集上的指标为:0.5069513916969299，总噪声为:0.025070490315556526,减少噪声-0.48188090324401855
# Epoch 2, Train Loss: 12.234606742858887
# 验证集上的指标为:0.42968887090682983，总噪声为:0.025070490315556526,减少噪声-0.40461838245391846
# Epoch 3, Train Loss: 12.056303977966309
# 验证集上的指标为:0.2894584536552429，总噪声为:0.025070490315556526,减少噪声-0.26438796520233154
# Epoch 4, Train Loss: 11.95142650604248
# 验证集上的指标为:0.2947194278240204，总噪声为:0.025070490315556526,减少噪声-0.269648939371109
# Epoch 5, Train Loss: 11.922185897827148
# 验证集上的指标为:0.24166949093341827，总噪声为:0.025070490315556526,减少噪声-0.2165990024805069
# Epoch 6, Train Loss: 11.825960159301758
# 验证集上的指标为:0.25946244597435，总噪声为:0.025070490315556526,减少噪声-0.2343919575214386
# Epoch 7, Train Loss: 11.801541328430176
# 验证集上的指标为:0.20464488863945007，总噪声为:0.025070490315556526,减少噪声-0.1795744001865387
# Epoch 8, Train Loss: 11.696192741394043
# 验证集上的指标为:0.17247894406318665，总噪声为:0.025070490315556526,减少噪声-0.14740845561027527
# Epoch 9, Train Loss: 11.830530166625977
# 验证集上的指标为:0.21883291006088257，总噪声为:0.025070490315556526,减少噪声-0.1937624216079712
# Epoch 10, Train Loss: 11.747941017150879
# 验证集上的指标为:0.17970134317874908，总噪声为:0.025070490315556526,减少噪声-0.1546308547258377
# Epoch 11, Train Loss: 11.697607040405273
# 验证集上的指标为:0.1458858698606491，总噪声为:0.025070490315556526,减少噪声-0.12081538140773773
# Epoch 12, Train Loss: 11.701217651367188
# 验证集上的指标为:0.14722323417663574，总噪声为:0.025070490315556526,减少噪声-0.12215274572372437
# Epoch 13, Train Loss: 11.739384651184082
# 验证集上的指标为:0.16291862726211548，总噪声为:0.025070490315556526,减少噪声-0.1378481388092041
# Epoch 14, Train Loss: 11.69021224975586
# 验证集上的指标为:0.14345425367355347，总噪声为:0.025070490315556526,减少噪声-0.11838376522064209
# Epoch 15, Train Loss: 11.673807144165039
# 验证集上的指标为:0.14123252034187317，总噪声为:0.025070490315556526,减少噪声-0.11616203188896179
# Epoch 16, Train Loss: 11.679315567016602
# 验证集上的指标为:0.13440895080566406，总噪声为:0.025070490315556526,减少噪声-0.10933846235275269
# Epoch 17, Train Loss: 11.697290420532227
# 验证集上的指标为:0.14626403152942657，总噪声为:0.025070490315556526,减少噪声-0.1211935430765152
# Epoch 18, Train Loss: 11.534669876098633
# 验证集上的指标为:0.019710224121809006，总噪声为:0.025070490315556526,减少噪声0.0053602661937475204
# Epoch 19, Train Loss: 11.550687789916992
# 验证集上的指标为:0.017115894705057144，总噪声为:0.025070490315556526,减少噪声0.007954595610499382
# Epoch 20, Train Loss: 11.558525085449219
# 验证集上的指标为:0.032332029193639755，总噪声为:0.025070490315556526,减少噪声-0.007261538878083229
# Epoch 21, Train Loss: 11.556528091430664
# 验证集上的指标为:0.04093042388558388，总噪声为:0.025070490315556526,减少噪声-0.01585993357002735
# Epoch 22, Train Loss: 11.56392765045166
# 验证集上的指标为:0.028986504301428795，总噪声为:0.025070490315556526,减少噪声-0.003916013985872269
# Epoch 23, Train Loss: 11.536238670349121
# 验证集上的指标为:0.020857764407992363，总噪声为:0.025070490315556526,减少噪声0.004212725907564163
# Epoch 24, Train Loss: 11.565515518188477
# 验证集上的指标为:0.0532115213572979，总噪声为:0.025070490315556526,减少噪声-0.02814103104174137
# Epoch 25, Train Loss: 11.631031036376953
# 验证集上的指标为:0.01925812102854252，总噪声为:0.025070490315556526,减少噪声0.005812369287014008
# Epoch 26, Train Loss: 11.533772468566895
# 验证集上的指标为:0.034459277987480164，总噪声为:0.025070490315556526,减少噪声-0.009388787671923637
# Epoch 27, Train Loss: 11.54052734375
# 验证集上的指标为:0.01558761578053236，总噪声为:0.025070490315556526,减少噪声0.009482874535024166
# Epoch 28, Train Loss: 11.592072486877441
# 验证集上的指标为:0.015263385139405727，总噪声为:0.025070490315556526,减少噪声0.009807105176150799
# Epoch 29, Train Loss: 11.575089454650879
# 验证集上的指标为:0.024299321696162224，总噪声为:0.025070490315556526,减少噪声0.0007711686193943024
# Epoch 30, Train Loss: 11.611105918884277
# 验证集上的指标为:0.014946828596293926，总噪声为:0.025070490315556526,减少噪声0.0101236617192626
# Epoch 31, Train Loss: 11.546428680419922
# 验证集上的指标为:0.015604602172970772，总噪声为:0.025070490315556526,减少噪声0.009465888142585754
# Epoch 32, Train Loss: 11.533356666564941
# 验证集上的指标为:0.015165308490395546，总噪声为:0.025070490315556526,减少噪声0.00990518182516098
# Epoch 33, Train Loss: 12.09203052520752
# 验证集上的指标为:0.4067574739456177，总噪声为:0.025070490315556526,减少噪声-0.3816869854927063
# Epoch 34, Train Loss: 12.087625503540039
# 验证集上的指标为:0.3136705458164215，总噪声为:0.025070490315556526,减少噪声-0.28860005736351013
# Epoch 35, Train Loss: 12.076958656311035
# 验证集上的指标为:0.29855093359947205，总噪声为:0.025070490315556526,减少噪声-0.27348044514656067
# Epoch 36, Train Loss: 11.99513053894043
# 验证集上的指标为:0.2710783779621124，总噪声为:0.025070490315556526,减少噪声-0.24600788950920105
# Epoch 37, Train Loss: 11.994807243347168
# 验证集上的指标为:0.2626471221446991，总噪声为:0.025070490315556526,减少噪声-0.23757663369178772
# Epoch 38, Train Loss: 12.008357048034668
# 验证集上的指标为:0.29413238167762756，总噪声为:0.025070490315556526,减少噪声-0.2690618932247162
# Epoch 39, Train Loss: 11.976590156555176
# 验证集上的指标为:0.25589287281036377，总噪声为:0.025070490315556526,减少噪声-0.2308223843574524
# Epoch 40, Train Loss: 12.007596969604492
# 验证集上的指标为:0.2910468578338623，总噪声为:0.025070490315556526,减少噪声-0.2659763693809509
# Epoch 41, Train Loss: 11.945114135742188
# 验证集上的指标为:0.24280598759651184，总噪声为:0.025070490315556526,减少噪声-0.21773549914360046
# Epoch 42, Train Loss: 11.929966926574707
# 验证集上的指标为:0.20965024828910828，总噪声为:0.025070490315556526,减少噪声-0.1845797598361969
# Epoch 43, Train Loss: 11.930357933044434
# 验证集上的指标为:0.25371527671813965，总噪声为:0.025070490315556526,减少噪声-0.22864478826522827
# Epoch 44, Train Loss: 11.92912769317627
# 验证集上的指标为:0.18619537353515625，总噪声为:0.025070490315556526,减少噪声-0.16112488508224487
# Epoch 45, Train Loss: 11.892163276672363
# 验证集上的指标为:0.2165280431509018，总噪声为:0.025070490315556526,减少噪声-0.19145755469799042
# Epoch 46, Train Loss: 11.964543342590332
# 验证集上的指标为:0.23449426889419556，总噪声为:0.025070490315556526,减少噪声-0.20942378044128418
# Epoch 47, Train Loss: 11.858176231384277
# 验证集上的指标为:0.17538957297801971，总噪声为:0.025070490315556526,减少噪声-0.15031908452510834
# Epoch 48, Train Loss: 11.874342918395996
# 验证集上的指标为:0.19725492596626282，总噪声为:0.025070490315556526,减少噪声-0.17218443751335144
# Epoch 49, Train Loss: 11.918242454528809
# 验证集上的指标为:0.23031440377235413，总噪声为:0.025070490315556526,减少噪声-0.20524391531944275
# Epoch 50, Train Loss: 11.871066093444824
# 验证集上的指标为:0.18689551949501038，总噪声为:0.025070490315556526,减少噪声-0.161825031042099
# Epoch 51, Train Loss: 11.849950790405273
# 验证集上的指标为:0.17499902844429016，总噪声为:0.025070490315556526,减少噪声-0.14992853999137878
# Epoch 52, Train Loss: 11.872333526611328
# 验证集上的指标为:0.18186795711517334，总噪声为:0.025070490315556526,减少噪声-0.15679746866226196
# Epoch 53, Train Loss: 11.791102409362793
# 验证集上的指标为:0.2103709727525711，总噪声为:0.025070490315556526,减少噪声-0.18530048429965973
# Epoch 54, Train Loss: 11.62059497833252
# 验证集上的指标为:0.0950041264295578，总噪声为:0.025070490315556526,减少噪声-0.06993363797664642
# Epoch 55, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 56, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 57, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 58, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 59, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 60, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 61, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 62, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 63, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 64, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 65, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 66, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 67, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 68, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 69, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 70, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 71, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 72, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 73, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 74, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 75, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 76, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# Epoch 77, Train Loss: nan
# 验证集上的指标为:nan，总噪声为:0.025070490315556526,减少噪声nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 13
#      10 best_loss = float('inf')
#      12 for epoch in range(epochs):
# ---> 13     for batch_idx, (inputs,label) in enumerate(dataloader):
#      14         # 添加噪声
#      15         inputs = inputs.to(device)  # 将输入数据移动到同一设备
#      16         label = label.to(device)
#
# File ~/anaconda3/envs/PT/lib/python3.11/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/anaconda3/envs/PT/lib/python3.11/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/PT/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/PT/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/PT/lib/python3.11/site-packages/torch/utils/data/dataset.py:211, in TensorDataset.__getitem__(self, index)
#     210 def __getitem__(self, index):
# --> 211     return tuple(tensor[index] for tensor in self.tensors)
#
# File ~/anaconda3/envs/PT/lib/python3.11/site-packages/torch/utils/data/dataset.py:211, in <genexpr>(.0)
#     210 def __getitem__(self, index):
# --> 211     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:

# %%
# model = T7DAE1()
# model.to(device)

model.load_state_dict(torch.load('/home/yzd/my_research/2024.12轨迹平滑/深度学习方法平滑/降噪自编码器/Test7_final_together/model/trained_models/Task6-1_model_best.pth',weights_only=True))

import numpy as np

model.eval()

with torch.no_grad():
    val_input = val_input.to(device)
    val_out = model(val_input)
    loss_val = criterion(val_out, val_label)
    orig_err = criterion(val_input, val_label)
print(f'验证集上的指标为:{loss_val}，总噪声为:{orig_err},减少噪声{orig_err-loss_val}')

# 6. 绘制原始轨迹和重建后的轨迹
plt.figure(figsize=(10, 7))

# 绘制原始轨迹
# num = 845
num = np.random.randint(0,30000)
plt.figure(figsize=[8,6])
plt.plot(val_label.cpu().numpy()[num,:,0], val_label.cpu().numpy()[num,:,1], '-o',c='blue', label='Original Data')
plt.plot(val_input.cpu().numpy()[num,:,0], val_input.cpu().numpy()[num,:,1], '-o', c='green', label='Noisy Data')
plt.plot(val_out.cpu().numpy()[num,:,0], val_out.cpu().numpy()[num,:,1], '-o', c='red', label='Reconstructed Data')
plt.title('Reconstructed Trajectory')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.axis('equal')
plt.show()
# Out:
# 验证集上的指标为:0.004592605400830507，总噪声为:0.025070490315556526,减少噪声0.020477885380387306

# %%
# 计算突破约束比例

# 定义临时类
# 创建一个临时类并继承 MyMixin
class TempClass(Vehicle_Model_Methods):
    pass

# 实例化临时类
temp_instance = TempClass()
ax_out_rate,delta_out_rate,traj_out_rate=temp_instance.constrain_count(val_out,10,0.25)
print('加速度突破率：',ax_out_rate)
print('转向突破率：',delta_out_rate)
print('轨迹突破率：',traj_out_rate)
# Out:
# 加速度突破率： 0.0056795598939061165
# 转向突破率： 0.04964030161499977
# 轨迹突破率： 0.1947759985923767

# %%
# 计算原始数据和噪声数据

print('噪声数据')
ax_out_rate,delta_out_rate,traj_out_rate=temp_instance.constrain_count(val_input,10,0.25)
print('加速度突破率：',ax_out_rate)
print('转向突破率：',delta_out_rate)
print('轨迹突破率：',traj_out_rate)


print('\n原始数据')
ax_out_rate,delta_out_rate,traj_out_rate=temp_instance.constrain_count(val_label,10,0.25)
print('加速度突破率：',ax_out_rate)
print('转向突破率：',delta_out_rate)
print('轨迹突破率：',traj_out_rate)
# Out:
# 噪声数据
# 加速度突破率： 0.714092493057251
# 转向突破率： 0.6231790781021118
# 轨迹突破率： 0.9953458905220032
#
# 原始数据
# 加速度突破率： 0.029488330706954002
# 转向突破率： 0.01897525228559971
# 轨迹突破率： 0.18869715929031372
